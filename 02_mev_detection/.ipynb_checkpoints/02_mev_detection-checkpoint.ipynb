# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Make sure plots display inline in Jupyter
# %matplotlib inline

# Configure pandas and Jupyter to show full output (no truncation)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.expand_frame_repr', False)

# Configure Jupyter to show full output
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Increase output limit (if using Jupyter)
import sys
try:
    sys.stdout.reconfigure(encoding='utf-8')
except (AttributeError, TypeError):
    # sys.stdout.reconfigure() not available in Jupyter notebooks
    pass

# ───────────────────────────────────────────────
# MEV Analysis #2: Top 10 Toxic MEV Stats & Validator Breakdown (Expanded)
# ───────────────────────────────────────────────
# Uses df_clean (cleaned fused table after time parsing & deletion)
# Assumes df_clean already exists in memory from previous steps
# ───────────────────────────────────────────────

df_clean = pd.read_parquet('/Users/aileen/Downloads/pamm/pamm_clean_final.parquet')
print(f"Using cleaned fused table for MEV Analysis #2. Total rows: {len(df_clean):,}")
print("Available columns:", df_clean.columns.tolist())

# ───────────────────────────────────────────────
# Parse trades column to extract from_token and to_token
# ───────────────────────────────────────────────
import json
import ast

def parse_trades(trades_item):
    """
    Safely parse trades column to extract from_token and to_token.
    Returns: (from_token, to_token)
    """
    # Handle None and NaN values safely
    if trades_item is None:
        return None, None
    try:
        if pd.isna(trades_item):
            return None, None
    except (ValueError, TypeError):
        # If pd.isna returns array, check if all are NA
        if isinstance(trades_item, (list, np.ndarray)):
            return None, None
        pass
    
    try:
        # Handle string representation of list/dict
        if isinstance(trades_item, str):
            # Try to parse as Python literal (handles single quotes)
            try:
                parsed = ast.literal_eval(trades_item)
            except (ValueError, SyntaxError):
                # Fallback to JSON parsing
                cleaned = trades_item.replace("'", '"').replace('None', 'null').replace('True', 'true').replace('False', 'false')
                parsed = json.loads(cleaned)
        else:
            parsed = trades_item
        
        # Handle list format
        if isinstance(parsed, list) and len(parsed) > 0:
            trade_dict = parsed[0] if isinstance(parsed[0], dict) else parsed
            if isinstance(trade_dict, dict):
                from_token = trade_dict.get('from_token')
                to_token = trade_dict.get('to_token')
                return from_token, to_token
        
        # Handle dict format
        elif isinstance(parsed, dict):
            from_token = parsed.get('from_token')
            to_token = parsed.get('to_token')
            return from_token, to_token
            
    except (json.JSONDecodeError, ValueError, AttributeError, TypeError) as e:
        pass
    
    return None, None

# Apply parsing function
print("\nParsing trades column to extract from_token and to_token...")
parsed_trades_series = df_clean['trades'].apply(parse_trades)
parsed_trades_df = pd.DataFrame(
    parsed_trades_series.tolist(),
    columns=['from_token', 'to_token'],
    index=df_clean.index
)

# Add parsed columns to dataframe
df_clean['from_token'] = parsed_trades_df['from_token']
df_clean['to_token'] = parsed_trades_df['to_token']

# ───────────────────────────────────────────────
# Map token addresses to human-readable names
# ───────────────────────────────────────────────
# Common Solana token address to name mapping
TOKEN_NAME_MAP = {
    # Wrapped SOL
    'So11111111111111111111111111111111111111112': 'WSOL',
    'So11111111111111111111111111111111111111111': 'WSOL',  # Alternative WSOL address
    
    # Stablecoins
    'EPjFWdd5AufqSSqeM2qN1xzybapC8G4wEGGkZwyTDt1v': 'USDC',
    'Es9vMFrzaCERmJfrF4H2FYD4KCoNkY11McCe8BenwNYB': 'USDT',
    '7kbnvuGBxxj8AG9qp8Scn56muWGaRaFqxg1FsRp3PaFT': 'UXD',
    'EchesyfXePKdLbiA9xYJ6UXTx4urmzE2pz6DXuTVg3fH': 'UXP',
    
    # Popular tokens
    '9BB6NFEcjBCtnNLFko2FqVQBq8HHM13kCyYcdQbgpump': 'PUMP',  # Based on example in data
    'mSoLzYCxHdYgdzU16g5QSh3i5K3z3KZK7ytfqcJm7So': 'mSOL',
    '7vfCXTUXx5WJV5JADk17DUJ4ksgau7utNKj4b963voxs': 'ETH',
    '2FPyTwcZLUg1MDrwsyoP4D6s1tM7hAkHYRjkNb5w6Pxk': 'ETH',
    '7dHbWXmci3dT8UFYWYZweBLXgycu7Y3iL6trKn1Y7ARj': 'ORCA',
    '4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R': 'RAY',
    'SRMuApVNdxXokk5GT7XD5cUUgXMBCoAz2LHeuAoKWRt': 'SRM',
    'DezXAZ8z7PnrnRJjz3wXBoRgixCa6xjnB7YaB1pPB263': 'BONK',
    'EKpQGSJtjMFqKZ9KQanSqYXRcF8fBopzLHYxdM65zcjm': 'WIF',
    'JUPyiwrY2skib1qAwsWzJxZxqJp3ZJ5K3JqJ5JqJ5JqJ5': 'JUP',
    
    # Add more common tokens as needed
    # You can extend this mapping based on tokens found in your dataset
}

def get_token_name(token_address):
    """
    Map token address to human-readable name.
    Returns token name if found, otherwise returns address (truncated if long).
    """
    if pd.isna(token_address) or token_address is None:
        return None
    
    token_address_str = str(token_address)
    
    # Check direct mapping
    if token_address_str in TOKEN_NAME_MAP:
        return TOKEN_NAME_MAP[token_address_str]
    
    # Return address if not found (can be extended to query on-chain metadata)
    return token_address_str

# Apply token name mapping
print("\nMapping token addresses to names...")
df_clean['from_token_name'] = df_clean['from_token'].apply(get_token_name)
df_clean['to_token_name'] = df_clean['to_token'].apply(get_token_name)

# Show token name mapping statistics
trades_with_names = df_clean[df_clean['kind'] == 'TRADE']
from_token_mapped = trades_with_names['from_token_name'].notna().sum()
to_token_mapped = trades_with_names['to_token_name'].notna().sum()

# Count how many are mapped vs unmapped (addresses)
from_token_named = trades_with_names[
    (trades_with_names['from_token_name'].notna()) & 
    (~trades_with_names['from_token_name'].str.match(r'^[A-Za-z0-9]{32,44}$', na=False))
].shape[0]

to_token_named = trades_with_names[
    (trades_with_names['to_token_name'].notna()) & 
    (~trades_with_names['to_token_name'].str.match(r'^[A-Za-z0-9]{32,44}$', na=False))
].shape[0]

print(f"Token name mapping statistics:")
print(f"  from_token_name: {from_token_named:,} tokens mapped to names")
print(f"  to_token_name: {to_token_named:,} tokens mapped to names")

# Show most common token pairs
if from_token_mapped > 0 and to_token_mapped > 0:
    token_pairs = trades_with_names[
        trades_with_names['from_token_name'].notna() & 
        trades_with_names['to_token_name'].notna()
    ][['from_token_name', 'to_token_name']].copy()
    
    if len(token_pairs) > 0:
        token_pairs['pair'] = token_pairs['from_token_name'] + '/' + token_pairs['to_token_name']
        top_pairs = token_pairs['pair'].value_counts().head(10)
        print(f"\nTop 10 token pairs (by name):")
        for pair, count in top_pairs.items():
            print(f"  {pair}: {count:,} trades")

# Calculate parsing success rate
trades_with_tokens = df_clean[df_clean['kind'] == 'TRADE']
success_rate = trades_with_tokens['from_token'].notna().mean() * 100
print(f"\nParsing success rate for TRADE events (from_token non-null): {success_rate:.2f}%")
print(f"Total TRADE events with token pairs: {trades_with_tokens['from_token'].notna().sum():,}")

# ───────────────────────────────────────────────
# Expanded Detection: Add Classic Sandwich (3 TRADEs) + Fat (≥5)
# ───────────────────────────────────────────────
# Ensure lag columns for back-running
df_clean['prev_kind'] = df_clean['kind'].shift(1)
df_clean['prev_ms_time'] = df_clean['ms_time'].shift(1)
df_clean['time_diff_ms'] = df_clean['ms_time'] - df_clean['prev_ms_time']

# Extract TRADE records
trades = df_clean[df_clean['kind'] == 'TRADE'].copy()
print(f"\nTRADE events for MEV analysis: {len(trades):,}")

# 1. IMPROVED Sandwich Detection with False Positive Filtering
# Distinguishes MEV attacks from:
# - Jupiter aggregator routing (multiple users, same aggregator)
# - Legitimate market makers
# - Failed sandwich attempts (front-run but no profitable back-run)

sandwich_records = []
failed_attempts = []  # Track failed sandwich attempts

for slot, g in trades.groupby('slot'):
    trade_count = len(g)
    if trade_count < 3:
        continue
    
    # Sort by time within slot
    g = g.sort_values('ms_time').reset_index(drop=True)
    
    signer_cnt = g['signer'].value_counts()
    attackers = signer_cnt[signer_cnt >= 2].index  # Signers with ≥2 tx in slot
    
    if len(attackers) == 0:
        continue
    
    # Use amm_trade instead of amm_oracle
    amm_col = 'amm_trade' if 'amm_trade' in g.columns else 'amm_oracle'
    most_common_amm = g[amm_col].mode()
    amm_name = most_common_amm.iloc[0] if not most_common_amm.empty else 'Unknown'
    validator = g['validator'].mode().iloc[0] if 'validator' in g.columns and not g['validator'].mode().empty else 'Unknown'
    
    # Check for aggregator patterns (Jupiter, etc.)
    # Aggregators typically have:
    # - Many unique signers (users) in same slot
    # - Similar transaction timing
    # - Same aggregator program ID (if available)
    unique_signers = g['signer'].nunique()
    aggregator_ratio = unique_signers / trade_count
    
    for attacker in attackers:
        attacker_trades = g[g['signer'] == attacker].copy()
        attacker_tx_count = len(attacker_trades)
        
        # Filter out aggregator routing:
        # If >70% of trades have unique signers, likely aggregator routing
        if aggregator_ratio > 0.7 and attacker_tx_count < trade_count * 0.3:
            # This looks like aggregator routing, not MEV
            continue
        
        # Check for sandwich pattern: front-run → victim(s) → back-run
        # MEV sandwich requires:
        # 1. Attacker has trades at beginning AND end of slot
        # 2. Other signers (victims) in between
        attacker_positions = attacker_trades.index.tolist()
        first_attacker_pos = min(attacker_positions)
        last_attacker_pos = max(attacker_positions)
        
        # Check if there are other signers between first and last attacker trade
        middle_trades = g.iloc[first_attacker_pos+1:last_attacker_pos]
        victims_between = middle_trades[middle_trades['signer'] != attacker]
        
        if len(victims_between) == 0:
            # No victims between attacker trades - could be failed attempt or unrelated
            # Check if this is a failed attempt (attacker at start but no back-run)
            if first_attacker_pos < len(g) * 0.3:  # Attacker in first 30% of slot
                failed_attempts.append({
                    'slot': slot,
                    'amm_trade': amm_name,
                    'attacker_signer': attacker,
                    'type': 'failed_frontrun',
                    'validator': validator,
                    'reason': 'no_victims_between'
                })
            continue
        
        # NEW: Validate token pair consistency for sandwich detection
        # In a true sandwich, all trades should be on the same token pair
        # This helps distinguish MEV from aggregator routing across different pools
        token_pairs_valid = True
        if 'from_token' in g.columns and 'to_token' in g.columns:
            # Get token pairs for all trades in slot
            attacker_token_pairs = attacker_trades[['from_token', 'to_token']].dropna()
            victim_token_pairs = victims_between[['from_token', 'to_token']].dropna()
            
            if len(attacker_token_pairs) > 0 and len(victim_token_pairs) > 0:
                # Check if attacker trades use consistent token pairs
                attacker_pairs = attacker_token_pairs.apply(
                    lambda x: tuple(sorted([str(x['from_token']), str(x['to_token'])])), axis=1
                ).unique()
                
                # Check if victims use same token pairs as attacker
                victim_pairs = victim_token_pairs.apply(
                    lambda x: tuple(sorted([str(x['from_token']), str(x['to_token'])])), axis=1
                ).unique()
                
                # For a valid sandwich, at least one token pair should be shared
                # (attacker front-runs and back-runs on same pair, victims trade on same pair)
                common_pairs = set(attacker_pairs) & set(victim_pairs)
                
                if len(common_pairs) == 0 and len(attacker_pairs) > 0:
                    # No common token pairs - might be aggregator routing across pools
                    # Still allow if attacker has consistent pair (could be reverse sandwich)
                    if len(attacker_pairs) > 1:
                        token_pairs_valid = False  # Attacker trading multiple pairs
                # If common_pairs exist or attacker has single consistent pair, it's valid
        
        # Additional validation: Check timing patterns
        # MEV attacks typically have:
        # - Front-run early in slot
        # - Back-run late in slot
        # - Victims in between
        attacker_times = attacker_trades['ms_time'].values
        slot_start = g['ms_time'].min()
        slot_end = g['ms_time'].max()
        slot_duration = slot_end - slot_start
        
        # Check if attacker trades span the slot (indicates sandwich)
        time_span = attacker_times.max() - attacker_times.min()
        span_ratio = time_span / slot_duration if slot_duration > 0 else 0
        
        # MEV sandwich should span at least 30% of slot duration
        if span_ratio < 0.3 and trade_count < 5:
            # Too tight timing, might be aggregator bundle
            continue
        
        # Additional validation: Token pair consistency
        # If token pairs are available but don't match, this might not be a true sandwich
        if not token_pairs_valid:
            # Skip if token pairs indicate this is not a sandwich on same pool
            continue
        
        # Check for consistent pattern across multiple slots (indicates bot, not aggregator)
        # This will be checked later in aggregation
        
        # Extract token pair info for the record
        token_pair_info = None
        if 'from_token' in attacker_trades.columns and 'to_token' in attacker_trades.columns:
            attacker_tokens = attacker_trades[['from_token', 'to_token']].dropna()
            if len(attacker_tokens) > 0:
                # Get most common token pair
                token_pairs = attacker_tokens.apply(
                    lambda x: f"{x['from_token']}/{x['to_token']}", axis=1
                )
                token_pair_info = token_pairs.mode().iloc[0] if len(token_pairs.mode()) > 0 else None
        
        # Classify as sandwich
        sandwich_type = 'fat_sandwich' if trade_count >= 5 else 'sandwich'
        
        sandwich_records.append({
            'slot': slot,
            'amm_trade': amm_name,
            'attacker_signer': attacker,
            'attack_tx_count': attacker_tx_count,
            'trade_count_in_slot': trade_count,
            'victims_count': len(victims_between),
            'unique_signers': unique_signers,
            'aggregator_ratio': aggregator_ratio,
            'time_span_ratio': span_ratio,
            'token_pair': token_pair_info,  # NEW: Add token pair info
            'type': sandwich_type,
            'validator': validator,
            'confidence': 'high' if span_ratio > 0.5 and len(victims_between) >= 2 else 'medium'
        })

sandwich_df = pd.DataFrame(sandwich_records)
failed_attempts_df = pd.DataFrame(failed_attempts) if failed_attempts else pd.DataFrame()

print(f"\nSandwich patterns detected: {len(sandwich_df)}")
print(f"Failed sandwich attempts (front-run only): {len(failed_attempts_df)}")
if not sandwich_df.empty:
    print(f"High confidence MEV attacks: {len(sandwich_df[sandwich_df['confidence'] == 'high'])}")
    print(f"Medium confidence (possible aggregator): {len(sandwich_df[sandwich_df['confidence'] == 'medium'])}")

# Get top 10 attackers - prioritize high-confidence MEV attacks
if not sandwich_df.empty:
    # Filter to high-confidence attacks first, then medium
    high_conf = sandwich_df[sandwich_df['confidence'] == 'high']
    
    if len(high_conf) > 0:
        # Count by high-confidence attacks
        high_conf_counts = high_conf['attacker_signer'].value_counts()
        print(f"\nHigh-confidence MEV attackers: {len(high_conf_counts)}")
        
        # Get top 10 from high-confidence, fill with medium if needed
        top10_high = high_conf_counts.head(10).index.tolist()
        
        if len(top10_high) < 10:
            # Add medium-confidence attackers to reach 10
            medium_conf = sandwich_df[sandwich_df['confidence'] == 'medium']
            medium_counts = medium_conf['attacker_signer'].value_counts()
            # Exclude already selected
            medium_counts = medium_counts[~medium_counts.index.isin(top10_high)]
            top10_medium = medium_counts.head(10 - len(top10_high)).index.tolist()
            top10_attackers = top10_high + top10_medium
        else:
            top10_attackers = top10_high
    else:
        # Fallback to all if no high-confidence
        top10_attackers = sandwich_df['attacker_signer'].value_counts().head(10).index.tolist()
        print("\n⚠️  WARNING: No high-confidence MEV attacks found. Top 10 may include aggregator routing.")
    
    print(f"\nTop 10 attackers (prioritizing high-confidence MEV): {top10_attackers}")
    
    # Show breakdown
    if not sandwich_df.empty:
        print(f"\nConfidence breakdown:")
        print(f"  High confidence (likely MEV): {len(sandwich_df[sandwich_df['confidence'] == 'high'])}")
        print(f"  Medium confidence (possible aggregator/MEV): {len(sandwich_df[sandwich_df['confidence'] == 'medium'])}")
else:
    top10_attackers = []
    print("No sandwich patterns detected.")

# ───────────────────────────────────────────────
# VERIFICATION: Classify all detected attackers to filter out aggregators/wash traders
# This runs BEFORE final top 10 selection to ensure we only show actual MEV bots
# ───────────────────────────────────────────────
print(f"\n{'='*80}")
print("VERIFICATION: Classifying All Detected Attackers")
print(f"{'='*80}")
print("⚠️  Running verification on all detected attackers to filter out:")
print("   - Aggregators (Jupiter routing)")
print("   - Wash traders (volume inflation)")
print("   - Regular trade bots")
print("   Only addresses classified as 'LIKELY MEV BOT' or 'POSSIBLE MEV' will be included in final top 10.\n")

# Get all unique attackers from sandwich detection
all_detected_attackers = []
if not sandwich_df.empty:
    all_detected_attackers = sandwich_df['attacker_signer'].unique().tolist()

verification_results = []

if len(all_detected_attackers) > 0:
    print(f"Verifying {len(all_detected_attackers)} detected attackers...\n")
    
    for idx, attacker in enumerate(all_detected_attackers, 1):
        if idx % 50 == 0:
            print(f"  Progress: {idx}/{len(all_detected_attackers)} attackers verified...")
        
        attacker_trades = trades[trades['signer'] == attacker].copy()
        
        if len(attacker_trades) == 0:
            continue
        
        # Calculate metrics
        total_trades = len(attacker_trades)
        
        # 1. Check for aggregator pattern: many unique signers in same slots
        attacker_slots = attacker_trades['slot'].unique()
        aggregator_score = 0
        
        # Sample up to 200 slots for aggregator detection
        sample_slots = min(200, len(attacker_slots))
        for slot in attacker_slots[:sample_slots]:
            slot_trades = trades[trades['slot'] == slot]
            unique_signers = slot_trades['signer'].nunique()
            total_in_slot = len(slot_trades)
            if total_in_slot > 0:
                ratio = unique_signers / total_in_slot
                if ratio > 0.7:  # High unique signer ratio = aggregator
                    aggregator_score += 1
        
        aggregator_likelihood = aggregator_score / sample_slots if sample_slots > 0 else 0
        
        # 2. Check for MEV patterns
        # - Late-slot timing (front-running)
        late_slot_trades = attacker_trades[attacker_trades['us_since_first_shred'] > 300000]
        late_slot_ratio = len(late_slot_trades) / total_trades if total_trades > 0 else 0
        
        # - Oracle back-running
        attacker_trades_with_prev = attacker_trades.copy()
        attacker_trades_with_prev['prev_kind'] = df_clean.loc[attacker_trades_with_prev.index, 'prev_kind'].values
        oracle_backrun = attacker_trades_with_prev[
            (attacker_trades_with_prev['prev_kind'] == 'ORACLE') & 
            (attacker_trades_with_prev['time_diff_ms'] < 50)
        ]
        oracle_backrun_ratio = len(oracle_backrun) / total_trades if total_trades > 0 else 0
        
        # - High bytes_changed (oracle manipulation)
        high_bytes = attacker_trades[attacker_trades['bytes_changed_trade'] > 50]
        high_bytes_ratio = len(high_bytes) / total_trades if total_trades > 0 else 0
        
        # - Clusters (multiple tx in same slot)
        attacker_trades['tx_in_slot'] = attacker_trades.groupby('slot')['slot'].transform('count')
        clusters = attacker_trades[attacker_trades['tx_in_slot'] >= 2]
        cluster_ratio = len(clusters) / total_trades if total_trades > 0 else 0
        
        # Calculate MEV score
        mev_score = (late_slot_ratio * 0.3 + 
                    oracle_backrun_ratio * 0.3 + 
                    high_bytes_ratio * 0.2 + 
                    cluster_ratio * 0.2)
        
        # 3. Check for wash trading patterns
        if len(attacker_trades) > 10:
            time_span_hours = (attacker_trades['ms_time'].max() - attacker_trades['ms_time'].min()) / (1000 * 60 * 60)
            trades_per_hour = len(attacker_trades) / time_span_hours if time_span_hours > 0 else 0
            wash_trading_score = trades_per_hour / 50  # Normalize to 50 trades/hour
        else:
            wash_trading_score = 0
            trades_per_hour = 0
        
        # Classification with wash trading detection
        if aggregator_likelihood > 0.5:
            classification = "LIKELY AGGREGATOR (Jupiter, etc.)"
            confidence = "High" if aggregator_likelihood > 0.7 else "Medium"
        elif wash_trading_score > 1.0 and mev_score < 0.2:
            classification = "LIKELY WASH TRADING (Volume Inflation)"
            confidence = "High" if wash_trading_score > 2.0 else "Medium"
        elif mev_score > 0.3:
            classification = "LIKELY MEV BOT"
            confidence = "High" if mev_score > 0.5 else "Medium"
        elif cluster_ratio > 0.3:
            classification = "POSSIBLE MEV (Sandwich patterns)"
            confidence = "Medium"
        else:
            classification = "REGULAR TRADE BOT / UNKNOWN"
            confidence = "Low"
        
        verification_results.append({
            'attacker': attacker,
            'total_trades': total_trades,
            'trades_per_hour': trades_per_hour,
            'aggregator_likelihood': aggregator_likelihood,
            'late_slot_ratio': late_slot_ratio,
            'oracle_backrun_ratio': oracle_backrun_ratio,
            'high_bytes_ratio': high_bytes_ratio,
            'cluster_ratio': cluster_ratio,
            'mev_score': mev_score,
            'wash_trading_score': wash_trading_score,
            'classification': classification,
            'confidence': confidence
        })
    
    # Create verification dataframe
    verification_df = pd.DataFrame(verification_results)
    
    if not verification_df.empty:
        # Save full verification results
        verification_df.to_csv('mev_attacker_verification.csv', index=False)
        print(f"\n✓ Verification complete. Results saved to: mev_attacker_verification.csv")
        
        # Show classification breakdown
        print(f"\nClassification Breakdown (All {len(verification_df)} Detected Attackers):")
        classification_counts = verification_df['classification'].value_counts()
        for classification, count in classification_counts.items():
            print(f"  {classification}: {count}")
        
        # Filter to only MEV bots for top 10 list
        mev_bots = verification_df[
            verification_df['classification'].isin(['LIKELY MEV BOT', 'POSSIBLE MEV (Sandwich patterns)'])
        ].copy()
        
        if len(mev_bots) > 0:
            # Sort by MEV score (descending) and get top 10
            mev_bots = mev_bots.sort_values('mev_score', ascending=False)
            top10_mev_bots = mev_bots.head(10)['attacker'].tolist()
            
            print(f"\n{'='*80}")
            print("FILTERED TOP 10 MEV ATTACKERS (After Verification)")
            print(f"{'='*80}")
            print(f"\n✓ Found {len(mev_bots)} addresses classified as MEV bots (out of {len(verification_df)} total)")
            print(f"✓ Top 10 MEV bots (by MEV score):")
            for idx, attacker in enumerate(top10_mev_bots, 1):
                attacker_info = mev_bots[mev_bots['attacker'] == attacker].iloc[0]
                print(f"  {idx}. {attacker}")
                print(f"     Classification: {attacker_info['classification']}")
                print(f"     MEV Score: {attacker_info['mev_score']:.2%}")
                print(f"     Total Trades: {attacker_info['total_trades']:,}")
            
            # Update top10_attackers to only include verified MEV bots
            top10_attackers = top10_mev_bots
            
            print(f"\n⚠️  IMPORTANT: Updated top10_attackers list to only include verified MEV bots.")
            print(f"   Excluded: {len(verification_df) - len(mev_bots)} addresses classified as aggregators/wash traders/regular bots")
        else:
            print(f"\n⚠️  WARNING: No addresses classified as 'LIKELY MEV BOT' or 'POSSIBLE MEV' found!")
            print(f"   All {len(verification_df)} detected addresses are classified as:")
            for classification, count in classification_counts.items():
                print(f"     - {classification}: {count}")
            print(f"\n   This suggests:")
            print(f"     - Most activity is aggregator routing (Jupiter, etc.)")
            print(f"     - Or detection thresholds may need adjustment")
            print(f"   Original top10_attackers list (by sandwich count) will be used, but may include aggregators.")
    else:
        print("No verification results generated.")
else:
    print("No attackers detected for verification.")

# Analyze failed attempts
if not failed_attempts_df.empty:
    print(f"\n{'='*80}")
    print("FAILED SANDWICH ATTEMPTS ANALYSIS")
    print(f"{'='*80}")
    print(f"Total failed attempts: {len(failed_attempts_df)}")
    print(f"Failed attempts per attacker:")
    print(failed_attempts_df['attacker_signer'].value_counts().head(10))
    print("\n⚠️  Note: Failed attempts indicate front-running without profitable back-run.")
    print("   These may be:")
    print("   - Unsuccessful MEV attempts")
    print("   - Legitimate early trades that didn't result in sandwich")
    print("   - Aggregator routing with timing coincidences")

# 2. Front-running Detection (late-slot trades >0.3s delay, expanded to include slot avg latency)
front_running = trades[trades['us_since_first_shred'] > 300000].copy()
front_running['type'] = 'front_running'
# Use amm_trade instead of amm_oracle
front_running = front_running[['slot', 'amm_trade', 'signer', 'type', 'validator', 'us_since_first_shred']].rename(columns={'signer': 'attacker_signer'})
if 'amm_trade' not in front_running.columns:
    front_running = front_running.rename(columns={'amm_oracle': 'amm_trade'})
front_running_top10 = front_running[front_running['attacker_signer'].isin(top10_attackers)]

# Average latency per slot in front-running
front_running['slot_avg_latency'] = front_running.groupby('slot')['us_since_first_shred'].transform('mean')

# 3. Back-running Detection (immediately after ORACLE, <50ms, expanded to include oracle count)
back_running = trades[(trades['prev_kind'] == 'ORACLE') & (trades['time_diff_ms'] < 50)].copy()
back_running['type'] = 'back_running'
# Use amm_trade instead of amm_oracle
back_running = back_running[['slot', 'amm_trade', 'signer', 'type', 'validator', 'time_diff_ms']].rename(columns={'signer': 'attacker_signer'})
if 'amm_trade' not in back_running.columns:
    back_running = back_running.rename(columns={'amm_oracle': 'amm_trade'})
back_running_top10 = back_running[back_running['attacker_signer'].isin(top10_attackers)]

# Count oracle updates per slot in back-running
oracle_per_slot = df_clean[df_clean['kind'] == 'ORACLE'].groupby('slot').size().reset_index(name='oracle_count')
back_running = back_running.merge(oracle_per_slot, on='slot', how='left').fillna(0)

# Merge all MEV records (top10 only)
# Ensure all dataframes have amm_trade column before merging
if 'amm_trade' not in sandwich_df.columns and 'amm' in sandwich_df.columns:
    sandwich_df = sandwich_df.rename(columns={'amm': 'amm_trade'})

all_mev = pd.concat([sandwich_df, front_running_top10, back_running_top10], ignore_index=True)

# Function to display Per pAMM Top 10 MEV table
def display_per_pamm_top10_mev(stats_df, top_n=10):
    """
    Display Top N MEV attackers per pAMM in a formatted table.
    
    Parameters:
    -----------
    stats_df : DataFrame
        Stats dataframe with columns: amm_trade, attacker_signer, validator, 
        fat_sandwich, sandwich, front_running, back_running, etc.
    top_n : int
        Number of top attackers to show per AMM (default: 10)
    """
    from IPython.display import display as ipy_display
    
    if stats_df.empty:
        print("\nNo MEV stats to display.")
        return
    
    # Ensure amm_trade column exists
    if 'amm_trade' not in stats_df.columns:
        if 'amm_oracle' in stats_df.columns:
            stats_df = stats_df.rename(columns={'amm_oracle': 'amm_trade'})
        else:
            print("Error: No amm_trade or amm_oracle column found in stats.")
            return
    
    print(f"\n{'='*100}")
    print(f"Per pAMM Top {top_n} MEV Attackers Table")
    print(f"{'='*100}\n")
    
    # Group by amm_trade
    amm_groups = stats_df.groupby('amm_trade')
    
    for amm, group in amm_groups:
        # Sort by total MEV activity (fat_sandwich + sandwich + front_running + back_running)
        group = group.copy()  # Avoid SettingWithCopyWarning
        group['total_mev'] = (group.get('fat_sandwich', 0) + 
                             group.get('sandwich', 0) + 
                             group.get('front_running', 0) + 
                             group.get('back_running', 0))
        
        # Get top N per AMM
        top_group = group.nlargest(top_n, 'total_mev')
        
        print(f"\n{'─'*100}")
        print(f"pAMM: {amm}")
        print(f"Total Attackers: {len(group)}, Showing Top {min(top_n, len(group))}")
        print(f"{'─'*100}")
        
        # Display columns
        display_cols = ['attacker_signer', 'validator', 'fat_sandwich', 'sandwich', 
                       'front_running', 'back_running', 'sandwich_complete', 
                       'cost_sol', 'profit_sol', 'net_profit_sol']
        available_cols = [c for c in display_cols if c in top_group.columns]
        
        # Format the table
        display_df = top_group[available_cols].copy()
        
        # Format float columns
        float_cols = ['cost_sol', 'profit_sol', 'net_profit_sol']
        for col in float_cols:
            if col in display_df.columns:
                display_df[col] = display_df[col].apply(lambda x: f'{x:.4f}' if isinstance(x, (int, float)) else x)
        
        # Reset index for display
        display_df = display_df.reset_index(drop=True)
        display_df.index = display_df.index + 1  # Start from 1 instead of 0
        
        # Use display() for better Jupyter formatting (scrollable, no truncation)
        ipy_display(display_df)
        print()

if all_mev.empty:
    print("\nNo MEV patterns detected.")
    stats = pd.DataFrame()
else:
    # Ensure all_mev has amm_trade column (should already have it from previous fixes)
    if 'amm_trade' not in all_mev.columns:
        if 'amm_oracle' in all_mev.columns:
            all_mev = all_mev.rename(columns={'amm_oracle': 'amm_trade'})
        elif 'amm' in all_mev.columns:
            all_mev = all_mev.rename(columns={'amm': 'amm_trade'})
    
    # Stats: Group by amm_trade + attacker_signer + type (FIXED: use amm_trade not amm_oracle)
    # IMPORTANT: Don't filter to top10 attackers here - we want ALL pAMMs with their top attackers
    stats = all_mev.groupby(['amm_trade', 'attacker_signer', 'type']).size().unstack(fill_value=0)
    stats = stats.reset_index()

    # Safe fill missing type columns
    for col in ['fat_sandwich', 'sandwich', 'front_running', 'back_running']:
        if col not in stats.columns:
            stats[col] = 0

    # Add validator (first per attacker-amm pair)
    validator_map = all_mev.groupby(['amm_trade', 'attacker_signer'])['validator'].first().reset_index(name='validator')
    stats = pd.merge(stats, validator_map, on=['amm_trade', 'attacker_signer'], how='left')

    # Derived metrics (approximate SOL)
    stats['sandwich_complete'] = stats.get('fat_sandwich', 0) // 2 + stats.get('sandwich', 0) // 2
    stats['cost_sol'] = (stats['sandwich_complete'] * 0.001) + (stats.get('front_running', 0) * 0.0005) + (stats.get('back_running', 0) * 0.0005)
    stats['profit_sol'] = (stats['sandwich_complete'] * 0.01) + (stats.get('front_running', 0) * 0.002) + (stats.get('back_running', 0) * 0.002)
    stats['net_profit_sol'] = stats['profit_sol'] - stats['cost_sol']
    
    # Add confidence levels to stats if available
    if 'confidence' in sandwich_df.columns:
        confidence_map = sandwich_df.groupby(['amm_trade', 'attacker_signer'])['confidence'].agg(
            lambda x: 'high' if (x == 'high').any() else 'medium'
        ).reset_index(name='confidence')
        stats = pd.merge(stats, confidence_map, on=['amm_trade', 'attacker_signer'], how='left')
    
    # Save ALL stats (not filtered to top10)
    stats.to_csv('per_pamm_all_mev_with_validator.csv', index=False)
    print("\nAll pAMM MEV stats (all attackers) saved to: per_pamm_all_mev_with_validator.csv")
    
    # Save failed attempts
    if not failed_attempts_df.empty:
        failed_attempts_df.to_csv('failed_sandwich_attempts.csv', index=False)
        print("Failed sandwich attempts saved to: failed_sandwich_attempts.csv")
    
    # Save confidence breakdown
    if not sandwich_df.empty and 'confidence' in sandwich_df.columns:
        confidence_summary = sandwich_df.groupby(['amm_trade', 'confidence']).size().unstack(fill_value=0)
        confidence_summary.to_csv('mev_confidence_breakdown.csv')
        print("MEV confidence breakdown saved to: mev_confidence_breakdown.csv")
        print("\n⚠️  IMPORTANT: Review confidence levels:")
        print("   - 'high': Likely MEV attacks (attacker spans slot, victims between)")
        print("   - 'medium': Possible aggregator routing or less clear MEV pattern")

# ───────────────────────────────────────────────
# Variable Ranking by MEV Detection Contribution
# ───────────────────────────────────────────────
print(f"\n{'='*80}")
print("VARIABLE RANKING BY MEV DETECTION CONTRIBUTION")
print(f"{'='*80}")

# Calculate contribution scores for each variable
variable_contributions = {}

if not sandwich_df.empty:
    # 1. Signer (attacker identification) - CRITICAL
    # Used in: All MEV detection (sandwich, front-run, back-run)
    signer_contribution = {
        'variable': 'signer',
        'importance': 'CRITICAL',
        'score': 10.0,
        'usage': 'Identifies MEV attackers across all detection methods',
        'details': [
            'Sandwich: Groups trades by signer to find attackers with ≥2 tx in slot',
            'Front-run: Filters to top MEV attackers by signer',
            'Back-run: Filters to top MEV attackers by signer',
            'Fat sandwich: Validates same signer at start and end of slot'
        ]
    }
    variable_contributions['signer'] = signer_contribution
    
    # 2. Token Pair (from_token/to_token) - CRITICAL for validation
    # Used in: Sandwich validation to ensure same pool
    token_pair_usage = 0
    if 'token_pair' in sandwich_df.columns:
        token_pair_usage = sandwich_df['token_pair'].notna().sum()
    
    token_pair_contribution = {
        'variable': 'from_token/to_token',
        'importance': 'CRITICAL',
        'score': 9.5,
        'usage': 'Validates sandwich attacks are on same token pair (same pool)',
        'details': [
            'Prevents false positives from aggregator routing across different pools',
            'Ensures front-run and back-run are on same trading pair',
            'Helps distinguish true MEV from multi-pool aggregator bundles',
            f'Used in {token_pair_usage:,} sandwich detections'
        ]
    }
    variable_contributions['token_pair'] = token_pair_contribution
    
    # 3. Slot - CRITICAL
    # Used in: All detection methods (grouping trades by slot)
    slot_contribution = {
        'variable': 'slot',
        'importance': 'CRITICAL',
        'score': 10.0,
        'usage': 'Groups trades temporally for sandwich detection',
        'details': [
            'Sandwich: Groups trades in same slot to detect front-run → victim → back-run',
            'Front-run: Identifies late-slot trades (>300ms)',
            'Back-run: Links trades to oracle updates in same slot',
            'Fat sandwich: Requires ≥5 trades in same slot'
        ]
    }
    variable_contributions['slot'] = slot_contribution
    
    # 4. Time (ms_time) - CRITICAL
    # Used in: Timing validation for sandwich and back-run
    time_contribution = {
        'variable': 'ms_time',
        'importance': 'CRITICAL',
        'score': 9.0,
        'usage': 'Validates timing patterns for MEV attacks',
        'details': [
            'Sandwich: Validates attacker trades span ≥30% of slot duration',
            'Back-run: Requires <50ms response time after oracle update',
            'Front-run: Identifies late-slot trades (>300ms delay)',
            'Time span ratio: Key metric for high-confidence MEV (span >50% = high confidence)'
        ]
    }
    variable_contributions['ms_time'] = time_contribution
    
    # 5. Validator - HIGH
    # Used in: Attribution and clustering
    validator_contribution = {
        'variable': 'validator',
        'importance': 'HIGH',
        'score': 7.5,
        'usage': 'Attribution and validator-level MEV analysis',
        'details': [
            'Identifies which validators process MEV attacks',
            'Enables validator-level clustering and analysis',
            'Helps identify validator-MEV bot relationships',
            'Used in per-validator MEV statistics'
        ]
    }
    variable_contributions['validator'] = validator_contribution
    
    # 6. AMM (amm_trade) - HIGH
    # Used in: Protocol-level analysis
    amm_contribution = {
        'variable': 'amm_trade',
        'importance': 'HIGH',
        'score': 7.0,
        'usage': 'Identifies which pAMM protocols are targeted',
        'details': [
            'Groups MEV attacks by protocol (ZeroFi, HumidiFi, etc.)',
            'Enables per-protocol MEV statistics',
            'Helps identify protocol-specific attack patterns',
            'Used in per-pAMM top 10 attacker analysis'
        ]
    }
    variable_contributions['amm_trade'] = amm_contribution
    
    # 7. Time difference (time_diff_ms) - HIGH
    # Used in: Back-running detection
    time_diff_contribution = {
        'variable': 'time_diff_ms',
        'importance': 'HIGH',
        'score': 8.0,
        'usage': 'Detects back-running after oracle updates',
        'details': [
            'Back-run: Requires <50ms between oracle update and trade',
            'Indicates automated bot response to oracle price changes',
            'Key metric for distinguishing MEV from normal trading',
            'Threshold: <50ms = suspicious, <30ms = highly suspicious'
        ]
    }
    variable_contributions['time_diff_ms'] = time_diff_contribution
    
    # 8. Latency (us_since_first_shred) - MEDIUM-HIGH
    # Used in: Front-running detection
    latency_contribution = {
        'variable': 'us_since_first_shred',
        'importance': 'MEDIUM-HIGH',
        'score': 7.0,
        'usage': 'Detects late-slot trades (front-running)',
        'details': [
            'Front-run: Requires >300ms delay (300,000 microseconds)',
            'Indicates strategic placement late in slot',
            'Suggests mempool monitoring and insertion',
            'Threshold: >300ms = suspicious front-running'
        ]
    }
    variable_contributions['us_since_first_shred'] = latency_contribution
    
    # 9. Previous kind (prev_kind) - MEDIUM
    # Used in: Back-running detection
    prev_kind_contribution = {
        'variable': 'prev_kind',
        'importance': 'MEDIUM',
        'score': 6.5,
        'usage': 'Links trades to preceding oracle updates',
        'details': [
            'Back-run: Requires prev_kind == "ORACLE"',
            'Validates trade immediately follows price update',
            'Key for detecting oracle exploitation',
            'Used in conjunction with time_diff_ms'
        ]
    }
    variable_contributions['prev_kind'] = prev_kind_contribution
    
    # 10. Aggregator ratio - MEDIUM
    # Used in: Filtering false positives
    aggregator_ratio_contribution = {
        'variable': 'aggregator_ratio',
        'importance': 'MEDIUM',
        'score': 6.0,
        'usage': 'Filters out Jupiter aggregator routing (false positives)',
        'details': [
            'Calculated as: unique_signers / trade_count',
            'If >0.7 and attacker has <30% of trades → likely aggregator',
            'Prevents false positives from legitimate aggregator routing',
            'Key for distinguishing MEV from aggregator bundles'
        ]
    }
    variable_contributions['aggregator_ratio'] = aggregator_ratio_contribution
    
    # 11. Time span ratio - MEDIUM
    # Used in: Confidence scoring
    time_span_ratio_contribution = {
        'variable': 'time_span_ratio',
        'importance': 'MEDIUM',
        'score': 6.5,
        'usage': 'Confidence scoring for sandwich attacks',
        'details': [
            'Calculated as: (attacker_max_time - attacker_min_time) / slot_duration',
            'High confidence: >50% span AND ≥2 victims',
            'Medium confidence: 30-50% span OR 1 victim',
            'Validates attacker trades span significant portion of slot'
        ]
    }
    variable_contributions['time_span_ratio'] = time_span_ratio_contribution
    
    # 12. Victims count - MEDIUM
    # Used in: Confidence scoring
    victims_count_contribution = {
        'variable': 'victims_count',
        'importance': 'MEDIUM',
        'score': 6.0,
        'usage': 'Confidence scoring and fat sandwich validation',
        'details': [
            'High confidence: ≥2 victims between attacker trades',
            'Validates true sandwich pattern (victims between front-run and back-run)',
            'Fat sandwich: Multiple victims in same slot',
            'Key for distinguishing MEV from failed attempts'
        ]
    }
    variable_contributions['victims_count'] = victims_count_contribution

# Sort by score (descending)
ranked_variables = sorted(variable_contributions.items(), key=lambda x: x[1]['score'], reverse=True)

# Display ranking
print("\nRank | Variable              | Importance | Score | Usage")
print("-" * 80)
for rank, (var_name, var_info) in enumerate(ranked_variables, 1):
    print(f"{rank:4d} | {var_info['variable']:20s} | {var_info['importance']:11s} | {var_info['score']:5.1f} | {var_info['usage']}")

# Save ranking to file
ranking_df = pd.DataFrame([
    {
        'rank': rank,
        'variable': var_info['variable'],
        'importance': var_info['importance'],
        'score': var_info['score'],
        'usage': var_info['usage'],
        'details': '; '.join(var_info['details'])
    }
    for rank, (var_name, var_info) in enumerate(ranked_variables, 1)
])
ranking_df.to_csv('mev_variable_ranking.csv', index=False)
print(f"\n✓ Variable ranking saved to: mev_variable_ranking.csv")

# Display detailed breakdown
print(f"\n{'='*80}")
print("DETAILED VARIABLE CONTRIBUTION BREAKDOWN")
print(f"{'='*80}")
for rank, (var_name, var_info) in enumerate(ranked_variables, 1):
    print(f"\n{rank}. {var_info['variable']} (Score: {var_info['score']:.1f}, {var_info['importance']})")
    print(f"   Usage: {var_info['usage']}")
    print("   Details:")
    for detail in var_info['details']:
        print(f"     • {detail}")

# Stats and all_mev are now available for next cells
# Out:
# Using cleaned fused table for MEV Analysis #2. Total rows: 5,506,090
# Available columns: ['slot', 'time', 'validator', 'tx_idx', 'sig', 'signer', 'kind', 'amm_oracle', 'account_updates', 'trades', 'us_since_first_shred', 'amm_trade', 'account_trade', 'is_pool_trade', 'bytes_changed_trade', 'datetime', 'timing_missing', 'ms_time']
#
# TRADE events for MEV analysis: 683,828
#
# Sandwich patterns detected: 26223
# Failed sandwich attempts (front-run only): 6339
# High confidence MEV attacks: 7897
# Medium confidence (possible aggregator): 18326
#
# High-confidence MEV attackers: 197
#
# Top 10 attackers (prioritizing high-confidence MEV): ['YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP', 'E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2', 'YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW', 'YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj', '4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV', 'FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1', 'k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq', 'CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP', 'TAPNDP5dFr9Vp47DFuddRxNVYmjUqgh8boiUrWFgMqi', 'AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3']
#
# Confidence breakdown:
#   High confidence (likely MEV): 7897
#   Medium confidence (possible aggregator/MEV): 18326
#
# ================================================================================
# FAILED SANDWICH ATTEMPTS ANALYSIS
# ================================================================================
# Total failed attempts: 6339
# Failed attempts per attacker:
# attacker_signer
# YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP     875
# YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW     554
# AEB9dXBoxkrapNd59Kg29JefMMf3M1WLcNA12XjKSf4R    420
# E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2    140
# 4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV    133
# k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq     133
# 2npqrs8E9iWPGjRhWp7BsD9nG62xnBm9Av4rWgqF3ZPK    130
# C2bK8HFrL71aLnpyExVoJmqjDPA9tbLMXcBNAkRQnLfQ    127
# EJdrWPg32qHnmc3cwgGRfTrvWpQkDH2vHNGsane6WFGd    125
# J8hVkBNKobntWqLspa3yhXEkvb8vZ9S9NiHgirN9yvV3    120
# Name: count, dtype: int64
#
# ⚠️  Note: Failed attempts indicate front-running without profitable back-run.
#    These may be:
#    - Unsuccessful MEV attempts
#    - Legitimate early trades that didn't result in sandwich
#    - Aggregator routing with timing coincidences
#
# All pAMM MEV stats (all attackers) saved to: per_pamm_all_mev_with_validator.csv
# Failed sandwich attempts saved to: failed_sandwich_attempts.csv
# MEV confidence breakdown saved to: mev_confidence_breakdown.csv
#
# ⚠️  IMPORTANT: Review confidence levels:
#    - 'high': Likely MEV attacks (attacker spans slot, victims between)
#    - 'medium': Possible aggregator routing or less clear MEV pattern

# %%
# ───────────────────────────────────────────────
# Cell 2: Display Per pAMM Top 10 MEV Attackers Table
# ───────────────────────────────────────────────
if not stats.empty:
    # Show summary of pAMMs found
    unique_pamms = stats['amm_trade'].unique()
    print(f"\nTotal pAMMs with MEV activity: {len(unique_pamms)}")
    print(f"pAMMs found: {', '.join(sorted(unique_pamms))}\n")
    
    # Display Per pAMM Top 10 MEV table using the function
    # Use display() instead of print() for better formatting in Jupyter
    display_per_pamm_top10_mev(stats, top_n=10)
    
    # Also save filtered top10 per pAMM version
    # For each pAMM, get top 10 attackers
    top10_per_pamm_list = []
    for amm, group in stats.groupby('amm_trade'):
        group = group.copy()  # Avoid SettingWithCopyWarning
        group['total_mev'] = (group.get('fat_sandwich', 0) + 
                             group.get('sandwich', 0) + 
                             group.get('front_running', 0) + 
                             group.get('back_running', 0))
        top10_per_pamm = group.nlargest(10, 'total_mev')
        top10_per_pamm_list.append(top10_per_pamm)
    
    if top10_per_pamm_list:
        top10_per_pamm_df = pd.concat(top10_per_pamm_list, ignore_index=True)
        top10_per_pamm_df = top10_per_pamm_df.drop('total_mev', axis=1, errors='ignore')
        top10_per_pamm_df.to_csv('per_pamm_top10_mev_with_validator.csv', index=False)
        print("\n✓ Per pAMM Top 10 MEV stats (top 10 per pAMM) saved to: per_pamm_top10_mev_with_validator.csv")
        
        # Also display the full dataframe using display() for better viewing
        print("\n" + "="*100)
        print("Full Per pAMM Top 10 MEV Table (All pAMMs Combined)")
        print("="*100)
        display(top10_per_pamm_df)
else:
    print("\nNo MEV stats available to display.")
# Out:
# Total pAMMs with MEV activity: 8
# pAMMs found: BisonFi, GoonFi, HumidiFi, ObricV2, SolFi, SolFiV2, TesseraV, ZeroFi
#
#
# ====================================================================================================
# Per pAMM Top 10 MEV Attackers Table
# ====================================================================================================
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: BisonFi
# Total Attackers: 182, Showing Top 10
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                  attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1    YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP  CiR8HNCfkjtcongPmP2DRdZPnFgjSbN5gsXdjmsXXHcB           456         7           1053          4075                231   2.7950    12.5660         9.7710
# 2   4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV  9n1eEtJJfj1535NYfx524QcCG5aHbf5DH7ejqBrFLBwG           127         2            208          1148                 64   0.7420     3.3520         2.6100
# 3   AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU            63         0            148           875                 31   0.5425     2.3560         1.8135
# 4   CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP  9n1eEtJJfj1535NYfx524QcCG5aHbf5DH7ejqBrFLBwG            91         1            117           649                 45   0.4280     1.9820         1.5540
# 5   FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1  ArMBx6veRq33ffEP9sxHafiPRgrtzww4XvbwZbSMfXiM            24         0             45           238                 12   0.1535     0.6860         0.5325
# 6   E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF            33         1             48           194                 16   0.1370     0.6440         0.5070
# 7   C2bK8HFrL71aLnpyExVoJmqjDPA9tbLMXcBNAkRQnLfQ  5pPRHniefFjkiaArbGX3Y8NUysJmQ9tMZg3FrFGwHzSm           181         5              0             0                 92   0.0920     0.9200         0.8280
# 8    foxMFk9faHggM4HWQWETCPSDvMbWx8LSv4c9CrkmBx6  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF           110         0              0             0                 55   0.0550     0.5500         0.4950
# 9   DkV8QZdg5GH7Bb5NteLJVYCF2mwBSCFt7AcTnmVvTfeW  EvnRmnMrd69kFdbLMxWkTn1icZ7DCceRhvmb2SJXqDo4            95         2              0             0                 48   0.0480     0.4800         0.4320
# 10  J8hVkBNKobntWqLspa3yhXEkvb8vZ9S9NiHgirN9yvV3  Bs19Z9SokV1s46jutN9tqqaCgYf1GsVyyytVfkzwn9qK            73         1              0             0                 36   0.0360     0.3600         0.3240
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: GoonFi
# Total Attackers: 256, Showing Top 10
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                  attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1   FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1  EUcJwf7jXskRE6NZBtFPVH2EedNvNYko8LL2WT62XctB           125        20            833          3691                 72   2.3340     9.7680         7.4340
# 2    TAPNDP5dFr9Vp47DFuddRxNVYmjUqgh8boiUrWFgMqi  ChorusmmK7i1AxXeiTtQgQZhQNiXYU84ULeaYF1EH15n           188         0            548          3147                 94   1.9415     8.3300         6.3885
# 3   E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd           101         2            536          2283                 51   1.4605     6.1480         4.6875
# 4   AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3  BtsmiEEvnSuUnKxqXj2PZRYpPJAc7C34mGz8gtJ1DAaH            44         2             17            86                 23   0.0745     0.4360         0.3615
# 5   4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV  GiYSnFRrXrmkJMC54A1j3K4xT6ZMfx1NSThEe5X2WpDe            26         0             13            62                 13   0.0505     0.2800         0.2295
# 6   EJdrWPg32qHnmc3cwgGRfTrvWpQkDH2vHNGsane6WFGd  4SgoyAwN26iu9Gpf12Bk1rnzp4G4yDUM3XVv4w7VQcAf            87        11              0             0                 48   0.0480     0.4800         0.4320
# 7   J1CMrMaFHJmG97R7xJYrJxRA3MNt7VyHe8CAEUnsQzre  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd            82         2              0             0                 42   0.0420     0.4200         0.3780
# 8    YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP  2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX            68         4              0             0                 36   0.0360     0.3600         0.3240
# 9   3xb1APhYyenJhoq6Kpjetps9rsmS8kJAGhXVBHaDyWmL  GiYSnFRrXrmkJMC54A1j3K4xT6ZMfx1NSThEe5X2WpDe            70         1              0             0                 35   0.0350     0.3500         0.3150
# 10  GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC  43Am3PKFeo9cACpqYL5Sk95rpVdxLw3Mc22PqRqZXEW2            45         2              0             0                 23   0.0230     0.2300         0.2070
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: HumidiFi
# Total Attackers: 589, Showing Top 10
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                  attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1    YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP  22rU5yUmdVThrkoPieVNphqEyAtMQKmZxjwcD8v4bJDU          2888       160           5676         19190               1524  13.9570    64.9720        51.0150
# 2    YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy          1019        63           3532         10466                540   7.5390    33.3960        25.8570
# 3   CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP  HnfPZDrbJFooiP9vvgWrjx3baXVNAZCgisT58gyMCgML           592         6           1442          6955                299   4.4975    19.7840        15.2865
# 4   4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU           477         8           1192          5180                242   3.4280    15.1640        11.7360
# 5    YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj  5pPRHniefFjkiaArbGX3Y8NUysJmQ9tMZg3FrFGwHzSm           632        17           1196          3524                324   2.6840    12.6800         9.9960
# 6    TAPNDP5dFr9Vp47DFuddRxNVYmjUqgh8boiUrWFgMqi  Fd7btgySsrjuo25CJCj7oE7VPMyezDhnx7pZkj2v69Nk           173         0            359          1745                 86   1.1380     5.0680         3.9300
# 7   AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3  HnfPZDrbJFooiP9vvgWrjx3baXVNAZCgisT58gyMCgML           241         3            234          1353                121   0.9145     4.3840         3.4695
# 8   AEB9dXBoxkrapNd59Kg29JefMMf3M1WLcNA12XjKSf4R  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU           864         0              0             0                432   0.4320     4.3200         3.8880
# 9    enzog436vHy38bMhNR9XDENrvhxPK7y8wBQri852rhG  FNKgX9dYUhYQFRTM9bkeKoRpsyEtZGNMxbdQLDzfqB8a           578         2              0             0                290   0.2900     2.9000         2.6100
# 10  9TXFVx8N9dPneS3ETRt8KWtUXLRUsz6j6JM3bEXqkR3Z  ChorusmmK7i1AxXeiTtQgQZhQNiXYU84ULeaYF1EH15n           541         3              0             0                271   0.2710     2.7100         2.4390
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: ObricV2
# Total Attackers: 14, Showing Top 10
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                  attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1   A3vFkGBrj4MRugemEXWdSFztWgBXi9eQPtD3V28Va7WH  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF            10         0              0             0                  5   0.0050     0.0500         0.0450
# 2   5Y8qP9AavHyG69gTMbJP6v3Cj85VnDimdE1GZtfdV1WL  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF             8         0              0             0                  4   0.0040     0.0400         0.0360
# 3   ATQs6A92eUzdxTBsQhRJxxJDpgYDTGvLnU4e5mMEfY3k  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF             6         1              0             0                  3   0.0030     0.0300         0.0270
# 4   7LFYBv2FQDY6aw5hL5SBCW2PiHG8TmENxBnfUnCksRbs  9r2CsyjRTmTRtu8GFk5oJRSQr5YfSENxDkf3eox8iPLa             1         0              0             0                  0   0.0000     0.0000         0.0000
# 5   99WHBf1vR8XQtMsMKFU3JMh6ZihZSVSGDjVtyABbAM9J  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU             1         0              0             0                  0   0.0000     0.0000         0.0000
# 6   9XUWb3unwaGczFkEJAZiQd2xaZmm6NK68G775JEn2kaZ  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU             1         0              0             0                  0   0.0000     0.0000         0.0000
# 7   AgmLJBMDCqWynYnQiPCuj9ewsNNsBJXyzoUhD9LJzN51  722RdWmHC5TGXBjTejzNjbc8xEiduVDLqZvoUGz6Xzbp             1         0              0             0                  0   0.0000     0.0000         0.0000
# 8   FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1  BeaCHioStqCEFDFxKwAEzyrUPYxqnBPhJ98gDKeEiTPb             1         0              0             0                  0   0.0000     0.0000         0.0000
# 9   GBU3X8mgT7dVQ1XxEQxdUMuEJDzTL88bCZgDB8qQvq34  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU             1         0              0             0                  0   0.0000     0.0000         0.0000
# 10  J8hVkBNKobntWqLspa3yhXEkvb8vZ9S9NiHgirN9yvV3  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU             1         0              0             0                  0   0.0000     0.0000         0.0000
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: SolFi
# Total Attackers: 9, Showing Top 9
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                 attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2  6y7V8dL673XFzm9QyC5vvh3itWkp7wztahBd2yDqsyrK             0         0             58           252                  0   0.1550     0.6200         0.4650
# 2  CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP  Awes4Tr6TX8JDzEhCZY2QVNimT6iD1zWHzf1vNyGvpLM             1         0             21           122                  0   0.0715     0.2860         0.2145
# 3  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3  CAo1dCGYrB6NhHh5xb1cGjUiu86iyCfMTENxgHumSve4             0         1             17            86                  0   0.0515     0.2060         0.1545
# 4  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1  JD549HsbJHeEKKUrKgg4Fj2iyv2RGjsV7NTZjZUrHybB             0         0              1             4                  0   0.0025     0.0100         0.0075
# 5   k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq  GoeW4aFK4dGoekJySgUynWDxBZiQJqm8GDAF4H53tDK9             0         0              0             2                  0   0.0010     0.0040         0.0030
# 6  2n78p72RVYbyAiPtzZCNBYjMsEXKRiqfd5zArK8r2tgG  BtsmiEEvnSuUnKxqXj2PZRYpPJAc7C34mGz8gtJ1DAaH             1         0              0             0                  0   0.0000     0.0000         0.0000
# 7  888SGnyhGzqQuuWDVL48tn7xJsAEV259mK9V4YEcUn6f   forb5u56XgvzxiKfRt4FVNFQKJrd2LWAfNCsCqL6P7q             0         1              0             0                  0   0.0000     0.0000         0.0000
# 8  8oKVwqA5S2B7g2Li6yqZ4KKghpER8G1vj3bbeg8dFkSw  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU             1         0              0             0                  0   0.0000     0.0000         0.0000
# 9  GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU             0         1              0             0                  0   0.0000     0.0000         0.0000
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: SolFiV2
# Total Attackers: 171, Showing Top 10
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                  attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1   E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2  EvnRmnMrd69kFdbLMxWkTn1icZ7DCceRhvmb2SJXqDo4           395        11           1296          6429                202   4.0645    17.4700        13.4055
# 2   FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1  GSTampk6BJRKSDkzhaMM49R7qRx98MTPYYWvKbp83XKc           123        19           1078          5149                 70   3.1835    13.1540         9.9705
# 3   4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV  HLnodbYkL5PFA8hjAZDkm5pGzV7eLTvcs671AW2L6St9            18         0             97           565                  9   0.3400     1.4140         1.0740
# 4   GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy            95         8              0             0                 51   0.0510     0.5100         0.4590
# 5   FAzY5522HMCBk8hAwwPmDebLJphMETRwiQq2rXC2dtQw  EvnRmnMrd69kFdbLMxWkTn1icZ7DCceRhvmb2SJXqDo4            82         1              0             0                 41   0.0410     0.4100         0.3690
# 6   6gRnEaxAPr1hjtwCzrmSAztA4xbHCVNWJSRXh74sXFKJ  Cogent51kHgGLHr7zpkpRjGYFXM57LgjHjDdqXd4ypdA            78         3              0             0                 40   0.0400     0.4000         0.3600
# 7   7JJ4RrYC4wBb2ZangbVW4XbQenhEbkdoo7vhoWoShYjp  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy            78         1              0             0                 39   0.0390     0.3900         0.3510
# 8   4i3kFLZuutG5fvjg5wvq15n4NPpj12wXCRMyP7TcZbNj  A4hyMd3FyvUJSRafDUSwtLLaQcxRP4r1BRC9w2AJ1to2            69         5              0             0                 36   0.0360     0.3600         0.3240
# 9   8oKVwqA5S2B7g2Li6yqZ4KKghpER8G1vj3bbeg8dFkSw  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF            54         2              0             0                 28   0.0280     0.2800         0.2520
# 10  J1CMrMaFHJmG97R7xJYrJxRA3MNt7VyHe8CAEUnsQzre  9W3QTgBhkU4Bwg6cwnDJo6eGZ9BtZafSdu1Lo9JmWws7            39         2              0             0                 20   0.0200     0.2000         0.1800
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: TesseraV
# Total Attackers: 157, Showing Top 10
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                  attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1   AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3  Fd7btgySsrjuo25CJCj7oE7VPMyezDhnx7pZkj2v69Nk           126         2            899          4736                 64   2.8815    11.9100         9.0285
# 2    k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq  22rU5yUmdVThrkoPieVNphqEyAtMQKmZxjwcD8v4bJDU           348         9            928          3924                178   2.6040    11.4840         8.8800
# 3   E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF            35         1             77           434                 17   0.2725     1.1920         0.9195
# 4   FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1  6y7V8dL673XFzm9QyC5vvh3itWkp7wztahBd2yDqsyrK            25         0             59           283                 12   0.1830     0.8040         0.6210
# 5   4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV   PRGNnb8DxVcP2WjSHfVRGgc8SkA5u6dbMwoTVV1BGKN            14         0             16           134                  7   0.0820     0.3700         0.2880
# 6   2EZWAWuv9e4pgcxPZRMmEffDH8q45S573gu5pDRp72HT  9n1eEtJJfj1535NYfx524QcCG5aHbf5DH7ejqBrFLBwG           120         3              0             0                 61   0.0610     0.6100         0.5490
# 7   J8hVkBNKobntWqLspa3yhXEkvb8vZ9S9NiHgirN9yvV3  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy           117         5              0             0                 60   0.0600     0.6000         0.5400
# 8    YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP  G3a3iYZKNLbivothF3twqcaTCEvoPb9uJ2bFc9DNKkBQ            79         0              0             0                 39   0.0390     0.3900         0.3510
# 9    1989zAmZBwkwR6g8S3H8gkDhHRm3P11gpurN7faJqDu  Aw5wEMXhbygFLR7jHtHpih8QvxVBGAMTqsQ2SjWPk1ex            71         1              0             0                 35   0.0350     0.3500         0.3150
# 10  EJdrWPg32qHnmc3cwgGRfTrvWpQkDH2vHNGsane6WFGd  ChorusmmK7i1AxXeiTtQgQZhQNiXYU84ULeaYF1EH15n            59         2              0             0                 30   0.0300     0.3000         0.2700
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# pAMM: ZeroFi
# Total Attackers: 115, Showing Top 10
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#                                  attacker_signer                                     validator  fat_sandwich  sandwich  front_running  back_running  sandwich_complete cost_sol profit_sol net_profit_sol
# 1   E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd            62         1            313          1434                 31   0.9045     3.8040         2.8995
# 2   AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3  DWvDTSh3qfn88UoQTEKRV2JnLt5jtJAVoiCo3ivtMwXP            43         3            149           725                 22   0.4590     1.9680         1.5090
# 3    k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq  FBKFWadXZJahGtFitAsBvbqh5968gLY7dMBBJUoUjeNi            15         2             39           194                  8   0.1245     0.5460         0.4215
# 4   FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1   q9XWcZ7T1wP4bW9SB4XgNNwjnFEJ982nE8aVbbNuwot            11         0              4            53                  5   0.0335     0.1640         0.1305
# 5   8oKVwqA5S2B7g2Li6yqZ4KKghpER8G1vj3bbeg8dFkSw  DrifTrN923QaouP89UxkQzFGbumKPCnfkNYQRwmZxatz            39         1              0             0                 19   0.0190     0.1900         0.1710
# 6   FAzY5522HMCBk8hAwwPmDebLJphMETRwiQq2rXC2dtQw  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd            34         5              0             0                 19   0.0190     0.1900         0.1710
# 7    1989zAmZBwkwR6g8S3H8gkDhHRm3P11gpurN7faJqDu   shftkxnsXmqAkmLgz9Mn7bNB5Fr6mKgFc58kFHfVikj            32         2              0             0                 17   0.0170     0.1700         0.1530
# 8   GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC  2Mob8FJkb8chZY5pTBMpKfLwgZAQHE5i9jAC5zbASitD            30         0              0             0                 15   0.0150     0.1500         0.1350
# 9    o721S2ZPSjJTEC9B5HgXdqZFPVq1avjKzRfZpTKjV9g  2Mob8FJkb8chZY5pTBMpKfLwgZAQHE5i9jAC5zbASitD            28         1              0             0                 14   0.0140     0.1400         0.1260
# 10  6gRnEaxAPr1hjtwCzrmSAztA4xbHCVNWJSRXh74sXFKJ  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd            28         0              0             0                 14   0.0140     0.1400         0.1260
# ✓ Per pAMM Top 10 MEV stats (top 10 per pAMM) saved to: per_pamm_top10_mev_with_validator.csv
#
# ====================================================================================================
# Full Per pAMM Top 10 MEV Table (All pAMMs Combined)
# ====================================================================================================
#    amm_trade                               attacker_signer  back_running  fat_sandwich  front_running  sandwich                                     validator  sandwich_complete  cost_sol  profit_sol  net_profit_sol confidence
# 0    BisonFi   YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP          4075           456           1053         7  CiR8HNCfkjtcongPmP2DRdZPnFgjSbN5gsXdjmsXXHcB                231    2.7950      12.566          9.7710       high
# 1    BisonFi  4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV          1148           127            208         2  9n1eEtJJfj1535NYfx524QcCG5aHbf5DH7ejqBrFLBwG                 64    0.7420       3.352          2.6100       high
# 2    BisonFi  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3           875            63            148         0  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                 31    0.5425       2.356          1.8135       high
# 3    BisonFi  CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP           649            91            117         1  9n1eEtJJfj1535NYfx524QcCG5aHbf5DH7ejqBrFLBwG                 45    0.4280       1.982          1.5540       high
# 4    BisonFi  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1           238            24             45         0  ArMBx6veRq33ffEP9sxHafiPRgrtzww4XvbwZbSMfXiM                 12    0.1535       0.686          0.5325       high
# 5    BisonFi  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2           194            33             48         1  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF                 16    0.1370       0.644          0.5070       high
# 6    BisonFi  C2bK8HFrL71aLnpyExVoJmqjDPA9tbLMXcBNAkRQnLfQ             0           181              0         5  5pPRHniefFjkiaArbGX3Y8NUysJmQ9tMZg3FrFGwHzSm                 92    0.0920       0.920          0.8280       high
# 7    BisonFi   foxMFk9faHggM4HWQWETCPSDvMbWx8LSv4c9CrkmBx6             0           110              0         0  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF                 55    0.0550       0.550          0.4950       high
# 8    BisonFi  DkV8QZdg5GH7Bb5NteLJVYCF2mwBSCFt7AcTnmVvTfeW             0            95              0         2  EvnRmnMrd69kFdbLMxWkTn1icZ7DCceRhvmb2SJXqDo4                 48    0.0480       0.480          0.4320       high
# 9    BisonFi  J8hVkBNKobntWqLspa3yhXEkvb8vZ9S9NiHgirN9yvV3             0            73              0         1  Bs19Z9SokV1s46jutN9tqqaCgYf1GsVyyytVfkzwn9qK                 36    0.0360       0.360          0.3240       high
# 10    GoonFi  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1          3691           125            833        20  EUcJwf7jXskRE6NZBtFPVH2EedNvNYko8LL2WT62XctB                 72    2.3340       9.768          7.4340       high
# 11    GoonFi   TAPNDP5dFr9Vp47DFuddRxNVYmjUqgh8boiUrWFgMqi          3147           188            548         0  ChorusmmK7i1AxXeiTtQgQZhQNiXYU84ULeaYF1EH15n                 94    1.9415       8.330          6.3885       high
# 12    GoonFi  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2          2283           101            536         2  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd                 51    1.4605       6.148          4.6875       high
# 13    GoonFi  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3            86            44             17         2  BtsmiEEvnSuUnKxqXj2PZRYpPJAc7C34mGz8gtJ1DAaH                 23    0.0745       0.436          0.3615       high
# 14    GoonFi  4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV            62            26             13         0  GiYSnFRrXrmkJMC54A1j3K4xT6ZMfx1NSThEe5X2WpDe                 13    0.0505       0.280          0.2295       high
# 15    GoonFi  EJdrWPg32qHnmc3cwgGRfTrvWpQkDH2vHNGsane6WFGd             0            87              0        11  4SgoyAwN26iu9Gpf12Bk1rnzp4G4yDUM3XVv4w7VQcAf                 48    0.0480       0.480          0.4320       high
# 16    GoonFi  J1CMrMaFHJmG97R7xJYrJxRA3MNt7VyHe8CAEUnsQzre             0            82              0         2  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd                 42    0.0420       0.420          0.3780       high
# 17    GoonFi   YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP             0            68              0         4  2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX                 36    0.0360       0.360          0.3240       high
# 18    GoonFi  3xb1APhYyenJhoq6Kpjetps9rsmS8kJAGhXVBHaDyWmL             0            70              0         1  GiYSnFRrXrmkJMC54A1j3K4xT6ZMfx1NSThEe5X2WpDe                 35    0.0350       0.350          0.3150       high
# 19    GoonFi  GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC             0            45              0         2  43Am3PKFeo9cACpqYL5Sk95rpVdxLw3Mc22PqRqZXEW2                 23    0.0230       0.230          0.2070       high
# 20  HumidiFi   YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP         19190          2888           5676       160  22rU5yUmdVThrkoPieVNphqEyAtMQKmZxjwcD8v4bJDU               1524   13.9570      64.972         51.0150       high
# 21  HumidiFi   YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW         10466          1019           3532        63  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy                540    7.5390      33.396         25.8570       high
# 22  HumidiFi  CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP          6955           592           1442         6  HnfPZDrbJFooiP9vvgWrjx3baXVNAZCgisT58gyMCgML                299    4.4975      19.784         15.2865       high
# 23  HumidiFi  4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV          5180           477           1192         8  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                242    3.4280      15.164         11.7360       high
# 24  HumidiFi   YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj          3524           632           1196        17  5pPRHniefFjkiaArbGX3Y8NUysJmQ9tMZg3FrFGwHzSm                324    2.6840      12.680          9.9960       high
# 25  HumidiFi   TAPNDP5dFr9Vp47DFuddRxNVYmjUqgh8boiUrWFgMqi          1745           173            359         0  Fd7btgySsrjuo25CJCj7oE7VPMyezDhnx7pZkj2v69Nk                 86    1.1380       5.068          3.9300       high
# 26  HumidiFi  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3          1353           241            234         3  HnfPZDrbJFooiP9vvgWrjx3baXVNAZCgisT58gyMCgML                121    0.9145       4.384          3.4695       high
# 27  HumidiFi  AEB9dXBoxkrapNd59Kg29JefMMf3M1WLcNA12XjKSf4R             0           864              0         0  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                432    0.4320       4.320          3.8880       high
# 28  HumidiFi   enzog436vHy38bMhNR9XDENrvhxPK7y8wBQri852rhG             0           578              0         2  FNKgX9dYUhYQFRTM9bkeKoRpsyEtZGNMxbdQLDzfqB8a                290    0.2900       2.900          2.6100       high
# 29  HumidiFi  9TXFVx8N9dPneS3ETRt8KWtUXLRUsz6j6JM3bEXqkR3Z             0           541              0         3  ChorusmmK7i1AxXeiTtQgQZhQNiXYU84ULeaYF1EH15n                271    0.2710       2.710          2.4390       high
# 30   ObricV2  A3vFkGBrj4MRugemEXWdSFztWgBXi9eQPtD3V28Va7WH             0            10              0         0  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF                  5    0.0050       0.050          0.0450       high
# 31   ObricV2  5Y8qP9AavHyG69gTMbJP6v3Cj85VnDimdE1GZtfdV1WL             0             8              0         0  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF                  4    0.0040       0.040          0.0360       high
# 32   ObricV2  ATQs6A92eUzdxTBsQhRJxxJDpgYDTGvLnU4e5mMEfY3k             0             6              0         1  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF                  3    0.0030       0.030          0.0270       high
# 33   ObricV2  7LFYBv2FQDY6aw5hL5SBCW2PiHG8TmENxBnfUnCksRbs             0             1              0         0  9r2CsyjRTmTRtu8GFk5oJRSQr5YfSENxDkf3eox8iPLa                  0    0.0000       0.000          0.0000     medium
# 34   ObricV2  99WHBf1vR8XQtMsMKFU3JMh6ZihZSVSGDjVtyABbAM9J             0             1              0         0  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                  0    0.0000       0.000          0.0000       high
# 35   ObricV2  9XUWb3unwaGczFkEJAZiQd2xaZmm6NK68G775JEn2kaZ             0             1              0         0  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                  0    0.0000       0.000          0.0000     medium
# 36   ObricV2  AgmLJBMDCqWynYnQiPCuj9ewsNNsBJXyzoUhD9LJzN51             0             1              0         0  722RdWmHC5TGXBjTejzNjbc8xEiduVDLqZvoUGz6Xzbp                  0    0.0000       0.000          0.0000       high
# 37   ObricV2  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1             0             1              0         0  BeaCHioStqCEFDFxKwAEzyrUPYxqnBPhJ98gDKeEiTPb                  0    0.0000       0.000          0.0000     medium
# 38   ObricV2  GBU3X8mgT7dVQ1XxEQxdUMuEJDzTL88bCZgDB8qQvq34             0             1              0         0  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                  0    0.0000       0.000          0.0000     medium
# 39   ObricV2  J8hVkBNKobntWqLspa3yhXEkvb8vZ9S9NiHgirN9yvV3             0             1              0         0  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                  0    0.0000       0.000          0.0000     medium
# 40     SolFi  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2           252             0             58         0  6y7V8dL673XFzm9QyC5vvh3itWkp7wztahBd2yDqsyrK                  0    0.1550       0.620          0.4650        NaN
# 41     SolFi  CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP           122             1             21         0  Awes4Tr6TX8JDzEhCZY2QVNimT6iD1zWHzf1vNyGvpLM                  0    0.0715       0.286          0.2145       high
# 42     SolFi  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3            86             0             17         1  CAo1dCGYrB6NhHh5xb1cGjUiu86iyCfMTENxgHumSve4                  0    0.0515       0.206          0.1545     medium
# 43     SolFi  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1             4             0              1         0  JD549HsbJHeEKKUrKgg4Fj2iyv2RGjsV7NTZjZUrHybB                  0    0.0025       0.010          0.0075        NaN
# 44     SolFi   k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq             2             0              0         0  GoeW4aFK4dGoekJySgUynWDxBZiQJqm8GDAF4H53tDK9                  0    0.0010       0.004          0.0030        NaN
# 45     SolFi  2n78p72RVYbyAiPtzZCNBYjMsEXKRiqfd5zArK8r2tgG             0             1              0         0  BtsmiEEvnSuUnKxqXj2PZRYpPJAc7C34mGz8gtJ1DAaH                  0    0.0000       0.000          0.0000     medium
# 46     SolFi  888SGnyhGzqQuuWDVL48tn7xJsAEV259mK9V4YEcUn6f             0             0              0         1   forb5u56XgvzxiKfRt4FVNFQKJrd2LWAfNCsCqL6P7q                  0    0.0000       0.000          0.0000     medium
# 47     SolFi  8oKVwqA5S2B7g2Li6yqZ4KKghpER8G1vj3bbeg8dFkSw             0             1              0         0  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                  0    0.0000       0.000          0.0000     medium
# 48     SolFi  GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC             0             0              0         1  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU                  0    0.0000       0.000          0.0000     medium
# 49   SolFiV2  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2          6429           395           1296        11  EvnRmnMrd69kFdbLMxWkTn1icZ7DCceRhvmb2SJXqDo4                202    4.0645      17.470         13.4055       high
# 50   SolFiV2  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1          5149           123           1078        19  GSTampk6BJRKSDkzhaMM49R7qRx98MTPYYWvKbp83XKc                 70    3.1835      13.154          9.9705       high
# 51   SolFiV2  4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV           565            18             97         0  HLnodbYkL5PFA8hjAZDkm5pGzV7eLTvcs671AW2L6St9                  9    0.3400       1.414          1.0740       high
# 52   SolFiV2  GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC             0            95              0         8  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy                 51    0.0510       0.510          0.4590       high
# 53   SolFiV2  FAzY5522HMCBk8hAwwPmDebLJphMETRwiQq2rXC2dtQw             0            82              0         1  EvnRmnMrd69kFdbLMxWkTn1icZ7DCceRhvmb2SJXqDo4                 41    0.0410       0.410          0.3690       high
# 54   SolFiV2  6gRnEaxAPr1hjtwCzrmSAztA4xbHCVNWJSRXh74sXFKJ             0            78              0         3  Cogent51kHgGLHr7zpkpRjGYFXM57LgjHjDdqXd4ypdA                 40    0.0400       0.400          0.3600       high
# 55   SolFiV2  7JJ4RrYC4wBb2ZangbVW4XbQenhEbkdoo7vhoWoShYjp             0            78              0         1  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy                 39    0.0390       0.390          0.3510       high
# 56   SolFiV2  4i3kFLZuutG5fvjg5wvq15n4NPpj12wXCRMyP7TcZbNj             0            69              0         5  A4hyMd3FyvUJSRafDUSwtLLaQcxRP4r1BRC9w2AJ1to2                 36    0.0360       0.360          0.3240       high
# 57   SolFiV2  8oKVwqA5S2B7g2Li6yqZ4KKghpER8G1vj3bbeg8dFkSw             0            54              0         2  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF                 28    0.0280       0.280          0.2520       high
# 58   SolFiV2  J1CMrMaFHJmG97R7xJYrJxRA3MNt7VyHe8CAEUnsQzre             0            39              0         2  9W3QTgBhkU4Bwg6cwnDJo6eGZ9BtZafSdu1Lo9JmWws7                 20    0.0200       0.200          0.1800       high
# 59  TesseraV  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3          4736           126            899         2  Fd7btgySsrjuo25CJCj7oE7VPMyezDhnx7pZkj2v69Nk                 64    2.8815      11.910          9.0285       high
# 60  TesseraV   k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq          3924           348            928         9  22rU5yUmdVThrkoPieVNphqEyAtMQKmZxjwcD8v4bJDU                178    2.6040      11.484          8.8800       high
# 61  TesseraV  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2           434            35             77         1  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF                 17    0.2725       1.192          0.9195       high
# 62  TesseraV  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1           283            25             59         0  6y7V8dL673XFzm9QyC5vvh3itWkp7wztahBd2yDqsyrK                 12    0.1830       0.804          0.6210       high
# 63  TesseraV  4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV           134            14             16         0   PRGNnb8DxVcP2WjSHfVRGgc8SkA5u6dbMwoTVV1BGKN                  7    0.0820       0.370          0.2880       high
# 64  TesseraV  2EZWAWuv9e4pgcxPZRMmEffDH8q45S573gu5pDRp72HT             0           120              0         3  9n1eEtJJfj1535NYfx524QcCG5aHbf5DH7ejqBrFLBwG                 61    0.0610       0.610          0.5490       high
# 65  TesseraV  J8hVkBNKobntWqLspa3yhXEkvb8vZ9S9NiHgirN9yvV3             0           117              0         5  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy                 60    0.0600       0.600          0.5400       high
# 66  TesseraV   YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP             0            79              0         0  G3a3iYZKNLbivothF3twqcaTCEvoPb9uJ2bFc9DNKkBQ                 39    0.0390       0.390          0.3510       high
# 67  TesseraV   1989zAmZBwkwR6g8S3H8gkDhHRm3P11gpurN7faJqDu             0            71              0         1  Aw5wEMXhbygFLR7jHtHpih8QvxVBGAMTqsQ2SjWPk1ex                 35    0.0350       0.350          0.3150       high
# 68  TesseraV  EJdrWPg32qHnmc3cwgGRfTrvWpQkDH2vHNGsane6WFGd             0            59              0         2  ChorusmmK7i1AxXeiTtQgQZhQNiXYU84ULeaYF1EH15n                 30    0.0300       0.300          0.2700       high
# 69    ZeroFi  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2          1434            62            313         1  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd                 31    0.9045       3.804          2.8995       high
# 70    ZeroFi  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3           725            43            149         3  DWvDTSh3qfn88UoQTEKRV2JnLt5jtJAVoiCo3ivtMwXP                 22    0.4590       1.968          1.5090       high
# 71    ZeroFi   k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq           194            15             39         2  FBKFWadXZJahGtFitAsBvbqh5968gLY7dMBBJUoUjeNi                  8    0.1245       0.546          0.4215       high
# 72    ZeroFi  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1            53            11              4         0   q9XWcZ7T1wP4bW9SB4XgNNwjnFEJ982nE8aVbbNuwot                  5    0.0335       0.164          0.1305       high
# 73    ZeroFi  8oKVwqA5S2B7g2Li6yqZ4KKghpER8G1vj3bbeg8dFkSw             0            39              0         1  DrifTrN923QaouP89UxkQzFGbumKPCnfkNYQRwmZxatz                 19    0.0190       0.190          0.1710       high
# 74    ZeroFi  FAzY5522HMCBk8hAwwPmDebLJphMETRwiQq2rXC2dtQw             0            34              0         5  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd                 19    0.0190       0.190          0.1710       high
# 75    ZeroFi   1989zAmZBwkwR6g8S3H8gkDhHRm3P11gpurN7faJqDu             0            32              0         2   shftkxnsXmqAkmLgz9Mn7bNB5Fr6mKgFc58kFHfVikj                 17    0.0170       0.170          0.1530       high
# 76    ZeroFi  GraZ9wjJVEGMQsyz3BwkkRdkJFmDrZw6Bnj3yzciwFEC             0            30              0         0  2Mob8FJkb8chZY5pTBMpKfLwgZAQHE5i9jAC5zbASitD                 15    0.0150       0.150          0.1350       high
# 77    ZeroFi   o721S2ZPSjJTEC9B5HgXdqZFPVq1avjKzRfZpTKjV9g             0            28              0         1  2Mob8FJkb8chZY5pTBMpKfLwgZAQHE5i9jAC5zbASitD                 14    0.0140       0.140          0.1260       high
# 78    ZeroFi  6gRnEaxAPr1hjtwCzrmSAztA4xbHCVNWJSRXh74sXFKJ             0            28              0         0  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd                 14    0.0140       0.140          0.1260       high

# %%
# ───────────────────────────────────────────────
# Cell 3: Trades and Bots Group by Validator
# ───────────────────────────────────────────────
print("\n" + "="*100)
print("Trades and Bots Group by Validator")
print("="*100 + "\n")

if not all_mev.empty:
    trades_per_validator = trades.groupby('validator').size().reset_index(name='trade_count')
    
    bots_per_validator = all_mev.groupby('validator')['attacker_signer'].nunique().reset_index(name='bot_count')
    
    mev_types_per_validator = all_mev.groupby('validator')['type'].value_counts().unstack(fill_value=0)
    
    validator_stats = pd.merge(trades_per_validator, bots_per_validator, on='validator', how='outer').fillna(0)
    validator_stats = pd.merge(validator_stats, mev_types_per_validator, on='validator', how='left').fillna(0)
    
    validator_stats['bot_ratio_%'] = (validator_stats['bot_count'] / validator_stats['trade_count'] * 100).round(2)
    
    validator_stats = validator_stats.sort_values('bot_count', ascending=False)
    
    # Safe output columns
    output_cols = ['validator', 'trade_count', 'bot_count', 'bot_ratio_%']
    mev_types = ['fat_sandwich', 'sandwich', 'front_running', 'back_running']
    for col in mev_types:
        if col in validator_stats.columns:
            output_cols.append(col)
    
    # Show Top 10 Validators
    print("Top 10 Validators by Bot Count:")
    print("-" * 100)
    top10_validator_stats = validator_stats.head(10)
    print(top10_validator_stats[output_cols].to_string(index=False, float_format=lambda x: f'{x:.2f}' if isinstance(x, float) else x))
    print()
    
    # Also display using display() for better viewing in Jupyter
    print("\n" + "="*100)
    print("Top 10 Validators Table (Formatted)")
    print("="*100)
    display(top10_validator_stats[output_cols])
    
    # Save full table
    validator_stats.to_csv('mev_trades_bots_per_validator.csv', index=False)
    print(f"\n✓ Full Trades and Bots grouped by validator saved to: mev_trades_bots_per_validator.csv")
    print(f"✓ Total validators: {len(validator_stats)}")
    
    # Also show full table using display() if user wants to see all
    print("\n" + "="*100)
    print("Full Validator Stats Table (All Validators)")
    print("="*100)
    display(validator_stats[output_cols])
else:
    print("No MEV data available for validator analysis.")
# Out:
# ====================================================================================================
# Trades and Bots Group by Validator
# ====================================================================================================
#
# Top 10 Validators by Bot Count:
# ----------------------------------------------------------------------------------------------------
#                                    validator  trade_count  bot_count  bot_ratio_%  fat_sandwich  sandwich  front_running  back_running
# HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU        28859     152.00         0.53       1234.00     27.00         685.00       3810.00
# DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy        24370     130.00         0.53        948.00     18.00         529.00       3220.00
# Fd7btgySsrjuo25CJCj7oE7VPMyezDhnx7pZkj2v69Nk        18847     110.00         0.58        613.00     15.00         471.00       1971.00
# 5pPRHniefFjkiaArbGX3Y8NUysJmQ9tMZg3FrFGwHzSm        15719     107.00         0.68        598.00     11.00         909.00       2119.00
# 9jxgosAfHgHzwnxsHw4RAZYaLVokMbnYtmiZBreynGFP        10616     105.00         0.99        505.00     11.00         227.00       1612.00
#  q9XWcZ7T1wP4bW9SB4XgNNwjnFEJ982nE8aVbbNuwot        14358     103.00         0.72        519.00     10.00         336.00       2081.00
# DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF        14189      99.00         0.70        561.00      9.00        1367.00       1691.00
# JD549HsbJHeEKKUrKgg4Fj2iyv2RGjsV7NTZjZUrHybB        13022      96.00         0.74        472.00     10.00        1300.00       1555.00
# CAo1dCGYrB6NhHh5xb1cGjUiu86iyCfMTENxgHumSve4         9620      89.00         0.93        441.00     10.00         252.00       1390.00
# 9rkJMARqK6VBkcxGfKBAwnA44gPAfGxPbPsfsggFNDSQ         8468      86.00         1.02        339.00     10.00         209.00       1200.00
#
#
# ====================================================================================================
# Top 10 Validators Table (Formatted)
# ====================================================================================================
#                                         validator  trade_count  bot_count  bot_ratio_%  fat_sandwich  sandwich  front_running  back_running
# 486  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU        28859      152.0         0.53        1234.0      27.0          685.0        3810.0
# 370  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy        24370      130.0         0.53         948.0      18.0          529.0        3220.0
# 443  Fd7btgySsrjuo25CJCj7oE7VPMyezDhnx7pZkj2v69Nk        18847      110.0         0.58         613.0      15.0          471.0        1971.0
# 120  5pPRHniefFjkiaArbGX3Y8NUysJmQ9tMZg3FrFGwHzSm        15719      107.0         0.68         598.0      11.0          909.0        2119.0
# 229  9jxgosAfHgHzwnxsHw4RAZYaLVokMbnYtmiZBreynGFP        10616      105.0         0.99         505.0      11.0          227.0        1612.0
# 697   q9XWcZ7T1wP4bW9SB4XgNNwjnFEJ982nE8aVbbNuwot        14358      103.0         0.72         519.0      10.0          336.0        2081.0
# 388  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF        14189       99.0         0.70         561.0       9.0         1367.0        1691.0
# 514  JD549HsbJHeEKKUrKgg4Fj2iyv2RGjsV7NTZjZUrHybB        13022       96.0         0.74         472.0      10.0         1300.0        1555.0
# 318  CAo1dCGYrB6NhHh5xb1cGjUiu86iyCfMTENxgHumSve4         9620       89.0         0.93         441.0      10.0          252.0        1390.0
# 236  9rkJMARqK6VBkcxGfKBAwnA44gPAfGxPbPsfsggFNDSQ         8468       86.0         1.02         339.0      10.0          209.0        1200.0
# ✓ Full Trades and Bots grouped by validator saved to: mev_trades_bots_per_validator.csv
# ✓ Total validators: 742
#
# ====================================================================================================
# Full Validator Stats Table (All Validators)
# ====================================================================================================
#                                         validator  trade_count  bot_count  bot_ratio_%  fat_sandwich  sandwich  front_running  back_running
# 486  HEL1USMZKAL2odpNBj2oCjffnFGaYwmbGmyewGv1e2TU        28859      152.0         0.53        1234.0      27.0          685.0        3810.0
# 370  DRpbCBMxVnDK7maPM5tGv6MvB3v1sRMC86PZ8okm21hy        24370      130.0         0.53         948.0      18.0          529.0        3220.0
# 443  Fd7btgySsrjuo25CJCj7oE7VPMyezDhnx7pZkj2v69Nk        18847      110.0         0.58         613.0      15.0          471.0        1971.0
# 120  5pPRHniefFjkiaArbGX3Y8NUysJmQ9tMZg3FrFGwHzSm        15719      107.0         0.68         598.0      11.0          909.0        2119.0
# 229  9jxgosAfHgHzwnxsHw4RAZYaLVokMbnYtmiZBreynGFP        10616      105.0         0.99         505.0      11.0          227.0        1612.0
# 697   q9XWcZ7T1wP4bW9SB4XgNNwjnFEJ982nE8aVbbNuwot        14358      103.0         0.72         519.0      10.0          336.0        2081.0
# 388  DtdSSG8ZJRZVv5Jx7K1MeWp7Zxcu19GD5wQRGRpQ9uMF        14189       99.0         0.70         561.0       9.0         1367.0        1691.0
# 514  JD549HsbJHeEKKUrKgg4Fj2iyv2RGjsV7NTZjZUrHybB        13022       96.0         0.74         472.0      10.0         1300.0        1555.0
# 318  CAo1dCGYrB6NhHh5xb1cGjUiu86iyCfMTENxgHumSve4         9620       89.0         0.93         441.0      10.0          252.0        1390.0
# 236  9rkJMARqK6VBkcxGfKBAwnA44gPAfGxPbPsfsggFNDSQ         8468       86.0         1.02         339.0      10.0          209.0        1200.0
# 718   shftkxnsXmqAkmLgz9Mn7bNB5Fr6mKgFc58kFHfVikj         6579       86.0         1.31         303.0       3.0          133.0         890.0
# 389  E1r4Psq84tHfQ6aPTvvDka4U3u8zPVD7gEUrH25RdxHL         8879       86.0         0.97         379.0      11.0          202.0        1176.0
# 510  Hz5aLvpKScNWoe9YZWxBLrQA3qzHJivBGtfciMekk8m5         6335       86.0         1.36         255.0       5.0          129.0         839.0
# 367  DNVZMSqeRH18Xa4MCTrb1MndNf3Npg4MEwqswo23eWkf         6507       82.0         1.26         254.0       5.0          181.0         959.0
# 420  EvnRmnMrd69kFdbLMxWkTn1icZ7DCceRhvmb2SJXqDo4         9818       82.0         0.84         329.0       9.0          387.0        1085.0
# 338  ChorusmmK7i1AxXeiTtQgQZhQNiXYU84ULeaYF1EH15n         8961       81.0         0.90         341.0       4.0          575.0        1198.0
# 515   JupmVLmA8RoyTUbTMMuTtoPWHEiNQobxgTeGTrPNkzT        13085       81.0         0.62         376.0      24.0          358.0        1693.0
# 417  EkvdKhULbMFqjKBKotAzGi3kwMvMpYNDKJXXQQmi6C1f         6746       81.0         1.20         275.0       6.0          143.0        1014.0
# 309  BtsmiEEvnSuUnKxqXj2PZRYpPJAc7C34mGz8gtJ1DAaH         6908       79.0         1.14         309.0       5.0          177.0        1002.0
# 219  9UM8wQ8F5oMiRcP5YdqD6Lr4krpBWCD8LtgQYoisJd9i         8279       78.0         0.94         304.0       4.0          196.0        1114.0
# 7    22rU5yUmdVThrkoPieVNphqEyAtMQKmZxjwcD8v4bJDU         3978       78.0         1.96         172.0       1.0           89.0         500.0
# 306  BkoS26vBuaXnSowACdChi4WKid8UwmuPNhEJWa8KsLHd         7316       77.0         1.05         277.0       7.0          185.0        1056.0
# 278  Awes4Tr6TX8JDzEhCZY2QVNimT6iD1zWHzf1vNyGvpLM        10272       75.0         0.73         280.0      11.0          166.0        1383.0
# 376  DWvDTSh3qfn88UoQTEKRV2JnLt5jtJAVoiCo3ivtMwXP         6312       74.0         1.17         236.0       5.0          288.0         776.0
# 110  5ZqveVffQPiUbkjBg4KD9kib1MKHLqiFno4ke9jSq9qk         6863       73.0         1.06         237.0       7.0          145.0         955.0
# 321  CG4tRANBKrzUmpv93V5sgftjQznBdiJsc2yPCzZWWuS9         4047       71.0         1.75         180.0       4.0          185.0         503.0
# 512  J6etcxDdYjPHrtyvDXrbCkx3q9W1UjMj1vy1jBFPJEbK         6871       71.0         1.03         223.0       2.0          326.0         868.0
# 479  GoeW4aFK4dGoekJySgUynWDxBZiQJqm8GDAF4H53tDK9         6191       70.0         1.13         195.0       9.0          179.0         863.0
# 658   krakeNd6ednDPEXxHAmoBs1qKVM8kLg79PvWF2mhXV1         4826       70.0         1.45         205.0       4.0          106.0         682.0
# 276  Aw5wEMXhbygFLR7jHtHpih8QvxVBGAMTqsQ2SjWPk1ex         4822       70.0         1.45         185.0       2.0          108.0         580.0
# 238  A1vqhA2fS6K7CvHsJKX1ACcHJFEmyRg4KuR5pctHANy4         6051       68.0         1.12         254.0       8.0          131.0         816.0
# 386  DrifTrN923QaouP89UxkQzFGbumKPCnfkNYQRwmZxatz         3813       66.0         1.73         189.0       3.0          142.0         470.0
# 231  9n1eEtJJfj1535NYfx524QcCG5aHbf5DH7ejqBrFLBwG         3381       65.0         1.92         145.0       2.0           79.0         489.0
# 156  76rcGHdPvgs8G1XrzCXUTWtwgT59AFDvpB4VbTS2TBBJ         3720       63.0         1.69         138.0       3.0           77.0         455.0
# 203  8uJiHDJ1b7UDQ4KFsQGJXK9nUCkokdKRJymg1Wy9nxvM         2134       63.0         2.95         103.0       3.0           43.0         293.0
# 472  GSTampk6BJRKSDkzhaMM49R7qRx98MTPYYWvKbp83XKc         4212       62.0         1.47         139.0      10.0           92.0         563.0
# 292  BSVckjdW2f8kcXPGcrPPtV9kUDBZ8w8PjrrGVnxgEdwq         4471       62.0         1.39         156.0       6.0           99.0         584.0
# 222  9W3QTgBhkU4Bwg6cwnDJo6eGZ9BtZafSdu1Lo9JmWws7         5669       61.0         1.08         202.0       7.0          170.0         869.0
# 427  FBKFWadXZJahGtFitAsBvbqh5968gLY7dMBBJUoUjeNi         5348       61.0         1.14         154.0       3.0           67.0         568.0
# 294  BUv44cVtsdvU9z2BfFGk6s5JZZWrmVnq5qCaii5ARyyB         3315       60.0         1.81         147.0       4.0           75.0         437.0
# 150  6y7V8dL673XFzm9QyC5vvh3itWkp7wztahBd2yDqsyrK         5006       60.0         1.20         189.0       4.0          127.0         740.0
# 181  7y5VhV4fkz6r4zUmH2UiwPjLwXzPL1PcV28or5NWkWRL         2756       59.0         2.14         111.0       2.0          103.0         335.0
# 113  5ejbTALcBsKQ7Cj1iSuu2mY5jqbYHqh9gF5ERXLiYj1z         4704       59.0         1.25         175.0       8.0          105.0         678.0
# 504  HpcB5Qg8Y9E73dUkot5e8HkgAJbExsYeUzniY4bCuKac         4304       59.0         1.37         162.0       5.0           86.0         538.0
# 498  HbidP4hpQdwhkzrxder3x3VNPt6DQnE25gFG46napD2p         3386       58.0         1.71         123.0       7.0           61.0         386.0
# 373  DTSUkYHd2e9P2HLyZfbLarsbDdPhQUhZnWjRYuJZQRC8         2840       57.0         2.01         116.0       1.0          262.0         357.0
# 609   ana2y2YvQ3ZPMwm6qhnN3nJoUSiT3qx5Pvetkq9xcfY         2893       56.0         1.94         113.0       1.0          129.0         378.0
# 433  FNKgX9dYUhYQFRTM9bkeKoRpsyEtZGNMxbdQLDzfqB8a         3326       55.0         1.65         138.0       2.0          298.0         408.0
# 51   3JotfSFPaod4KVK7nj7ULvcq5PjUBdZNVGracNkJNhrt         3056       55.0         1.80         127.0       2.0           70.0         386.0
# 153  722RdWmHC5TGXBjTejzNjbc8xEiduVDLqZvoUGz6Xzbp         2726       55.0         2.02         109.0       5.0           60.0         352.0
# 331  CW9C7HBwAMgqNdXkNgFg9Ujr3edR2Ab9ymEuQnVacd1A         3213       54.0         1.68         146.0       0.0          264.0         337.0
# 460  G3a3iYZKNLbivothF3twqcaTCEvoPb9uJ2bFc9DNKkBQ         2945       53.0         1.80         123.0       1.0           49.0         399.0
# 105  5TGfVQV1S3wHE9hkgGaQkRoPC7xZxiqwMcjQZxVYsf1j         1870       52.0         2.78          88.0       1.0           49.0         264.0
# 439  FZ4MT1HYJHd9GK8D5mJ9f3r7irLaDL5NxBNLjGqrLqs9         2834       50.0         1.76          93.0       1.0          129.0         385.0
# 255  AWcCdYG7Dy6GX45c6QMPbgGwgRZPKcBDT4bXGb3QrVRV         3798       50.0         1.32         131.0       1.0           76.0         454.0
# 441  FbYX2uN573G5WsgiPdHU6fS5PNUyjdXfGfpZNkYUuT4k         3575       50.0         1.40         125.0       1.0           79.0         539.0
# 96   5EhGYUyQNrxgUbuYF4vbL2SZDT6RMfhq3yjeyevvULeC         3922       49.0         1.25          92.0       8.0          111.0         503.0
# 469  GQzMeEMwAR44ugoNCifTb5NdRKos1GduDUPeNh6AgV46         3421       49.0         1.43          95.0       6.0           97.0         525.0
# 378  DZVqmD4QqSWM2gUyEXdQhvt4u3NZtCRxdsn2n2nNiBRL         2532       48.0         1.90         109.0       1.0           58.0         297.0
# 57   3SkE34PVeGck2ArEffFKjihrQgURsvnoTAhitsNXNzXd         4019       48.0         1.19         151.0       2.0           81.0         571.0
# 693   privaEdSEmnMPGPoQACUkcDGkFBbTArVvsEGd7C5wUM         2403       48.0         2.00          94.0       1.0           75.0         356.0
# 34   2m1A2WM1vte7RWz5xTTw4i1SiXmngVtXhqFERaUjoAAb         2378       47.0         1.98          78.0       0.0          191.0         253.0
# 202  8tjFeSApQ85ThoQXT28acfF2KUfQr3TvTdirSkzNnYC7         1871       47.0         2.51          72.0       2.0           34.0         234.0
# 137  6WgdYhhGE53WrZ7ywJA15hBVkw7CRbQ8yDBBTwmBtAHN         2377       47.0         1.98          92.0       1.0           46.0         316.0
# 323  CMPSSdrTnRQBiBGTyFpdCc3VMNuLWYWaSkE8Zh5z6gbd         2216       47.0         2.12          91.0       2.0           45.0         282.0
# 252  AMukCLCr52XxsEjXoDxKKxjNg4FpnsReXNaQx8aR6DJF         2330       46.0         1.97          91.0       1.0           59.0         318.0
# 502  HnfPZDrbJFooiP9vvgWrjx3baXVNAZCgisT58gyMCgML         2342       46.0         1.96          90.0       2.0           71.0         352.0
# 360  DB7DNWMVQASMFxcjkwdr4w4eg3NmfjWTk2rqFMMbrPLA         1354       45.0         3.32          86.0       1.0           24.0         169.0
# 174  7cVfgArCheMR6Cs4t6vz5rfnqd56vZq4ndaBrY5xkxXy         3015       45.0         1.49         104.0       2.0          220.0         358.0
# 14   2GUnfxZavKoPfS9s3VSEjaWDzB3vNf5RojUhprCS1rSx         3547       44.0         1.24         116.0       5.0          103.0         473.0
# 336  CfgRXmp1LEYr97EaT2RyoL2cSvtWgJh52Bes89RxVSoW         2616       44.0         1.68          98.0       3.0           50.0         328.0
# 249  AEHqTB2RtJjegsR2ePjvoJSm6AA5pnYKWVbcsn6kqTBD         3731       44.0         1.18         131.0       3.0           75.0         524.0
# 342  CoG8d9Fp2TFJRkAmrPMiPsGhQWHzdTTVoegEp9svRgmJ         2710       42.0         1.55          80.0       3.0           74.0         328.0
# 459  G2TBEh2ahNGS9tGnuBNyDduNjyfUtGhMcssgRb8b6KfH         2260       42.0         1.86          80.0       1.0           56.0         286.0
# 242  A9mvukTd77EbRoBX4ydSCFQHdu5bsRFkNXTTRstA8FAC         1902       41.0         2.16          69.0       1.0           44.0         271.0
# 410  EXckihF3qmguH5znjhfzLvHsbk2E3nEW2DqNh4MMnDMm         1889       41.0         2.17          86.0       0.0          162.0         241.0
# 295  BXAxLMMMUNYfC1z166VjWHR3WjTmqzLxB837o5ghmRtH         1696       40.0         2.36          86.0       0.0           53.0         217.0
# 315  C1ocKDYMCm2ooWptMMnpd5VEB2Nx4UMJgRuYofysyzcA         2256       40.0         1.77          97.0       3.0           27.0         298.0
# 442  Fc6NNdS2j3EmrWbU6Uqt6wsKB5ef72NjaWfNxKYbULGD         3416       40.0         1.17         112.0       5.0           90.0         489.0
# 734   vu1sGn2f1Xim6voHNLt4nLn38zNkYdLasU7hEr1TC2D         1259       39.0         3.10          50.0       1.0           22.0         156.0
# 140  6aDs9tUm2gErcPn2c1TZnp5cu2bQV9BzyuwW4baWQYd4         1832       38.0         2.07          64.0       1.0           40.0         212.0
# 299  BeaCHioStqCEFDFxKwAEzyrUPYxqnBPhJ98gDKeEiTPb         1131       38.0         3.36          61.0       0.0           14.0         197.0
# 478  GmCxjmjKZoaKN1DKunbYq8RCYib94Nm3sHyncFfofaF5         2213       38.0         1.72          82.0       4.0           53.0         319.0
# 497  HaLanfo94ezLc3JZ55qqxr7W3qbe1PprJyv2uEtriEqN         1304       37.0         2.84          49.0       1.0           22.0         181.0
# 490  HLnodbYkL5PFA8hjAZDkm5pGzV7eLTvcs671AW2L6St9         1934       36.0         1.86          64.0       1.0           60.0         293.0
# 334  CaveyttUBTKttncu1e4RF814XjuoGfYv8cEsiKGDNCPX         1417       36.0         2.54          36.0       2.0           31.0         136.0
# 352  CwyVpfmfSiMeCexi3JgUNvaiDfYN14cLDjzT99zcBuD2         2111       36.0         1.71          56.0       2.0           51.0         322.0
# 93   58KprHKFNHgH1Cvo4QwxWkDeJNaSQVteCoAAFUWjtESn         1561       36.0         2.31          53.0       1.0           36.0         193.0
# 556   RBFiUqjYuy4mupzZaU96ctXJBy23sRBRsL3KivDAsFM         1094       36.0         3.29          57.0       0.0           20.0         144.0
# 374  DUND26mEDfFeaPsVof3YvbXDRvpuQX7HMUJrLgEWzYw4         3399       35.0         1.03          72.0       3.0           78.0         468.0
# 545   Ninja1spj6n9t5hVYgF3PdnYz2PLnkt7rvaw3firmjs         2092       35.0         1.67          38.0       0.0           97.0         226.0
# 78   4SsMncJdtKiUcDtukkX15mqei7WiuQ9yvRtQrQW4reWC         1435       35.0         2.44          53.0       1.0            4.0         152.0
# 457  G1bLKfyNm7zsmmYEL9dyxBvMtxpFcwy2s84bHDj2ZFUY         1187       34.0         2.86          55.0       1.0           43.0         161.0
# 438  FWwwP9tNttSy9dJFxwf6ebXWfc6VJXqFNMTccrMiLFTH         1616       34.0         2.10          69.0       2.0           38.0         245.0
# 597   VQwCCSfW3o5NDx7n5FBr9SoYiLXVgetstHvaWBvv2YH         1539       34.0         2.21          59.0       1.0           61.0         204.0
# 332  CXPeim1wQMkcTvEHx9QdhgKREYYJD8bnaCCqPRwJ1to1         1753       34.0         1.94          52.0       1.0           19.0         210.0
# 428  FBbqKvwLfKGZrKrfSbPJz4ymQ7zMarhRyZtu1RBkSe89          928       34.0         3.66          37.0       1.0           21.0         151.0
# 491  HM1KjNaXa4w8K4gCXbieoMh5gUTNeUhg9fvdXMKeBW3L         1103       34.0         3.08          48.0       1.0           35.0         141.0
# 601   XkCriyrNwS3G4rzAXtG5B1nnvb5Ka1JtCku93VqeKAr         1285       33.0         2.57          59.0       0.0          101.0         155.0
# 95   5Cchr1XGEg7dbBXByV5NY2ad8jfxAM7HA3x8D56rq9Ux         3977       33.0         0.83         163.0       8.0          125.0         587.0
# 160  7GkMBmtrTZz8QbjSe1sXvAUtz7Pp42SQxfT5ymmJD4We          629       33.0         5.25          50.0       0.0            6.0          61.0
# 380  DZv25oNCWFvGXu9tH63BiAXvG94syweGZhbvdN3HxDxT         1555       33.0         2.12          56.0       1.0            6.0         238.0
# 343  Cogent51kHgGLHr7zpkpRjGYFXM57LgjHjDdqXd4ypdA          763       33.0         4.33          50.0       1.0           42.0          98.0
# 456  FzQqaDStQQHs52YKeCnDovwSqvyZBCgs2kJcmvoFZwaS         1890       32.0         1.69          49.0       2.0           54.0         268.0
# 253  ANC1u9sY36q3mi2MyVhtz71un8yLgTsFBUuyLcSPzKsk          998       32.0         3.21          37.0       2.0           16.0         103.0
# 598   Va1idLRtYEtVFJFsvz8vtt1uCJgea4Q1zi2Rh3eraJh         1034       32.0         3.09          61.0       0.0           18.0         110.0
# 99   5HYjArGt81naevDdwMaEx8yeGNw9jYBSDJa8YavT9Mp4          604       32.0         5.30          34.0       0.0           23.0          63.0
# 572   SSmBEooM7RkmyuXxuKgAhTvhQZ36Z3G2WsmLGJKoQLY         1110       31.0         2.79          53.0       1.0           44.0         168.0
# 131  6M53yM6dsE6hiaHgxWvYa4fsfzQTGyAZn7rM6JrzbqJV          841       31.0         3.69          47.0       0.0           19.0         101.0
# 583   Ste1115xFGdAYK5jaWA3dEFcUc1S5jEbVvD8e327zty          896       31.0         3.46          40.0       0.0           81.0         108.0
# 262  AiDoLWFKzNxSXKeZ4zym2TEPkg6F4kQ3YBA8WhANVPEq         1319       31.0         2.35          46.0       1.0           34.0         174.0
# 462  G9vCpJUUSpEm4zPwzSNpDmZ8MGwLEbiSLV59EBzCGvzM         1369       30.0         2.19          53.0       1.0           40.0         226.0
# 551   PUmpKiNnSVAZ3w4KaFX6jKSjXUNHFShGkXbERo54xjb         1752       30.0         1.71          39.0       1.0           56.0         230.0
# 616   bkpk9KVsDRfrArzzmkJ9mPEvbXfQxczzQYR3QMGiR8Z         1241       30.0         2.42          40.0       0.0           29.0         175.0
# 620   bxrAptB5ZpZBhoLedJpoGWY5hBjjt3zvVBr2323Rrq6          790       30.0         3.80          37.0       0.0           11.0          78.0
# 606   aXiomFkk6VzXaBhPuhMqTLZZguCFzzbyP9LTtZ7ZHLQ          784       30.0         3.83          42.0       1.0           85.0         118.0
# 683   pSoLoZx55zZz61gjxSTwHtwTg4yTwdm7ruBmyjbYgT2         1833       30.0         1.64          45.0       0.0           85.0         189.0
# 643   grptonHnt7YSmJokGK9TJJTBXDT8ca4LSWMHCCfzzPa         1167       29.0         2.49          48.0       1.0          148.0         164.0
# 519   LA1NEzryoih6CQW3gwQqJQffK2mKgnXcjSQZSRpM3wc          935       29.0         3.10          42.0       0.0           21.0         141.0
# 228  9iFPQbP1jGkj67sXg6YLLGRUBVEDMcapdS6jmCZSnz8R          870       29.0         3.33          37.0       1.0           12.0         112.0
# 136  6TkKqq15wXjqEjNg9zqTKADwuVATR9dW3rkNnsYme1ea         1789       28.0         1.57          51.0       0.0           29.0         274.0
# 90   4vdWYn2KbmQ3Dns5wVBfz4CFQDds4b7CpsC8MHBhHAib          367       28.0         7.63          26.0       0.0            5.0          45.0
# 243  ABC1U4cf9DZMwqy8ktEr4WJj8VHmVBQibbC57gEJthwY          558       28.0         5.02          30.0       1.0           21.0          82.0
# 246  ACvL73V4GNnxPVfZ7K89jCrYurLyzpEuE9qirjvh2Xmi          868       28.0         3.23          37.0       0.0           72.0         143.0
# 151  6yFGGAgYpBxgYPuHW4rv7hJmhKrUiXKyHkpVGaYtKrwE         1322       28.0         2.12          56.0       0.0           22.0         207.0
# 539   Mwz8VgAEnPtfqS62r3ixrFiMJwnNfEwR141CGnsTo5k          613       28.0         4.57          41.0       1.0           10.0          81.0
# 408  EUcJwf7jXskRE6NZBtFPVH2EedNvNYko8LL2WT62XctB         1260       28.0         2.22          45.0       2.0           24.0         173.0
# 416  EfPYQ4BUMiKa6736qqrtnCBGkUSRDGSr1WvtyUgWHuyp          779       27.0         3.47          31.0       2.0           15.0         110.0
# 157  7CR3Jq4ny2tsr3DX3DvyjoU8TYs776MGkU6nLMWjAqCT          980       27.0         2.76          36.0       3.0           28.0         164.0
# 199  8n4pc4sCJtBeLfJdGyJn6EcZuhtfTiepRa9ExdJFdmEN          698       27.0         3.87          37.0       0.0           16.0          82.0
# 421  Ex1AxFCipXGfSxgvXPPT3nPQUARddCduHwKR6jHiXAaT         1069       27.0         2.53          33.0       1.0           21.0         161.0
# 183  84gC25fbFKYueR9WEfreUysk1n3ZFxLFDDjbyqeqGpoW         1336       27.0         2.02          30.0       2.0          114.0         160.0
# 173  7Zm1pE4FubFYZDyAQ5Labh3A4cxDcvve1s3WCRgEAZ84         1123       27.0         2.40          48.0       3.0           61.0         172.0
# 635   fishfishrD9BwrQQiAcG6YeYZVUYVJf3tb9QGQPMJqF         1026       27.0         2.63          37.0       2.0           30.0         142.0
# 474  GYx8kpp7SsRwtQEEsGQjAxb4hFMMmT91kFJuDeky3YGQ         1224       27.0         2.21          34.0       1.0            7.0         141.0
# 43   2zykwzzo1pd3H2oSj5j5SRLTvmpa9Nr2S2Bh8tTVd5Tq          300       27.0         9.00          24.0       0.0           11.0          41.0
# 104  5RvfTSowms7BTYaBj8SxVjj7ELAAKdQadKsuNpmBAwCs         1020       27.0         2.65          41.0       1.0           22.0         157.0
# 721   spcti6GQVvinbtHU9UAkbXhjTcBJaba1NVx4tmK4M5F          678       26.0         3.83          23.0       0.0           10.0          77.0
# 610   anza1rXDVhy1NfVNtsbT3kSBh2jgB1BGZUKuUibSAJd          755       26.0         3.44          36.0       1.0           28.0         130.0
# 496  Ha1iade1AH3B12K9SccfWoPdFtQKKQsj2ZyWwxcjqJJU         1357       26.0         1.92          43.0       0.0           77.0         195.0
# 149  6xWLi1TDSh65fWsSqE1zdvANTSuVDRMx4ghsGJwgunS8         1121       25.0         2.23          31.0       3.0           19.0         131.0
# 730   vALigXFg9wnnhVHN16vNxHxXtAXiBv5QjAE6udoniBY          726       25.0         3.44          19.0       1.0            5.0          79.0
# 158  7EzbSahSfSjeRexHcNDLDpzHBAGBLjLKtjbmuoQnEtjE          902       25.0         2.77          43.0       0.0           24.0         148.0
# 347  Crg1X8FftV44NmwfFvgREjanBQmyyS7NEu6duLU7Cyy6          450       25.0         5.56          26.0       0.0            9.0          47.0
# 16   2Mob8FJkb8chZY5pTBMpKfLwgZAQHE5i9jAC5zbASitD          523       25.0         4.78          22.0       0.0           14.0          59.0
# 66   3s97yjq2MhoPVPC3U9VeE3Z5S643Pweovg88ysvrQPw5          514       25.0         4.86          25.0       0.0            9.0          34.0
# 470  GREEDkgav1ox1jYyd9Anv6exLqKV2vYnxMw5prGwmNKc         1004       25.0         2.49          40.0       0.0           28.0         136.0
# 263  AicQr2zCWBLiBwt2r6o7iTemmtyE7q5pTKyuuupbXEQA         1120       25.0         2.23          33.0       0.0           14.0         151.0
# 60   3YVoK8UN62dyiPZnGBzBTkGdwsVmmK1MpRoLcxNRs9BE          618       25.0         4.05          28.0       0.0            9.0          67.0
# 324  CPcDFHCAKkr5Kp9T5aQWJhXV5J6iFj141NMQ87L6poPL          563       25.0         4.44          29.0       0.0           13.0          52.0
# 64   3psxMyr7rQzywVp1MXKd1XFmFz33NjydzCoJx9t2sMQW          812       25.0         3.08          27.0       0.0           61.0          92.0
# 599   WUNoB9YQXmXXRcJsjY1G8PfVag5aAfnyGmFd6YwJVwp          344       25.0         7.27          28.0       0.0            3.0          43.0
# 680   oPaLtitM6cwpFVzP2rDhLsJLdY2vcbuZiJJyD1TFUKs          765       25.0         3.27          30.0       0.0           66.0          80.0
# 30   2gDeeRa3mwPPtw1CMWPkEhRWo9v5izNBBfEXanr8uibX          351       25.0         7.12          30.0       0.0            2.0          50.0
# 201   8pyp3vfVPRziYdAYEyqkwytdBbdVbQmHqfQAVDcRV3w          457       25.0         5.47          20.0       0.0           15.0          63.0
# 70   43Am3PKFeo9cACpqYL5Sk95rpVdxLw3Mc22PqRqZXEW2          546       25.0         4.58          25.0       3.0           13.0          69.0
# 138   6XKqyUVUcpe3CNucjF6gk5zonJDqNGvob6kaTy4Ps1U          994       25.0         2.52          37.0       1.0           36.0         134.0
# 695   puffinQSvKFriPbyE5atyx1ptfnyytovbzxybr1jsyy          614       25.0         4.07          31.0       0.0           27.0          71.0
# 168  7QQGNm3ptwinipDCyaCF7jY5katgmFUu1ieP2f7nwLpE         1747       24.0         1.37          86.0       9.0           31.0         281.0
# 661   mXv18ov8qCiQGs3ieoen981LdgZzYJjJak6reK6fpNC          544       24.0         4.41          24.0       1.0           15.0          93.0
# 179  7qGNnXKW1e3DsqEaSxwxMdBTFsrK73XtWTmkGitRyMQc         1027       24.0         2.34          34.0       1.0           37.0         149.0
# 560   RNXnAJV1DeBt6Lytjz4wYzvS3d6bhsfidS5Np4ovwZz          815       24.0         2.94          21.0       3.0           25.0         104.0
# 341  CkCMabrc3HgBgDkeKPXkbWuQpUuSqW7zs1Mg3HFArx61          493       24.0         4.87          30.0       0.0           15.0          59.0
# 708   sTepQGoReJq2tBKStL19DT6nnGHcGiAvFjyYaokLyuM          752       24.0         3.19          35.0       2.0           20.0          96.0
# 589   TxtxXzLTDQ9W4ya3xgwyaqVa6Tky6Yqhi5BLpPCc9tZ          720       24.0         3.33          26.0       1.0           13.0          83.0
# 281  BCS95L5JHBWHvWkcEJBEF3BH5QHxKcPeaTgoYmHLvfFh          255       24.0         9.41          22.0       1.0           16.0          36.0
# 574   SWiz7QwnYPm61pWWUUkMhj4r5pZLP1SvYibdHcB2cov          340       24.0         7.06          27.0       0.0            1.0          51.0
# 132  6MiEjXqYksCtKnJpvAp3CAoEZnnWZyoSxu41HCzAYNdc          831       23.0         2.77          21.0       2.0           48.0         103.0
# 92   57i31UEyDg4koaZMZ1wAHbYuezXv3AVaHtvJgJarxt3f          418       23.0         5.50          23.0       0.0            3.0          54.0
# 582   Stakex4B2tpDHPWGvV1dninfiaYCGdakgTknpzPitLh          383       23.0         6.01          19.0       0.0            7.0          24.0
# 8    23SUe5fzmLws1M58AnGnvnUBRUKJmzCpnFQwv4M4b9Er          525       23.0         4.38          32.0       1.0           22.0          69.0
# 511  HzrEstnLfzsijhaD6z5frkSE2vWZEH5EUfn3bU9swo1f         1234       23.0         1.86          27.0       2.0           60.0         183.0
# 566   SFundNVpuWk89g211WKUZGkuu4BsKSp7PbnmRsPZLos          571       23.0         4.03          20.0       0.0           18.0          48.0
# 312  BxkAkLR2W3agWtjMXBNvhxmB8vsn7zhjNQcyfost99KY          335       23.0         6.87          22.0       0.0            2.0          36.0
# 624   ciTyjzN9iyobidMycjyqRRM7vXAHXkFzH3m8vEr6cQj          411       23.0         5.60          20.0       0.0           46.0          50.0
# 437  FUNDTXgtnkfuhK6G6JUi5CzxPWeZNF9n96vFuBNGFy1v          598       23.0         3.85          29.0       0.0           16.0          67.0
# 538   MutT1jxCXbRWJXpXoJK259gLrNfzDezdxS3BSkQAmv1         1007       23.0         2.28          23.0       2.0           46.0         133.0
# 117  5ikB9XZNVsjwKb6hHT3FS3So1Z1SrDvU5yaniWEQyDEG          683       23.0         3.37          20.0       0.0           14.0          56.0
# 679   nymsHergYedT9CJMgtGMvqXUTGcbs5o3MiWTJUbqTGY          481       23.0         4.78          18.0       0.0           29.0          43.0
# 101  5MAGJ3zShtXMMVXjZRoFqtFF7XhP8iLSyZrxdL7KpjcB          578       22.0         3.81          24.0       0.0            8.0          60.0
# 396  EBoKqyT2kCabcHXgpF7ScwrHgGUsR821xkTJsHtP2JJi          356       22.0         6.18          26.0       0.0            7.0          51.0
# 23   2Wf9V9rPeVRUTfmWdPedCJuWVr6MFfyLuigEq42DuMDc          359       22.0         6.13          20.0       2.0            4.0          41.0
# 166  7PdKhpKz7T39vZHFL1UfcYNDsLvay6hp4KPQq1aUckFf          779       22.0         2.82          23.0       1.0           49.0          87.0
# 426  FACb6bbTDRBHCK999V8ox8jga5JBnt1r3vvzmAYAMv2o          324       22.0         6.79          17.0       0.0            6.0          29.0
# 518   KoLibrJsbABbtmtFPc7nPvDxT81rc4UPM7mY9xSLjpo          411       22.0         5.35          17.0       1.0            4.0          39.0
# 431  FGiEdzde7Fco2WLpNQMat299hUVoykJdaA5hxdmCzHiS          502       22.0         4.38          24.0       0.0            9.0          73.0
# 49   3CKKAoVi94EnfX8QcVxEmk8CAvZTc6nAYzXp1WkSUofX          225       22.0         9.78          21.0       0.0            8.0          38.0
# 94   5AsoSeQtLoN8eLsf3wKrR3LwxHME4sTBGR6dpTCP1k3H          374       21.0         5.61          20.0       1.0           13.0          51.0
# 493  HT41udB8mLZZf7tev9tUoHYJ41TP8GWZ6zFMbjiviXk5          521       21.0         4.03          22.0       4.0           15.0          84.0
# 212  9AW87WqARQonyJYhx1G25fKfvjURFYVmHs79z1NUXDPD          575       21.0         3.65          25.0       0.0           14.0          86.0
# 196  8hAYbagNt7CMBooFfqVJhBgLqLffpjXTWJMk8yybjJsN          421       21.0         4.99          22.0       0.0           24.0          55.0
# 585   THE1CosYJD9F1eBq53Fg4MZYZa5WrPUf2RQU5ZHnfEj          240       21.0         8.75          19.0       0.0            8.0          26.0
# 163  7MTjmteQHhthwwTZhUzsc2dP4NBvGNRqj8jzdqNxHFGE          447       21.0         4.70          23.0       0.0           17.0          72.0
# 668   mineL1YNwcRnxN93B2sX6q22R11WfRqxnY4NBV8KfFY          659       21.0         3.19          18.0       1.0            8.0          79.0
# 187  8T8AJfUCXwPFwEMmjca8gCRSktPrqbUBVa6ggNyhLhFJ          620       21.0         3.39          19.0       0.0           40.0          53.0
# 226  9gFxqsXbFyrKXUkqpAatonn47uYZ7sEZSnMxhzQoXrUJ          712       21.0         2.95          22.0       0.0           33.0         105.0
# 477  GkFT5nmcFVmJiLwuE98PjdF3LReMeq4WbejFHfwrnsgw          483       21.0         4.35          17.0       0.0           13.0          61.0
# 240  A4hyMd3FyvUJSRafDUSwtLLaQcxRP4r1BRC9w2AJ1to2          560       21.0         3.75          20.0       1.0           10.0          71.0
# 476  GiYSnFRrXrmkJMC54A1j3K4xT6ZMfx1NSThEe5X2WpDe          413       21.0         5.08          18.0       0.0           13.0          54.0
# 207  91oPXTs2oq8VvJpQ5TnvXakFGnnJSpEB6HFWDtSctwMt          579       21.0         3.63          24.0       0.0           16.0          75.0
# 356  D3htsc6iRQJLqCNWcC2xcZgUuvcd1JT8zoYNqraNcTQz          448       20.0         4.46          16.0       0.0            7.0          55.0
# 489  HLXxkmjb47spcmbbKi3UCfZ2qmFY29t8MN562AEmh2Qh          460       20.0         4.35          19.0       0.0            6.0          53.0
# 350  Cu9Ls6dsTL6cxFHZdStHwVSh1uy2ynXz8qPJMS5FRq86          562       20.0         3.56          16.0       2.0           15.0          82.0
# 326  CTDGxTK789ZvhgyHZHtSnxTtysbyY1mrywXEJiYYqXxC          261       20.0         7.66          18.0       0.0            4.0          37.0
# 300  BfgMdL4FaNHp5zZpD7WMYG5sZUrCWQPEjXDwWS7M5q3F          749       20.0         2.67          38.0       1.0          163.0         112.0
# 482  GwHH8ciFhR8vejWCqmg8FWZUCNtubPY2esALvy5tBvji          324       20.0         6.17          18.0       1.0            0.0          48.0
# 449  Frog1Fks1AVN8ywFH3HTFeYojq6LQqoEPzgQFx2Kz5Ch          859       20.0         2.33          25.0       0.0            9.0         106.0
# 581   SscQkTYV2BFQYGGffAmTzvefrFrw6z9GNYiWHstVZ77          444       20.0         4.50          17.0       0.0            7.0          45.0
# 195  8ebFZA8NPLBZD91CwsG1HWQsa2B5Ludgdyf5Hi3sYhhs          320       20.0         6.25          17.0       0.0            4.0          34.0
# 107  5VrW7YNBccVnhnZVmooCePdLFcs2UjfxRT3hoY9mN8Ec          496       20.0         4.03          19.0       1.0            6.0          54.0
# 409  EWARp8Syq8cTWGWHtP5LT9fKAn5GvXfSCH8LfAwpgQ6m          275       20.0         7.27          12.0       0.0            6.0          38.0
# 269  AqyRvpjjSN6jWYPxijoJwhmKwJFk6fRYDh9fQZHcJ2o7          504       19.0         3.77          15.0       1.0           14.0          71.0
# 154  73hojLdq1vZDSxeVQEqVFJ4iwLngdvEJPEpEHkSdv6BZ          442       19.0         4.30          17.0       0.0           11.0          43.0
# 720   soLStaCk5TiGCpeLKa9Fvv6f5JQGMa6S3uhLh826e9N          387       19.0         4.91          16.0       1.0            5.0          46.0
# 464  GFXVa19rX6iwfs3sLS5UvX9Exu2usRsG4V5MRMDRo23V          291       19.0         6.53          15.0       0.0            6.0          36.0
# 406  ETuPS3kRfLufz5VSYN2ZrePoEVSZSpgVPKz3MUZpYe3x          421       19.0         4.51          21.0       1.0           13.0          57.0
# 159  7G4RfctwLLgqG4ZWfCirU8dfJd87mKQWgB4EHQRv8i7v          294       19.0         6.46          20.0       0.0            7.0          41.0
# 189  8ZQg3K1V1Z2BVJkjmnxpi43WKhjPGXphzu5QmBkJibSP          513       19.0         3.70          18.0       0.0           16.0          58.0
# 691   popscoyTKVksa4TyTXw488b3vvFxM7qQEyTBeMQopKu          236       19.0         8.05          15.0       1.0            6.0          18.0
# 738   wifwUaAXgGXixi757cinR8RhAzNuuyKg8hh7mkCDPEc          259       19.0         7.34          16.0       0.0            0.0          35.0
# 671   mrgn4sJJu5GBa5wbKyjuASzhyCifvcedGoLtpKjB3Wf          677       19.0         2.81          23.0       0.0            0.0          89.0
# 10   2AKKnirWVZMhnzuwqpizw9SwfZjGpRFLx2zCCNtPWpbc          299       19.0         6.35          25.0       1.0            3.0          26.0
# 522   Lake8NXDThihebhxS3Js7mFnj9fthmus93zEdsFNrsL          387       19.0         4.91          13.0       4.0            0.0          45.0
# 48   3C2cXXVHCm2w2EWnHUNxhtZCB2EMv2AeJ4TpW5ws18fi          560       19.0         3.39          18.0       0.0           17.0          78.0
# 176  7mF8NZJdREuM1uwYcvKffuY9QJBEoHhNp4hZ4NS2fuXW          459       19.0         4.14          18.0       0.0           14.0          79.0
# 704   rubyWZkfnjG716rx69n2oCAhevVZaMRQunir9VQcY2E         1172       19.0         1.62          40.0       2.0           66.0         169.0
# 130  6JKwz43wDTgk5n8eNCJrtsnNtkDdKd1XUZAvB9WkiEQ4          337       19.0         5.64          24.0       0.0            9.0          45.0
# 445  FjYEr2UCeFzNfAKiFrbhG34Zv8LxbmfHYAFhAfc7SLQL          546       19.0         3.48          15.0       1.0           13.0          51.0
# 205  8vk6QpG93JSaQCSgnycBsv5qmfQBk4qC9FjNA35E5JhU          401       19.0         4.74          14.0       0.0           22.0          38.0
# 483  H8fHToVcZPi5bupGZohGPX2SWs8NHzgFKQ31wi5n6oux          645       19.0         2.95          12.0       1.0           19.0          51.0
# 106  5Us18hLZPXJTS4QVuGSsUw137Dyd2tgBaem24Xsf5nBS         1216       19.0         1.56          57.0       3.0           38.0         206.0
# 333  CZanBzZHFzrGY5qKzaX3CNhJ5smHEMTWFFnoeUi4J6dr          196       18.0         9.18          21.0       0.0            3.0          30.0
# 121  5pZvwjSpGYCxpJeySwSbSAji7kZe4YntL7rQvXM3YcNT          217       18.0         8.29          17.0       0.0           10.0          31.0
# 55   3RXKQBRv7xKTQeNdLSPhCiD4QcUfxEQ12rtgUkMf5LnS          583       18.0         3.09          11.0       0.0           10.0          42.0
# 165  7Nu9ckgtjobZ3MkbadGFKEvRymYuah9HmcxiUJKMM9NB          378       18.0         4.76          18.0       0.0            8.0          53.0
# 541   NATsUSZGohWw8xtLdxG4yus21UCkaes4FLfM2eqKbRk          313       18.0         5.75          18.0       0.0            6.0          26.0
# 655   juigBT2qetpYpf1iwgjaiWTjryKkY3uUTVAnRFKkqY6          752       18.0         2.39          17.0       3.0           15.0          83.0
# 289  BR1aTt4ZZUCwWJDkSYf1hqkYJjo7Mb7Ar8iVTkeSwUB8          524       18.0         3.44          13.0       0.0           10.0          52.0
# 272  AsMpvJ3DZ2Ydu1WTRMAyMH4QjSLiUG39rKzfzvtE1bWr          449       18.0         4.01          14.0       0.0           10.0          65.0
# 546   NordEHiwa6wT5TCjdeWJzpsA7DSmWQPqfSS7m2b6cv3          238       18.0         7.56          12.0       0.0            7.0          24.0
# 4     1Link6hB1NpkCwJt3ZtpQKZszKauhEcKgiWjaU8PRDG          163       18.0        11.04          22.0       0.0            5.0          11.0
# 548   PAWsME7oYbjt5TRNc11mBa33JhKnQr9AYherdr9YAZ6          280       18.0         6.43          14.0       0.0            3.0          39.0
# 25   2XmhZKHmfjku3T3nC9xKhgr5bm1CAmWXqNsNt49mo82C          505       18.0         3.56          16.0       1.0            8.0          78.0
# 636   forb5u56XgvzxiKfRt4FVNFQKJrd2LWAfNCsCqL6P7q          344       18.0         5.23          10.0       1.0           16.0          37.0
# 36   2mMGsb5uy1Q4Dvezr8HK2E8SJoChcb2X7b61tJPaVHHd          572       18.0         3.15          18.0       1.0           17.0          68.0
# 335  Certusm1sa411sMpV9FPqU5dXAYhmmhygvxJ23S6hJ24          483       18.0         3.73          11.0       0.0           26.0          48.0
# 669   mint13XHZSSxtgHuTSM9qPDEJSbWktpmpM4CZxeLB8f          760       18.0         2.37          23.0       0.0           44.0          84.0
# 76   4QNekaDqrLmUENqkVhGCJrgHziPxkX9kridbKwunx9su          393       18.0         4.58          14.0       0.0            8.0          47.0
# 340  CjmXSapt1ouz3CZzgkRJckBEwMSo5fVdVrizLeRscwYD          312       18.0         5.77          17.0       0.0           13.0          44.0
# 234  9q16BB7WGmBxf1nJTdxH5zPnBUhtHqdqXqRFjSjuM4k7          160       18.0        11.25          12.0       1.0            1.0          17.0
# 379  DZVySotZvrvJyVAcgjFtUDm93zoCaq9wBruMAUz83CWW          780       18.0         2.31          15.0       2.0           31.0          74.0
# 567   SLAY6uN1zZpXBTfbuDDCesNmM5D288xrz8uYvfS3n41          640       18.0         2.81          17.0       0.0           14.0          76.0
# 501  Hj2jzpAp57KyM3SmnYwJbDVrQ8tTWizMon2hhzYzwxet          384       18.0         4.69          19.0       0.0            9.0          65.0
# 368  DP9iBgK9c7tJYb83KhxQMFNc1LXYu7nE7EhWpEzQnjmg          229       18.0         7.86          13.0       1.0            8.0          30.0
# 194  8cqck84coxk8TGXYBD95QosKCEA6fKwXLevcEv3oGmu8          283       17.0         6.01          12.0       0.0            7.0          32.0
# 494  HVXXmNKkmDZbZwj74iL2Y9Wu4SyrchBoxAfFYVAktLrG          399       17.0         4.26          12.0       0.0           14.0          37.0
# 584   SyndicAgdEphcy5xhAKZAomTYhcF8xhC7za2UD9xeug          412       17.0         4.13          13.0       0.0           12.0          60.0
# 710   sbidYi7fbif6qNsMpwBKvyF5DKcLCbjaegpADsKqNux          368       17.0         4.62          14.0       0.0           14.0          48.0
# 675   nebu15XQKGpxzhhckADBX9PgvGN5qk9RRJCFLKc118w          286       17.0         5.94          21.0       1.0            8.0          46.0
# 307  BoNKmNCGvoHS4CkKvYRnF21iEpUP827pZjhFGdA4t5as          425       17.0         4.00          17.0       1.0            8.0          72.0
# 215  9GHvMeJ4ZWuAX6sDGscFL1TBMszx2EehnrcTVUy4MZJQ          379       17.0         4.49          12.0       1.0           12.0          52.0
# 588   Tri1F8B6YtjkBztGCwBNSLEZib1EAqMUEUM7dTT7ZG3          390       17.0         4.36          13.0       1.0            9.0          50.0
# 451  FugJZepeGfh1Ruunhep19JC4F3Hr2FL3oKUMezoK8ajp          383       17.0         4.44          15.0       1.0           22.0          53.0
# 731   vahMVcSS3v6uwyFormV7FDAUbQSHwmy6vUedp1P7L42          179       17.0         9.50          11.0       0.0            4.0          14.0
# 488  HH5dA42XF1HxNk1TRpG6LuKfLViMYNdAz5iWrFM4hWFi          773       17.0         2.20          14.0       0.0           12.0          80.0
# 128  61QB1Evn9E3noQtpJm4auFYyHSXS5FPgqKtPgwJJfEQk          331       17.0         5.14          10.0       0.0            6.0          41.0
# 632   farbZXR7aBQSMCYiUXzoS4pRUsvuCZ38f6AXMXiKACf          154       17.0        11.04          13.0       0.0            2.0          14.0
# 503  HnwMGBAw5PxaX56eSYc969MorEy2NzEMPLkmBkdnJmeq          272       17.0         6.25          14.0       0.0            5.0          34.0
# 725   t23p8aBQN6P6tziMuN5XPmzqVRrip9oes7KuQwSmate          792       17.0         2.15          17.0       1.0           41.0          53.0
# 171  7VZM7YHcX73TpGoXDeBu61g4QKC86GwAEnew8dA7Y2xn          383       17.0         4.44          15.0       0.0           18.0          37.0
# 112  5d9Mdc2Zk8as8GL1AxQeXxv5htBBvC5bjfmsXC7UUWwG          474       17.0         3.59          12.0       0.0            8.0          44.0
# 233  9ppJrpsbbuGNjiMhhD52Ueco4KXUzVfrtNQ6tAcDab4f          278       17.0         6.12          13.0       1.0            5.0          50.0
# 531   MBVyz9s72WSfUmbr1S8fgHjDJQkPs1Q4Wxi6A2Mees9          697       17.0         2.44          13.0       0.0           42.0          60.0
# 735   vvvvbtDs9HsdsE6NskZMnb1RA6muoud1ChQuiF9QhSM          259       17.0         6.56          10.0       0.0            4.0          36.0
# 377  DZKTNGR3r4Akj3G42ReZatKhkmgEXoZjk5Ed2tFwRyqm          313       17.0         5.43          16.0       0.0           12.0          44.0
# 185  8GLRbAstsabZuZUx73AoyfGi1FRCWSUhRgMugFyofEz7          293       17.0         5.80          15.0       0.0            6.0          46.0
# 224  9bkyxgYxRrysC1ijd6iByp9idn112CnYTw243fdH2Uvr          247       17.0         6.88          10.0       0.0            5.0          25.0
# 328  CVRr5oHCAAooVbYze7CvXtRp4FUtkMCSqBZU7MVu8v8e          278       16.0         5.76          14.0       0.0            5.0          33.0
# 330  CVvaeDPR2o7P1eawG5c9TPFLzSXAewwPovPmREaEL4Cm          526       16.0         3.04          10.0       0.0           13.0          60.0
# 320  CEL22Qx7p85qY6gmhCZaYJrrnynJitkVRMQo6qZdT8Ns          208       16.0         7.69           7.0       2.0            3.0          30.0
# 308  Bs19Z9SokV1s46jutN9tqqaCgYf1GsVyyytVfkzwn9qK          310       16.0         5.16          12.0       1.0            8.0          37.0
# 521   LTP1bMnfq1Z6UctyDXYHo9qcUJ6ReXm9cG2VwQcsHBt          174       16.0         9.20          11.0       0.0            4.0          22.0
# 550   PRGNnb8DxVcP2WjSHfVRGgc8SkA5u6dbMwoTVV1BGKN          294       16.0         5.44          15.0       0.0            5.0          44.0
# 359  D8xKNftHzFcCekENuTEcFC1eoL9y8wNHEg4Q5z57KK4e          281       16.0         5.69          15.0       0.0            2.0          28.0
# 435  FSVdqBzx5D4UsqBLnvmH5dFx2dCm1pTPAbQWJ1PYzTJ2          344       16.0         4.65          13.0       0.0            4.0          50.0
# 651   icex1C6pnZxznQWiHZZANjGU8nZ8kNquFnjyY7XXrXE          267       16.0         5.99          12.0       0.0            4.0          42.0
# 391  E99w1XfS4UNM1xUKXWEuDmj8Mduy7u65jm2NCULTspSV          222       16.0         7.21           9.0       1.0            3.0          24.0
# 293  BULKzVM41WAyQZfL34vxqdsYwEYH9mJAJyzRS4xraf8b          389       16.0         4.11          12.0       0.0            8.0          43.0
# 337  ChaossRPGKnsVhX1GfPC78yq5Sqju4cMThcAsKZNz5d6          149       16.0        10.74          16.0       0.0            5.0          20.0
# 617   bonkcbAQvHpYWxEG63E8ufTB1cxkkk9eAKaPdGePE88          412       16.0         3.88          14.0       1.0            2.0          55.0
# 732   vaoJKVZYPAsqc52T2nNQhABR1gU6Cy2koDKfCQaEiva          227       16.0         7.05          12.0       0.0            8.0          34.0
# 719   simpRo1FrQYGa1moicfgnPDp6KyE38d4gYrZzhjXYJb          420       16.0         3.81          17.0       0.0           17.0          51.0
# 59   3WDh9HgusCujDmXCVhophLrHvoKHQd1Sd4uFHz1Awo35          297       16.0         5.39          10.0       0.0           14.0          46.0
# 223  9Wmaz9VPpEnH67ZqrvYd9bcH66DtsGaEKcSQE1ac5wkf          285       16.0         5.61          12.0       0.0            4.0          23.0
# 45   32ke3uf1qL3xLqbwzU76T2sbG2XaJrGuSCNdUnien3zm          431       16.0         3.71          12.0       0.0            5.0          46.0
# 127  5zuNci3TV79w6zLoJZzbZujMvkVZb2FcSPhgv9aT24AK          331       16.0         4.83          17.0       0.0           23.0          65.0
# 544   NdMV1C3XMCRqSBwBtNmoUNnKctYh95Ug4xb6FSTcAWr          280       15.0         5.36           9.0       0.0            0.0          30.0
# 666   mds4GEuiSgQRqveGyktWpETBFCb4AS2wDnhqwLHcT6Z          397       15.0         3.78          15.0       0.0            9.0          48.0
# 35   2mDrrmhSzpSyaF12izGk8hnFjtKCGeCFPwQHpRiJDby2          351       15.0         4.27          16.0       0.0            8.0          49.0
# 562   RoYFUUD7QD9aQ34UCMcwfye8dC5YvJeXz2J3mmoy5S4          204       15.0         7.35          14.0       1.0           11.0          49.0
# 674   nateKhsYkrVc992UuTfAhEEFQqr2zQfpGg9RafNkxdC          164       15.0         9.15          10.0       1.0            5.0          36.0
# 702   rsbp8zMHbGCpLoRktmsjspYv77VcjxAzH1KxPCD9BiU          483       15.0         3.11          13.0       0.0            8.0          52.0
# 696   q1yPXLsYcJhzxhUYLewFDjYmsBh2gDFnYqrZ9VPshrk          166       15.0         9.04           9.0       0.0            2.0          28.0
# 339  CiR8HNCfkjtcongPmP2DRdZPnFgjSbN5gsXdjmsXXHcB          249       15.0         6.02          14.0       0.0           19.0          43.0
# 81   4XspXDcJy3DWZsVdaXrt8pE1xhcLpXDKkhj9XyjmWWNy          513       15.0         2.92          16.0       1.0            9.0          69.0
# 77   4SgoyAwN26iu9Gpf12Bk1rnzp4G4yDUM3XVv4w7VQcAf          372       15.0         4.03          15.0       0.0           15.0          56.0
# 499  HcZvwZ83PfjrQDiq3GLHxisTs17aGURs6bJ2LwtmL4qv          250       15.0         6.00           7.0       0.0            2.0          17.0
# 271  As9NxA9bCfhrVLAFyGeWG5X5iLYPGhU3R7nLfX3tN6am          141       15.0        10.64          13.0       0.0            1.0          16.0
# 728   uEhHSnCXvWgtgvVaYscPHjG13G3peMmngQQ2ghC54i3          201       15.0         7.46          14.0       1.0            4.0          30.0
# 200  8nbE53mcKhy74HLiGZ1q5HRocwiCvgh49csSaHSdtukr          679       15.0         2.21          10.0       1.0           22.0         106.0
# 204  8uPW9msN75rfaKiwy8y8NxEX5zSk2WejtVv5YhZr3jCo          214       15.0         7.01          12.0       0.0            4.0          41.0
# 62   3cZSHGfNdaULpFAvGbWbxpVwzXB4gHdk8NFucPNR5pgA          548       15.0         2.74          13.0       0.0           10.0          86.0
# 699   radM7PKUpZwJ9bYPAJ7V8FXHeUmH1zim6iaXUKkftP9          340       15.0         4.41          12.0       1.0            5.0          52.0
# ...
# 453  Fy7RCjDdFLG8wLn7TBKbccaKwYX1FetdSoVDREdUHf5o           88        5.0         5.68           0.0       0.0            6.0           5.0
# 139  6YDWxPaJWpZxJ6JLGaBeTJaGQn3gi3Pwtivii9cDyDHo           41        5.0        12.20           1.0       0.0            3.0           6.0
# 129  65pHd5P2VrehonT1cdJ2JUnq5wi3WUgfL3A8RhYH7Kg7           58        5.0         8.62           4.0       0.0            6.0           6.0
# 524   LiFiDJwJjW98MB8wxcnXpafKYsuz1hwpUkuszkERiX6          124        5.0         4.03           2.0       1.0            2.0          14.0
# 542   NLMSHTjmSiRxGJPs3uaqtsFBC2dTGYwK41U18Nmw5kH           21        5.0        23.81           0.0       1.0            3.0           5.0
# 303  BiU1DNow77wGwSXW1bLmkcQe2cuySpkbz7xtbitD9Fmk           99        5.0         5.05           1.0       0.0            1.0           9.0
# 61   3YX7PQuESmR2h95FDgjahEQjyCBhmY1Ts2MsrM1Kg9DS           67        5.0         7.46           3.0       0.0            1.0          14.0
# 612   ark1hdnnfmusE24wGHkyVG1gdRCqfmXs9drasDAdABZ           57        5.0         8.77           0.0       0.0            2.0           6.0
# 11   2D2v7sMqDuq2ekZnFhaQm4k2ErWHemZQuYf5qaVTPFmg           29        5.0        17.24           3.0       0.0            0.0           3.0
# 607   adramSYKBv1yHoZTub4kepcmF5LybPxwyJcsz4fpfi7           61        5.0         8.20           1.0       0.0            0.0          11.0
# 24   2X7WoaXX9KPqNrNfvguhnwo3rjFPNsfw2t75fGjWRthz           37        5.0        13.51           0.0       0.0            3.0           9.0
# 74   4JahMMrVRS1gimWoXpD5H6KwKc2MrsoTDFMaStMttL1E          169        5.0         2.96           2.0       0.0            3.0          10.0
# 591   UMi1r5J3SagSu4HC3waB3YFzbXi82rRSScgW2e8NTfr           29        5.0        17.24           1.0       0.0            0.0           7.0
# 587   TopjgY7N1fJdnW89S9fX6t7LF61nspgXGL1NpgAKhDG           46        5.0        10.87           4.0       0.0            4.0           5.0
# 608   adre1Xia7ekGsEqNgHeFc7MYwkfzTQNeJgQmZ2agAKZ           66        5.0         7.58           2.0       0.0            0.0           8.0
# 575   SWnetabTLirPWqEK1V1T7HkVLC5vGvfjEsb89wiqrGh          105        5.0         4.76           2.0       0.0            5.0          11.0
# 109  5ZjxMYBbnKd4VFxLjAChSWMTeQ96147HnxZvQJxUseHV           76        4.0         5.26           0.0       0.0            0.0          11.0
# 365  DEgenZMznWXvg5YHaZM75arVTauV453SeXX1UrxcGNup           48        4.0         8.33           2.0       0.0            0.0           9.0
# 20   2UBhtRuyr9nvWsUnrbWrvJiYWEU8TVBD4PLYQJKiRa9H           61        4.0         6.56           0.0       0.0            1.0           8.0
# 690   pitch9cMruwjDtAnisNS4mwZUPhMsBztNEGu2weMg55           59        4.0         6.78           3.0       0.0            0.0           1.0
# 349  CtzN7ysR5rX69qd168Aosbuc83mPozhi81bEHbG7ecNP           51        4.0         7.84           1.0       0.0            5.0           9.0
# 267  AnKWYWA1zktynzWqPC5KQFYWrTEWNny2CAHbAVU9zSXT           45        4.0         8.89           2.0       0.0            1.0           9.0
# 430  FFevTkywysWf8PJvH4DZkEp4v9ks9HJPJhZWbhhJiYnr          105        4.0         3.81           0.0       0.0            0.0           8.0
# 638   gVALrRd3xq4D62KJNGDCpMMGz976w2x1Vo79mSNn4bh           43        4.0         9.30           0.0       0.0            3.0           6.0
# 603   YE11a5nVJtUNqsojkphYuWc7StqBzbCeFH6BjhAAUEV           23        4.0        17.39           1.0       0.0            0.0           3.0
# 552   Pid6HQnMCFb9izqX9i7X6ePdUPieGmjHoPxC1Jfooix           81        4.0         4.94           0.0       0.0            1.0           4.0
# 273  Atom7LRkdXj6MBoWJPgjaetrCMrgB9nnkQBYXTWE8Z3S           51        4.0         7.84           1.0       0.0            2.0           6.0
# 458  G1eAmANVWf6ZeoxG4aMbS1APauyEDHqLxHFytzk5hZqN           51        4.0         7.84           1.0       0.0            1.0           3.0
# 466  GK2YYwmQk58xA2k2SeugY3i334SJVViqTT8sT5wim3Dk           53        4.0         7.55           3.0       0.0            2.0          11.0
# 175  7knvB4bbqHCKuNp3ef2hJWdwqoH6WAUi55NQt6LdRfkx           45        4.0         8.89           1.0       0.0            0.0           3.0
# 705   sCANXAaS1a7yB8jz3USvGNLfd8DSc9r7TNzNSKKPkfY           55        4.0         7.27           1.0       0.0            3.0          16.0
# 142  6gL3uHvuUjaPp9mTBf2VZ4tpKiYhbWyPrAPboGByzEHd          117        4.0         3.42           0.0       0.0            1.0           8.0
# 397  ECNnK4VjcKTsABiw8FAp3JCE6tCmYyrEJthYVyMazmxi           46        4.0         8.70           0.0       0.0            2.0           7.0
# 682   orbit1bWKxnECKLqjhm5rybTiEC2GEYbecyebgEfM5q           37        4.0        10.81           1.0       1.0            0.0           9.0
# 354  D1Vbgkrhp1TmLGhfUD1urRMx5Ntz9AqQpgdX8DR8QMC1           95        4.0         4.21           1.0       0.0            4.0           7.0
# 711   scb1Z7du8NVSaHFXsafSjRdXr6xBjWR3iugikL739Y1           69        4.0         5.80           2.0       0.0            0.0          15.0
# 280  B94PGWcxE9iEDov8sZobTkqEY96Yb5gfcsYWSWpQxh6S           80        4.0         5.00           1.0       0.0            3.0          10.0
# 506  HrpWeJSYnQVtZe3BKxFCBrAEr8GRCmYUbQev4hoGDBs6          154        4.0         2.60           1.0       0.0            2.0          18.0
# 291   BSMe78Jk1BfeJDdHQj1aXVjrT2aMAYidyNAGQsTshrk           58        3.0         5.17           2.0       0.0            0.0           7.0
# 727   tkmaiSoZ3F8MofkQBVWG6JYSCzyN6ioe7ReYXohx3WJ           28        3.0        10.71           0.0       0.0            0.0           5.0
# 254  AWZhUiQjrjtxL8MEMWsCFbMausFQKkdTnDsFW2i411hN           43        3.0         6.98           0.0       0.0            2.0           4.0
# 245  ACTGYsH7bHbaSP7z9N86oLPHBThAELbGfTboc1VoFeZz           60        3.0         5.00           1.0       0.0            6.0           8.0
# 230  9maF99FLLAMh5v5JKG1ZyRZVBVsT5VkZnAJzDvduCpJa           36        3.0         8.33           0.0       0.0            3.0           3.0
# 213  9D3o3EYeknhTrRvXS1PnD2euGXnMFa3HwpYBq5gPZJDA           33        3.0         9.09           1.0       0.0            2.0           6.0
# 41   2ufnDYz755WuHqGCczry1ACTNUVZdn2cm43bCyyPSZtH           38        3.0         7.89           0.0       0.0            1.0           4.0
# 124  5yEnvhM4Ld3UZs2n173J2iR369E1ddcbQYeLSZxk4cYj           49        3.0         6.12           0.0       0.0            0.0           3.0
# 715   sce3TfT81rxYYcdbP1kBFMcTK3ZBc8hvHVeXD6WLSzE           54        3.0         5.56           2.0       0.0            2.0          10.0
# 102  5N9r2ne7dPgHtzeHC5ETJ3DAueKQiXSU8KAmEZrrojT7           50        3.0         6.00           2.0       0.0            4.0          14.0
# 100   5LNEDitSMhApT2uFnmtN7FmjCiGuatpnb2uU4f3shrk           52        3.0         5.77           0.0       0.0            0.0           3.0
# 75   4Kbcyn7JVPAWLRLPsNGTPmcNMvCkLTw51ZLRhqsUC6jP           47        3.0         6.38           1.0       0.0            3.0           5.0
# 726   te1ee9rGf369wxYQkuxkvuvMuTJ9cksgZySmNUF8rNY           41        3.0         7.32           0.0       0.0            2.0           5.0
# 182  7zAHbRxEQaNjKnQMjFm7j8LebHSGfzsQDdm2ZpUNPa7G           46        3.0         6.52           4.0       0.0            0.0           0.0
# 317   CARBN9PY1Qej1aCg4885pfoYH8EHfjWuMy59pVa48ky           18        3.0        16.67           0.0       0.0            1.0           4.0
# 637   fotby1ABxpei2EVH9uXJ6KbHYgPjbg4Sny9eRzQjtRN           29        3.0        10.34           1.0       0.0            0.0           2.0
# 402  EPFZFVrXuveEQar9LaEkt5kDRPMnbvK54qu5FwCxpkcy           54        3.0         5.56           0.0       1.0            2.0           7.0
# 659   mALL2W6DUgDDtcyurC9v5YTF2CMMeuRwPBkf6tEoG3y           58        3.0         5.17           2.0       0.0            1.0           1.0
# 657   kom1oNHyyt84XLGVfi5Jo1qkVkU5xG1sBxPG19rWknE           38        3.0         7.89           0.0       0.0            2.0           2.0
# 413  EdFUcP2f6j9iBg5BqsgJn3WDr1JieiKCo41hZ5Zrsk6w           32        3.0         9.38           0.0       0.0            0.0           3.0
# 533   MFLKSo4XDfrBf4FByx76zYM2dXSWcigag7ec2bCHTR4           25        3.0        12.00           1.0       0.0            1.0           4.0
# 557   REA1zKzM5WjDEcpB27Zx2Rk16foNPtLGTETy93LLgNw           21        3.0        14.29           2.0       0.0            0.0           2.0
# 571   SQDS9iwyWvT2mQbSZzuNKGoxuBug5jRHouF6SuMRBkA           65        3.0         4.62           0.0       0.0            0.0           4.0
# 602   Xoir1BnQX9TbEvon9HRbD8tkjcD9dorsxmNjZAV64Re           15        3.0        20.00           0.0       0.0            1.0           4.0
# 372  DTELykegBxxEn9c15GbH1zbYFr9CFd8VHQnhTGfz5JLb           55        3.0         5.45           0.0       0.0            2.0           7.0
# 623   chrtyETASKQhsndRM9pr6qC3gAHG5MuRwCgXSNVqnJL           55        3.0         5.45           2.0       0.0            0.0           1.0
# 611   anzaeL7Lsv71HW2mew8YcKGyGqL6qNn3xoNPRrejM73           36        3.0         8.33           1.0       0.0            0.0           4.0
# 366  DKSy9mQn63487j7oXHxqmykLEYUA3akTHm1QNPgDLGN8           30        3.0        10.00           2.0       0.0            1.0           1.0
# 344  CpNnGGhgVATJAbzHUXdrcGfpPiGuZyPka4QUmH7YgavX           87        3.0         3.45           1.0       0.0            1.0           8.0
# 329  CVgwMrWo9chKEuEPCe6Za9KJe8jamnAcoeWzaMeNubr6           49        3.0         6.12           0.0       0.0            0.0           6.0
# 641   gotasRuLTuJNZDtLHmaDJpEUjCWZqkHcuwbLhkgCwCX           35        3.0         8.57           0.0       0.0            0.0           7.0
# 714   sce2zXNjLpPMcSCATTrLiQhAAvHNNMKypTFVtg2H37U           43        2.0         4.65           1.0       1.0            1.0           7.0
# 103  5P35CJVKU15Rrh5M6EVkre23EyA3K34kAut2GXhHKM7W           84        2.0         2.38           1.0       0.0            1.0           2.0
# 644   h3ZXAE168mNxsszYYrUfkMVSCWx6DU2Uvrx97Kb1Nch           34        2.0         5.88           0.0       0.0            0.0           2.0
# 717   scs2Ra91pMbvqFAP7uitrN5U25SoyBTqZgBbhpVMJko           36        2.0         5.56           0.0       0.0            0.0           2.0
# 528   Lua1fxRRHCnjVAYdfGyv2GbUsRHGM2DN2wgpWuF2WSb           23        2.0         8.70           0.0       0.0            1.0           2.0
# 525   LimeA3gMLb2SjxrKbP7NsWk1UwTZrw4B6Ctc9dmVU6E           49        2.0         4.08           0.0       0.0            2.0           8.0
# 98   5HCTsoKM7vwjubSZSyVWChaHQ9sNNRB1d2SuvL3eZ6Y6           23        2.0         8.70           0.0       0.0            0.0           8.0
# 84   4b1onMDEasBh4BuPekQWijx3BYR64hAE1z2jJyeZUkck           25        2.0         8.00           0.0       0.0            1.0           3.0
# 724   svsD6T44XJnuXQWB15sy1pBxxruzrFy8rR7gXy8Jsj3           46        2.0         4.35           1.0       0.0            1.0           1.0
# 520   LFGGGJtnBLvq78DyMz1gTeedM6f8owck76qHThDABBC           50        2.0         4.00           0.0       0.0            1.0           2.0
# 605   ZoD1XLMhxdMveAJL4x9oab4FhRKP5NThTnSCH19Tdjp           48        2.0         4.17           0.0       0.0            1.0           3.0
# 2    13DmVBcyrSdsSsLWaKH9x1dwxDf48Wu5wprwxMmLshrk           23        2.0         8.70           0.0       0.0            0.0           3.0
# 618   bookoVmqw4QjVj5BbkFacouadx9M7816wyRkfM7A5Lo           71        2.0         2.82           0.0       0.0            0.0           3.0
# 619   burncPhAzPbo9QCzN9j8ig2FKZjwDhM5zgN2eW3GmWa           29        2.0         6.90           1.0       0.0            0.0           5.0
# 505   HrWYa5vKZrcDbQWE39SGYwyzYcbsmXfBiHJGxpasymm            8        2.0        25.00           0.0       0.0            1.0           2.0
# 311  BuonuQoAR74GoMwCFhxKWVWWSGGt2wfbNmQ3cizaJ97G           15        2.0        13.33           0.0       0.0            1.0           2.0
# 471  GRT7yrpfF1TEvp3RmCzu5YZ74B4EueVMPg5NYtSiPwtD           18        2.0        11.11           0.0       0.0            3.0           4.0
# 264  AjGby82yXeYgj3kmng9y3c4nQpZFmiPpJKecLJTHbfbP           43        2.0         4.65           1.0       0.0            0.0           1.0
# 446   FoXyHJXdQGK2eHoTjSAzHq4hzxWdJvpGgyzrtPS9eAk           31        2.0         6.45           1.0       2.0            1.0           6.0
# 425  F1REzm2dJW1wfj2yHjCMV3FxVs8TXQG9qoW4MFEz6uYo           19        2.0        10.53           1.0       0.0            0.0           2.0
# 237  9ueKvL3WiLM4mNUZrfWqPTYY2Np5YwzFTYvAiPibx1Zq           36        2.0         5.56           0.0       0.0            0.0           3.0
# 664   mds2fZEpJP688PqJHvfLxGyf2VFrcNkvjuUxNYCwjrq           30        2.0         6.67           0.0       0.0            1.0           4.0
# 475  Gd33fENP1XsBimff41s1EWrs2kmqfGQqEJ5CQPQB3Jwy           56        2.0         3.57           0.0       0.0            2.0           3.0
# 411  EZHZcXFpiiooHDJymKPro6gSVBqz6JfRwDAnSHUwkXRV           25        1.0         4.00           0.0       0.0            0.0           1.0
# 739   xLabscif2DLnYg39rQThqi7A9E45L9qiysRZhmZ1ARE           19        1.0         5.26           0.0       0.0            0.0           1.0
# 279  B4dn3WWS95M4qNXaR5NTdkNzhzvTZVqC13E3eLrWhXLa           32        1.0         3.12           0.0       0.0            2.0           5.0
# 390  E4xNK4UwGnMtkdiUPyx13i6NkFDdW9Gw9NFGY93wEdGZ           13        1.0         7.69           0.0       0.0            0.0           1.0
# 37   2nhGaJvR17TeytzJVajPfABHQcAwinKoCG8F69gRdQot           47        1.0         2.13           0.0       0.0            0.0           1.0
# 600   XAqHfPFsqTfAJHBRHAcEECkMSykXjkUj2Rta16Qshrk           31        1.0         3.23           0.0       0.0            0.0           2.0
# 73   4GEEKSwuiBHWTff9WaqrDcToZjbX6KYdyB4c578Zxse2           36        1.0         2.78           0.0       0.0            1.0           3.0
# 681   odcvDWH5wHVKz9XtmGGxTj5ZsmawTjCCty3nyBKDGzS           38        1.0         2.63           1.0       0.0            4.0           5.0
# 244  ABREU5YkQcfpDZymoQ97iGUgQcfgjctWUUxEMfumiPdV            8        1.0        12.50           0.0       0.0            1.0           0.0
# 536   MargusHP4dQyxrBuCWngzJp6EZSvg1aPNxdgpXykfr4           17        1.0         5.88           1.0       0.0            0.0           0.0
# 197  8j7RdaofeR9jaXWqYTubqooHpcajP7EfhWbR4UKUB4fF           31        1.0         3.23           2.0       0.0            3.0           4.0
# 467  GLAMiBuunBioazKwNbkGnWP6BM2sfVjehr4goPPGBFAC           17        1.0         5.88           0.0       0.0            1.0           1.0
# 716   scs1NCSTafrUX6RBx113B9YDCepo1QdEzU8WwEkf25i           28        1.0         3.57           1.0       0.0            1.0           3.0
# 162  7Hp1e6BrTBkbBN4wFiNmycPVPsjvyUUBL2tGhYEMT6gt           37        1.0         2.70           0.0       0.0            0.0           1.0
# 146  6qwYjs5vCSEKaTMBbHinnW8fvdGj1r8cpzPoAV1EHKsw           27        1.0         3.70           0.0       0.0            0.0           1.0
# 565   SELEXm1aELCweknS2tsG6A4WivjVvgrTWn9doHNLj66           16        0.0         0.00           0.0       0.0            0.0           0.0
# 33   2kVZVTY8FMRZ3WuHzyqNz8qd4Ytbba9f9DaesUm5WLvR           16        0.0         0.00           0.0       0.0            0.0           0.0
# 27   2bpfa8JbFfZUGUsedDsemu6vQUxbhcEM8ALSH3PgXd2d           15        0.0         0.00           0.0       0.0            0.0           0.0
# 21   2Ue9zGmDnvYRrJNEjuAdNkbbickw6fKWtbeNM7T2rakg           11        0.0         0.00           0.0       0.0            0.0           0.0
# 1    12i8gndWWWMTRzJBFhnYkobNgZB3XMUUJq75HeUrshrk           10        0.0         0.00           0.0       0.0            0.0           0.0
# 122  5t4shVsKnUqgjmhK3fFNsvyju2E6Rd7cc4S5pmqqEVEW           16        0.0         0.00           0.0       0.0            0.0           0.0
# 694   prt1st4RSxAt32ams4zsXCe1kavzmKeoR7eh1sdYRXW           14        0.0         0.00           0.0       0.0            0.0           0.0

# %%
# ───────────────────────────────────────────────
# Cell 4: VERIFICATION - Are These Actually MEV Bots or Aggregators?
# Based on Grok's analysis: Verify if detected "attackers" are MEV bots or just aggregators
# ───────────────────────────────────────────────

print("\n" + "="*100)
print("VERIFICATION: MEV Bots vs Aggregators (Jupiter, etc.)")
print("="*100)
print("\n⚠️  IMPORTANT: The detected 'attackers' may be:")
print("   1. MEV bots (actual attackers)")
print("   2. Jupiter aggregator (bundling user orders)")
print("   3. Regular trade bots (market making, arbitrage)")
print("   4. Legitimate high-frequency traders")
print("\nThis analysis helps distinguish between them.\n")

if not sandwich_df.empty and len(top10_attackers) > 0:
    # Analyze top attackers in detail
    print("Analyzing top detected 'attackers' for MEV vs Aggregator patterns...\n")
    
    verification_results = []
    
    for attacker in top10_attackers[:5]:  # Analyze top 5
        attacker_trades = trades[trades['signer'] == attacker].copy()
        
        if len(attacker_trades) == 0:
            continue
        
        # Calculate metrics
        total_trades = len(attacker_trades)
        
        # 1. Check for aggregator pattern: many unique signers in same slots
        attacker_slots = attacker_trades['slot'].unique()
        aggregator_score = 0
        
        for slot in attacker_slots[:100]:  # Sample first 100 slots
            slot_trades = trades[trades['slot'] == slot]
            unique_signers = slot_trades['signer'].nunique()
            total_in_slot = len(slot_trades)
            if total_in_slot > 0:
                ratio = unique_signers / total_in_slot
                if ratio > 0.7:  # High unique signer ratio = aggregator
                    aggregator_score += 1
        
        aggregator_likelihood = aggregator_score / min(100, len(attacker_slots))
        
        # 2. Check for MEV patterns
        # - Late-slot timing (front-running)
        late_slot_trades = attacker_trades[attacker_trades['us_since_first_shred'] > 300000]
        late_slot_ratio = len(late_slot_trades) / total_trades if total_trades > 0 else 0
        
        # - Oracle back-running
        attacker_trades_with_prev = attacker_trades.copy()
        attacker_trades_with_prev['prev_kind'] = df_clean.loc[attacker_trades_with_prev.index - 1, 'kind'].values
        oracle_backrun = attacker_trades_with_prev[
            (attacker_trades_with_prev['prev_kind'] == 'ORACLE') & 
            (attacker_trades_with_prev['time_diff_ms'] < 50)
        ]
        oracle_backrun_ratio = len(oracle_backrun) / total_trades if total_trades > 0 else 0
        
        # - High bytes_changed (oracle manipulation)
        high_bytes = attacker_trades[attacker_trades['bytes_changed_trade'] > 50]
        high_bytes_ratio = len(high_bytes) / total_trades if total_trades > 0 else 0
        
        # - Clusters (multiple tx in same slot)
        attacker_trades['tx_in_slot'] = attacker_trades.groupby('slot')['slot'].transform('count')
        clusters = attacker_trades[attacker_trades['tx_in_slot'] >= 2]
        cluster_ratio = len(clusters) / total_trades if total_trades > 0 else 0
        
        # Calculate MEV score
        mev_score = (late_slot_ratio * 0.3 + 
                    oracle_backrun_ratio * 0.3 + 
                    high_bytes_ratio * 0.2 + 
                    cluster_ratio * 0.2)
        
        # 3. Check for wash trading patterns
        # Wash trading indicators:
        # - Circular flows (same address sending/receiving)
        # - Many unique recipient addresses
        # - Low net profit despite high volume
        # - Temporary addresses (created and used once)
        # - Immediate return of funds
        
        # Check for circular flow pattern: same signer appearing multiple times in short period
        attacker_trades_sorted = attacker_trades.sort_values('ms_time')
        time_gaps = attacker_trades_sorted['ms_time'].diff()
        
        # Wash trading: rapid cycling (many trades in short time)
        if len(attacker_trades) > 10:
            time_span_hours = (attacker_trades['ms_time'].max() - attacker_trades['ms_time'].min()) / (1000 * 60 * 60)
            trades_per_hour = len(attacker_trades) / time_span_hours if time_span_hours > 0 else 0
            
            # High trade frequency with low profit indicators = wash trading
            # Orb analysis showed: 116K USDC cycled, only 3.33 USDC profit = wash trading
            # Pattern: >50 trades/hour with low MEV score = likely wash trading
            wash_trading_score = trades_per_hour / 50  # Normalize to 50 trades/hour
        else:
            wash_trading_score = 0
            trades_per_hour = 0
        
        # Classification with wash trading detection
        if aggregator_likelihood > 0.5:
            classification = "LIKELY AGGREGATOR (Jupiter, etc.)"
            confidence = "High" if aggregator_likelihood > 0.7 else "Medium"
        elif wash_trading_score > 1.0 and mev_score < 0.2:
            # High trade frequency but low MEV score = wash trading
            classification = "LIKELY WASH TRADING (Volume Inflation)"
            confidence = "High" if wash_trading_score > 2.0 else "Medium"
        elif mev_score > 0.3:
            classification = "LIKELY MEV BOT"
            confidence = "High" if mev_score > 0.5 else "Medium"
        elif cluster_ratio > 0.3:
            classification = "POSSIBLE MEV (Sandwich patterns)"
            confidence = "Medium"
        else:
            classification = "REGULAR TRADE BOT / UNKNOWN"
            confidence = "Low"
        
        verification_results.append({
            'attacker': attacker,
            'total_trades': total_trades,
            'trades_per_hour': f"{trades_per_hour:.1f}",
            'aggregator_likelihood': f"{aggregator_likelihood:.2%}",
            'late_slot_ratio': f"{late_slot_ratio:.2%}",
            'oracle_backrun_ratio': f"{oracle_backrun_ratio:.2%}",
            'high_bytes_ratio': f"{high_bytes_ratio:.2%}",
            'cluster_ratio': f"{cluster_ratio:.2%}",
            'mev_score': f"{mev_score:.2%}",
            'wash_trading_score': f"{wash_trading_score:.2f}",
            'classification': classification,
            'confidence': confidence
        })
        
        print(f"\n{'─'*100}")
        print(f"Attacker: {attacker}")
        print(f"{'─'*100}")
        print(f"Total Trades: {total_trades:,}")
        print(f"\nPattern Analysis:")
        print(f"  Trades per Hour: {trades_per_hour:.1f}")
        print(f"  Aggregator Likelihood: {aggregator_likelihood:.2%} (slots with >70% unique signers)")
        print(f"  Late-Slot Trades (>300ms): {late_slot_ratio:.2%}")
        print(f"  Oracle Back-Running (<50ms): {oracle_backrun_ratio:.2%}")
        print(f"  High Bytes Changed (>50): {high_bytes_ratio:.2%}")
        print(f"  Clusters (≥2 tx/slot): {cluster_ratio:.2%}")
        print(f"\nMEV Score: {mev_score:.2%}")
        print(f"Wash Trading Score: {wash_trading_score:.2f} (>1.0 = suspicious)")
        print(f"\nClassification: {classification}")
        print(f"Confidence: {confidence}")
        
        # Special note for wash trading
        if "WASH TRADING" in classification:
            print(f"\n⚠️  WASH TRADING DETECTED:")
            print(f"   - High trade frequency ({trades_per_hour:.1f} trades/hour)")
            print(f"   - Low MEV score ({mev_score:.2%}) = not extracting value")
            print(f"   - Pattern: Volume inflation, transaction count farming, or protocol gaming")
            print(f"   - Example: AEB9dXBoxkrapNd59Kg29JefMMf3M1WLcNA12XjKSf4R cycled 116K USDC, only 3.33 USDC profit")
    
    # Summary table
    verification_df = pd.DataFrame(verification_results)
    if not verification_df.empty:
        print(f"\n{'='*100}")
        print("VERIFICATION SUMMARY")
        print(f"{'='*100}")
        display(verification_df)
        
        # Save verification results
        verification_df.to_csv('mev_attacker_verification.csv', index=False)
        print("\n✓ Verification results saved to: mev_attacker_verification.csv")
        
        # Count classifications
        print(f"\nClassification Breakdown:")
        print(verification_df['classification'].value_counts())
        
        print(f"\n⚠️  IMPORTANT NOTES:")
        print(f"   - If 'LIKELY AGGREGATOR': These are NOT MEV bots, just Jupiter/aggregator routing")
        print(f"   - If 'LIKELY WASH TRADING': Volume inflation, not MEV (e.g., AEB9dXBoxkrapNd59Kg29JefMMf3M1WLcNA12XjKSf4R)")
        print(f"   - If 'LIKELY MEV BOT': These show MEV attack patterns")
        print(f"   - If 'REGULAR TRADE BOT': May be legitimate market making/arbitrage")
        print(f"   - Check Orb (orbmarkets.io) for these addresses to verify transaction history")
        print(f"   - Look for failed transactions (slippage errors) = failed MEV attempts")
        print(f"   - Wash trading: Circular flows, low profit despite high volume = protocol gaming")
        
else:
    print("No attackers detected to verify. This may indicate:")
    print("  - Low MEV activity (good news for pAMMs)")
    print("  - Detection thresholds too strict")
    print("  - Mostly aggregator routing (Jupiter) without MEV patterns")

# ───────────────────────────────────────────────
# Detailed Activity Analysis for Top Attackers
# ───────────────────────────────────────────────
if len(top10_attackers) > 0:
    print(f"\n{'='*100}")
    print("DETAILED ACTIVITY ANALYSIS")
    print(f"{'='*100}\n")
    
    for attacker in top10_attackers[:3]:  # Top 3
        attacker_txs = df_clean[df_clean['signer'] == attacker].copy()
        
        if len(attacker_txs) == 0:
            continue
        
        print(f"\nAttacker: {attacker}")
        print(f"Total Events: {len(attacker_txs):,}")
        
        # Event type breakdown
        event_types = attacker_txs['kind'].value_counts()
        print(f"\nEvent Types:")
        for kind, count in event_types.items():
            print(f"  {kind}: {count:,}")
        
        # TRADE-specific analysis
        attacker_trades = attacker_txs[attacker_txs['kind'] == 'TRADE']
        if len(attacker_trades) > 0:
            print(f"\nTRADE Analysis:")
            print(f"  Total TRADEs: {len(attacker_trades):,}")
            
            # Timing analysis
            if 'us_since_first_shred' in attacker_trades.columns:
                avg_latency = attacker_trades['us_since_first_shred'].mean()
                late_trades = len(attacker_trades[attacker_trades['us_since_first_shred'] > 300000])
                print(f"  Avg Latency: {avg_latency:,.0f} µs")
                print(f"  Late-Slot Trades (>300ms): {late_trades:,} ({late_trades/len(attacker_trades):.2%})")
            
            # Bytes changed analysis
            if 'bytes_changed_trade' in attacker_trades.columns:
                high_bytes = len(attacker_trades[attacker_trades['bytes_changed_trade'] > 50])
                print(f"  High Bytes Changed (>50): {high_bytes:,} ({high_bytes/len(attacker_trades):.2%})")
            
            # Slot clustering
            slot_counts = attacker_trades['slot'].value_counts()
            multi_slot = len(slot_counts[slot_counts >= 2])
            print(f"  Slots with Multiple Trades: {multi_slot:,}")
            
            # Save detailed activity
            activity_file = f'attacker_{attacker[:8]}_detailed_activity.csv'
            attacker_trades.to_csv(activity_file, index=False)
            print(f"  ✓ Detailed activity saved to: {activity_file}")
    
    # ───────────────────────────────────────────────
    # Pool Activity Analysis - Show Bot Density Across Pools
    # ───────────────────────────────────────────────
    print(f"\n{'='*100}")
    print("POOL ACTIVITY ANALYSIS - Attacker Distribution Across Pools")
    print(f"{'='*100}\n")
    
    if len(top10_attackers) > 0:
        pool_analysis_results = []
        
        for attacker in top10_attackers:
            attacker_trades = trades[trades['signer'] == attacker].copy()
            
            if len(attacker_trades) == 0:
                continue
            
            # Get pool information from account_trade (where is_pool_trade == True)
            if 'account_trade' in attacker_trades.columns and 'is_pool_trade' in attacker_trades.columns:
                pool_trades = attacker_trades[attacker_trades['is_pool_trade'] == True]
                
                if len(pool_trades) > 0:
                    # Get unique pools
                    unique_pools = pool_trades['account_trade'].nunique()
                    pool_counts = pool_trades['account_trade'].value_counts()
                    
                    # Top pools for this attacker
                    top_pools = pool_counts.head(5).to_dict()
                    
                    pool_analysis_results.append({
                        'attacker': attacker,
                        'total_trades': len(attacker_trades),
                        'pool_trades': len(pool_trades),
                        'unique_pools': unique_pools,
                        'pools_per_trade_ratio': unique_pools / len(pool_trades) if len(pool_trades) > 0 else 0,
                        'top_pool': pool_counts.index[0] if len(pool_counts) > 0 else 'N/A',
                        'top_pool_trades': pool_counts.iloc[0] if len(pool_counts) > 0 else 0,
                        'top_pool_%': (pool_counts.iloc[0] / len(pool_trades) * 100) if len(pool_trades) > 0 else 0
                    })
                else:
                    # No pool trades detected
                    pool_analysis_results.append({
                        'attacker': attacker,
                        'total_trades': len(attacker_trades),
                        'pool_trades': 0,
                        'unique_pools': 0,
                        'pools_per_trade_ratio': 0,
                        'top_pool': 'N/A',
                        'top_pool_trades': 0,
                        'top_pool_%': 0
                    })
            else:
                # Fallback: use amm_trade as proxy for pools
                unique_amms = attacker_trades['amm_trade'].nunique()
                amm_counts = attacker_trades['amm_trade'].value_counts()
                
                pool_analysis_results.append({
                    'attacker': attacker,
                    'total_trades': len(attacker_trades),
                    'pool_trades': len(attacker_trades),
                    'unique_pools': unique_amms,  # Using AMM as proxy
                    'pools_per_trade_ratio': unique_amms / len(attacker_trades) if len(attacker_trades) > 0 else 0,
                    'top_pool': amm_counts.index[0] if len(amm_counts) > 0 else 'N/A',
                    'top_pool_trades': amm_counts.iloc[0] if len(amm_counts) > 0 else 0,
                    'top_pool_%': (amm_counts.iloc[0] / len(attacker_trades) * 100) if len(attacker_trades) > 0 else 0
                })
        
        if pool_analysis_results:
            pool_analysis_df = pd.DataFrame(pool_analysis_results)
            
            print("Attacker Pool Distribution Summary:")
            print("-" * 100)
            display_cols = ['attacker', 'total_trades', 'unique_pools', 'top_pool', 'top_pool_trades', 'top_pool_%']
            display(pool_analysis_df[display_cols])
            
            # Detailed pool breakdown per attacker
            print(f"\n{'─'*100}")
            print("DETAILED POOL BREAKDOWN PER ATTACKER:")
            print(f"{'─'*100}\n")
            
            for attacker in top10_attackers:
                attacker_trades = trades[trades['signer'] == attacker].copy()
                
                if len(attacker_trades) == 0:
                    continue
                
                print(f"\nAttacker: {attacker}")
                print(f"{'─'*80}")
                
                if 'account_trade' in attacker_trades.columns and 'is_pool_trade' in attacker_trades.columns:
                    pool_trades = attacker_trades[attacker_trades['is_pool_trade'] == True]
                    
                    if len(pool_trades) > 0:
                        pool_stats = pool_trades.groupby(['account_trade', 'amm_trade']).agg({
                            'slot': 'count',
                            'ms_time': ['min', 'max']
                        }).reset_index()
                        pool_stats.columns = ['pool', 'amm', 'trade_count', 'first_trade', 'last_trade']
                        pool_stats = pool_stats.sort_values('trade_count', ascending=False)
                        
                        print(f"Active in {len(pool_stats)} pools:")
                        print(f"\nTop 10 Pools by Trade Count:")
                        top_pools = pool_stats.head(10)
                        for idx, row in top_pools.iterrows():
                            print(f"  {idx+1}. Pool: {row['pool'][:20]}... | AMM: {row['amm']} | Trades: {row['trade_count']:,}")
                        
                        if len(pool_stats) > 10:
                            print(f"  ... and {len(pool_stats) - 10} more pools")
                    else:
                        print("No pool trades detected (using AMM as proxy)")
                        amm_stats = attacker_trades.groupby('amm_trade').size().sort_values(ascending=False)
                        print(f"Active in {len(amm_stats)} AMMs:")
                        for amm, count in amm_stats.head(10).items():
                            print(f"  • {amm}: {count:,} trades")
                else:
                    # Fallback to AMM
                    amm_stats = attacker_trades.groupby('amm_trade').size().sort_values(ascending=False)
                    print(f"Active in {len(amm_stats)} AMMs (pool data not available):")
                    for amm, count in amm_stats.head(10).items():
                        print(f"  • {amm}: {count:,} trades")
            
            # Summary statistics
            print(f"\n{'─'*100}")
            print("POOL ACTIVITY SUMMARY:")
            print(f"{'─'*100}")
            print(f"Average pools per attacker: {pool_analysis_df['unique_pools'].mean():.1f}")
            print(f"Max pools for single attacker: {pool_analysis_df['unique_pools'].max()}")
            print(f"Min pools for single attacker: {pool_analysis_df['unique_pools'].min()}")
            print(f"\nAttacker Pool Concentration:")
            print(f"  High concentration (1-2 pools): {len(pool_analysis_df[pool_analysis_df['unique_pools'] <= 2])} attackers")
            print(f"  Medium concentration (3-5 pools): {len(pool_analysis_df[(pool_analysis_df['unique_pools'] > 2) & (pool_analysis_df['unique_pools'] <= 5)])} attackers")
            print(f"  Low concentration (6+ pools): {len(pool_analysis_df[pool_analysis_df['unique_pools'] > 5])} attackers")
            
            # Pool density analysis - which pools have most attackers
            print(f"\n{'─'*100}")
            print("POOL DENSITY - Which Pools Have Most Attackers:")
            print(f"{'─'*100}")
            
            # Collect all pool-attacker pairs
            pool_attacker_pairs = []
            for attacker in top10_attackers:
                attacker_trades = trades[trades['signer'] == attacker].copy()
                
                if 'account_trade' in attacker_trades.columns and 'is_pool_trade' in attacker_trades.columns:
                    pool_trades = attacker_trades[attacker_trades['is_pool_trade'] == True]
                    if len(pool_trades) > 0:
                        unique_pools = pool_trades['account_trade'].unique()
                        for pool in unique_pools:
                            pool_attacker_pairs.append({
                                'pool': pool,
                                'attacker': attacker,
                                'amm': pool_trades[pool_trades['account_trade'] == pool]['amm_trade'].iloc[0] if len(pool_trades[pool_trades['account_trade'] == pool]) > 0 else 'Unknown'
                            })
                else:
                    # Fallback to AMM
                    unique_amms = attacker_trades['amm_trade'].unique()
                    for amm in unique_amms:
                        pool_attacker_pairs.append({
                            'pool': amm,  # Using AMM as pool proxy
                            'attacker': attacker,
                            'amm': amm
                        })
            
            if pool_attacker_pairs:
                pool_density_df = pd.DataFrame(pool_attacker_pairs)
                pool_density = pool_density_df.groupby(['pool', 'amm']).size().reset_index(name='attacker_count')
                pool_density = pool_density.sort_values('attacker_count', ascending=False)
                
                print(f"\nTop 20 Pools by Attacker Count (Bot Density):")
                print(pool_density.head(20).to_string(index=False))
                
                # Save pool analysis
                pool_analysis_df.to_csv('attacker_pool_analysis.csv', index=False)
                pool_density.to_csv('pool_density_analysis.csv', index=False)
                print(f"\n✓ Attacker pool analysis saved to: attacker_pool_analysis.csv")
                print(f"✓ Pool density analysis saved to: pool_density_analysis.csv")
                
                # Insights
                print(f"\n{'─'*100}")
                print("INSIGHTS:")
                print(f"{'─'*100}")
                max_density_pool = pool_density.iloc[0]
                print(f"  • Most targeted pool: {max_density_pool['pool'][:20]}... ({max_density_pool['attacker_count']} attackers)")
                print(f"  • AMM: {max_density_pool['amm']}")
                print(f"  • High density pools (>3 attackers): {len(pool_density[pool_density['attacker_count'] > 3])} pools")
                print(f"  • Low density pools (1 attacker): {len(pool_density[pool_density['attacker_count'] == 1])} pools")
                print(f"\n  Interpretation:")
                print(f"    - High density pools (>3 attackers) = likely profitable targets for MEV")
                print(f"    - Low density (1 attacker) = specialized bot or less profitable")
                print(f"    - Multi-pool attackers = generalized bots scanning multiple opportunities")
    
    print(f"\n{'='*100}")
    print("RECOMMENDATIONS:")
    print(f"{'='*100}")
    print("1. Check Orb (orbmarkets.io) for these addresses:")
    for attacker in top10_attackers[:5]:
        print(f"   https://orbmarkets.io/account/{attacker}")
    print("\n2. Look for:")
    print("   - Failed transactions (slippage errors) = failed MEV attempts")
    print("   - Transaction patterns (repeated front-run/back-run)")
    print("   - Program IDs (Jupiter aggregator vs MEV bot)")
    print("   - Profit/loss patterns")
    print("\n3. Compare with known MEV bot addresses from public sources")
    print("4. Review verification results above to determine if aggregator or MEV")
    print("5. Review pool density analysis - high density pools may need protection")
# Out:
# ====================================================================================================
# VERIFICATION: MEV Bots vs Aggregators (Jupiter, etc.)
# ====================================================================================================
#
# ⚠️  IMPORTANT: The detected 'attackers' may be:
#    1. MEV bots (actual attackers)
#    2. Jupiter aggregator (bundling user orders)
#    3. Regular trade bots (market making, arbitrage)
#    4. Legitimate high-frequency traders
#
# This analysis helps distinguish between them.
#
# Analyzing top detected 'attackers' for MEV vs Aggregator patterns...
#
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Attacker: YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Total Trades: 31,220
#
# Pattern Analysis:
#   Trades per Hour: 2828.8
#   Aggregator Likelihood: 69.00% (slots with >70% unique signers)
#   Late-Slot Trades (>300ms): 21.55%
#   Oracle Back-Running (<50ms): 74.52%
#   High Bytes Changed (>50): 0.01%
#   Clusters (≥2 tx/slot): 77.14%
#
# MEV Score: 44.25%
# Wash Trading Score: 56.58 (>1.0 = suspicious)
#
# Classification: LIKELY AGGREGATOR (Jupiter, etc.)
# Confidence: Medium
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Attacker: E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Total Trades: 14,969
#
# Pattern Analysis:
#   Trades per Hour: 1356.3
#   Aggregator Likelihood: 85.00% (slots with >70% unique signers)
#   Late-Slot Trades (>300ms): 15.55%
#   Oracle Back-Running (<50ms): 73.66%
#   High Bytes Changed (>50): 4.50%
#   Clusters (≥2 tx/slot): 47.93%
#
# MEV Score: 37.25%
# Wash Trading Score: 27.13 (>1.0 = suspicious)
#
# Classification: LIKELY AGGREGATOR (Jupiter, etc.)
# Confidence: High
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Attacker: YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Total Trades: 14,400
#
# Pattern Analysis:
#   Trades per Hour: 1304.8
#   Aggregator Likelihood: 79.00% (slots with >70% unique signers)
#   Late-Slot Trades (>300ms): 24.55%
#   Oracle Back-Running (<50ms): 72.81%
#   High Bytes Changed (>50): 0.00%
#   Clusters (≥2 tx/slot): 82.33%
#
# MEV Score: 45.67%
# Wash Trading Score: 26.10 (>1.0 = suspicious)
#
# Classification: LIKELY AGGREGATOR (Jupiter, etc.)
# Confidence: High
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Attacker: YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Total Trades: 5,085
#
# Pattern Analysis:
#   Trades per Hour: 461.6
#   Aggregator Likelihood: 69.00% (slots with >70% unique signers)
#   Late-Slot Trades (>300ms): 23.52%
#   Oracle Back-Running (<50ms): 69.30%
#   High Bytes Changed (>50): 0.02%
#   Clusters (≥2 tx/slot): 73.51%
#
# MEV Score: 42.55%
# Wash Trading Score: 9.23 (>1.0 = suspicious)
#
# Classification: LIKELY AGGREGATOR (Jupiter, etc.)
# Confidence: Medium
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Attacker: 4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Total Trades: 9,999
#
# Pattern Analysis:
#   Trades per Hour: 906.2
#   Aggregator Likelihood: 73.00% (slots with >70% unique signers)
#   Late-Slot Trades (>300ms): 15.26%
#   Oracle Back-Running (<50ms): 70.90%
#   High Bytes Changed (>50): 0.03%
#   Clusters (≥2 tx/slot): 50.30%
#
# MEV Score: 35.91%
# Wash Trading Score: 18.12 (>1.0 = suspicious)
#
# Classification: LIKELY AGGREGATOR (Jupiter, etc.)
# Confidence: High
#
# ====================================================================================================
# VERIFICATION SUMMARY
# ====================================================================================================
#                                        attacker  total_trades trades_per_hour aggregator_likelihood late_slot_ratio oracle_backrun_ratio high_bytes_ratio cluster_ratio mev_score wash_trading_score                     classification confidence
# 0   YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP         31220          2828.8                69.00%          21.55%               74.52%            0.01%        77.14%    44.25%              56.58  LIKELY AGGREGATOR (Jupiter, etc.)     Medium
# 1  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2         14969          1356.3                85.00%          15.55%               73.66%            4.50%        47.93%    37.25%              27.13  LIKELY AGGREGATOR (Jupiter, etc.)       High
# 2   YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW         14400          1304.8                79.00%          24.55%               72.81%            0.00%        82.33%    45.67%              26.10  LIKELY AGGREGATOR (Jupiter, etc.)       High
# 3   YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj          5085           461.6                69.00%          23.52%               69.30%            0.02%        73.51%    42.55%               9.23  LIKELY AGGREGATOR (Jupiter, etc.)     Medium
# 4  4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV          9999           906.2                73.00%          15.26%               70.90%            0.03%        50.30%    35.91%              18.12  LIKELY AGGREGATOR (Jupiter, etc.)       High
# ✓ Verification results saved to: mev_attacker_verification.csv
#
# Classification Breakdown:
# classification
# LIKELY AGGREGATOR (Jupiter, etc.)    5
# Name: count, dtype: int64
#
# ⚠️  IMPORTANT NOTES:
#    - If 'LIKELY AGGREGATOR': These are NOT MEV bots, just Jupiter/aggregator routing
#    - If 'LIKELY WASH TRADING': Volume inflation, not MEV (e.g., AEB9dXBoxkrapNd59Kg29JefMMf3M1WLcNA12XjKSf4R)
#    - If 'LIKELY MEV BOT': These show MEV attack patterns
#    - If 'REGULAR TRADE BOT': May be legitimate market making/arbitrage
#    - Check Orb (orbmarkets.io) for these addresses to verify transaction history
#    - Look for failed transactions (slippage errors) = failed MEV attempts
#    - Wash trading: Circular flows, low profit despite high volume = protocol gaming
#
# ====================================================================================================
# DETAILED ACTIVITY ANALYSIS
# ====================================================================================================
#
#
# Attacker: YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP
# Total Events: 31,220
#
# Event Types:
#   TRADE: 31,220
#
# TRADE Analysis:
#   Total TRADEs: 31,220
#   Avg Latency: 206,755 µs
#   Late-Slot Trades (>300ms): 6,729 (21.55%)
#   High Bytes Changed (>50): 4 (0.01%)
#   Slots with Multiple Trades: 7,946
#   ✓ Detailed activity saved to: attacker_YubQzu18_detailed_activity.csv
#
# Attacker: E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2
# Total Events: 14,969
#
# Event Types:
#   TRADE: 14,969
#
# TRADE Analysis:
#   Total TRADEs: 14,969
#   Avg Latency: 179,653 µs
#   Late-Slot Trades (>300ms): 2,328 (15.55%)
#   High Bytes Changed (>50): 674 (4.50%)
#   Slots with Multiple Trades: 2,579
#   ✓ Detailed activity saved to: attacker_E2MPTDnF_detailed_activity.csv
#
# Attacker: YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW
# Total Events: 14,400
#
# Event Types:
#   TRADE: 14,400
#
# TRADE Analysis:
#   Total TRADEs: 14,400
#   Avg Latency: 220,259 µs
#   Late-Slot Trades (>300ms): 3,535 (24.55%)
#   High Bytes Changed (>50): 0 (0.00%)
#   Slots with Multiple Trades: 4,953
#   ✓ Detailed activity saved to: attacker_YubVwWeg_detailed_activity.csv
#
# ====================================================================================================
# POOL ACTIVITY ANALYSIS - Attacker Distribution Across Pools
# ====================================================================================================
#
# Attacker Pool Distribution Summary:
# ----------------------------------------------------------------------------------------------------
#                                        attacker  total_trades  unique_pools                                      top_pool  top_pool_trades  top_pool_%
# 0   YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP         31220             5  DB3sUCP2H4icbeKmK6yb6nUxU5ogbcRHtGuq7W2RoRwW             8777   28.113389
# 1  E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2         14969            26  65ZHSArs5XxPseKQbB1B4r16vDxMWnCxHMzogDAqiDUc             4899   32.727637
# 2   YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW         14400             2  FAYL7CoNENA6jGCWVJb5MZ7mjKuiiyYRkDTopdVticpp            14380   99.861111
# 3   YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj          5085             1  3QYYvFWgSuGK8bbxMSAYkCqE8QfSuFtByagnZAuekia2             5085  100.000000
# 4  4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV          9999            23  FksffEqnBRixYGR791Qw2MgdU7zNCpHVFYBL4Fa4qVuH             1876   18.761876
# 5  FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1         12075            20  65ZHSArs5XxPseKQbB1B4r16vDxMWnCxHMzogDAqiDUc             6531   54.086957
# 6   k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq          6369             9  FLckHLGMJy5gEoXWwcE68Nprde1D4araK4TGLw4pQq2n             5737   90.076935
# 7  CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP         10563            18  FksffEqnBRixYGR791Qw2MgdU7zNCpHVFYBL4Fa4qVuH             3481   32.954653
# 8   TAPNDP5dFr9Vp47DFuddRxNVYmjUqgh8boiUrWFgMqi          6949            18  4ynTYgJK5ruYx3AZMRjCHrJk1qkm61fePF7dkbvRQD46             2279   32.796086
# 9  AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3         10721            37  FLckHLGMJy5gEoXWwcE68Nprde1D4araK4TGLw4pQq2n             4189   39.072848
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# DETAILED POOL BREAKDOWN PER ATTACKER:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# Attacker: YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP
# ────────────────────────────────────────────────────────────────────────────────
# Active in 5 pools:
#
# Top 10 Pools by Trade Count:
#   4. Pool: DB3sUCP2H4icbeKmK6yb... | AMM: HumidiFi | Trades: 8,777
#   5. Pool: FksffEqnBRixYGR791Qw... | AMM: HumidiFi | Trades: 6,921
#   1. Pool: 51FQwjrvo8J8zXUaKyAz... | AMM: BisonFi | Trades: 5,709
#   2. Pool: 6n9VhCwQ7EwK6NqFDjnH... | AMM: HumidiFi | Trades: 5,476
#   3. Pool: AvGeFw71N5sNfV97mZ1u... | AMM: HumidiFi | Trades: 4,337
#
# Attacker: E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2
# ────────────────────────────────────────────────────────────────────────────────
# Active in 26 pools:
#
# Top 10 Pools by Trade Count:
#   10. Pool: 65ZHSArs5XxPseKQbB1B... | AMM: SolFiV2 | Trades: 4,899
#   4. Pool: 2kfQuYG2FVZL2RqqKEtt... | AMM: SolFiV2 | Trades: 2,803
#   20. Pool: EZAzVScHjYXpmSDkW4Am... | AMM: GoonFi | Trades: 1,052
#   7. Pool: 4uWuh9fC7rrZKrN8ZdJf... | AMM: GoonFi | Trades: 974
#   18. Pool: BjBHvbqgQCRmvZ6u3VzG... | AMM: SolFiV2 | Trades: 837
#   17. Pool: 9oLPmVd3Mett8X5YuwM2... | AMM: ZeroFi | Trades: 731
#   8. Pool: 4ynTYgJK5ruYx3AZMRjC... | AMM: GoonFi | Trades: 673
#   24. Pool: GRaDQ7rcSvXyAbZGQLZB... | AMM: ZeroFi | Trades: 453
#   3. Pool: 2QEaskXh29Nj8TBdCyqf... | AMM: ZeroFi | Trades: 383
#   16. Pool: 9hFbZixs3PPkaXsiJWic... | AMM: GoonFi | Trades: 313
#   ... and 16 more pools
#
# Attacker: YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW
# ────────────────────────────────────────────────────────────────────────────────
# Active in 2 pools:
#
# Top 10 Pools by Trade Count:
#   2. Pool: FAYL7CoNENA6jGCWVJb5... | AMM: HumidiFi | Trades: 14,380
#   1. Pool: F45HLDGN3mYBaJAKB1UG... | AMM: TesseraV | Trades: 20
#
# Attacker: YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj
# ────────────────────────────────────────────────────────────────────────────────
# Active in 1 pools:
#
# Top 10 Pools by Trade Count:
#   1. Pool: 3QYYvFWgSuGK8bbxMSAY... | AMM: HumidiFi | Trades: 5,085
#
# Attacker: 4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV
# ────────────────────────────────────────────────────────────────────────────────
# Active in 23 pools:
#
# Top 10 Pools by Trade Count:
#   20. Pool: FksffEqnBRixYGR791Qw... | AMM: HumidiFi | Trades: 1,876
#   8. Pool: 6n9VhCwQ7EwK6NqFDjnH... | AMM: HumidiFi | Trades: 1,699
#   11. Pool: AvGeFw71N5sNfV97mZ1u... | AMM: HumidiFi | Trades: 1,600
#   6. Pool: 51FQwjrvo8J8zXUaKyAz... | AMM: BisonFi | Trades: 1,593
#   13. Pool: DB3sUCP2H4icbeKmK6yb... | AMM: HumidiFi | Trades: 1,013
#   3. Pool: 3QYYvFWgSuGK8bbxMSAY... | AMM: HumidiFi | Trades: 452
#   7. Pool: 65ZHSArs5XxPseKQbB1B... | AMM: SolFiV2 | Trades: 328
#   19. Pool: FkEB6uvyzuoaGpgs4yRt... | AMM: SolFiV2 | Trades: 293
#   17. Pool: FAYL7CoNENA6jGCWVJb5... | AMM: HumidiFi | Trades: 266
#   9. Pool: 8WFduUYU7iX94E3ZMejp... | AMM: HumidiFi | Trades: 199
#   ... and 13 more pools
#
# Attacker: FbgR9632h4rvPciZzCHRGNrEaQM9bC2cGgAikJ8HUfS1
# ────────────────────────────────────────────────────────────────────────────────
# Active in 20 pools:
#
# Top 10 Pools by Trade Count:
#   9. Pool: 65ZHSArs5XxPseKQbB1B... | AMM: SolFiV2 | Trades: 6,531
#   6. Pool: 4uWuh9fC7rrZKrN8ZdJf... | AMM: GoonFi | Trades: 2,595
#   7. Pool: 4ynTYgJK5ruYx3AZMRjC... | AMM: GoonFi | Trades: 2,003
#   20. Pool: FLckHLGMJy5gEoXWwcE6... | AMM: TesseraV | Trades: 378
#   8. Pool: 51FQwjrvo8J8zXUaKyAz... | AMM: BisonFi | Trades: 317
#   3. Pool: 2kfQuYG2FVZL2RqqKEtt... | AMM: SolFiV2 | Trades: 93
#   17. Pool: BjBHvbqgQCRmvZ6u3VzG... | AMM: SolFiV2 | Trades: 40
#   19. Pool: EZAzVScHjYXpmSDkW4Am... | AMM: GoonFi | Trades: 36
#   11. Pool: 6N8CvQP3KMQ7poeyLg94... | AMM: ZeroFi | Trades: 21
#   2. Pool: 2QEaskXh29Nj8TBdCyqf... | AMM: ZeroFi | Trades: 18
#   ... and 10 more pools
#
# Attacker: k3bS5WfZ5P2NTgkVSwdbVrveYc25iXiEHYfZfVruBGq
# ────────────────────────────────────────────────────────────────────────────────
# Active in 9 pools:
#
# Top 10 Pools by Trade Count:
#   7. Pool: FLckHLGMJy5gEoXWwcE6... | AMM: TesseraV | Trades: 5,737
#   4. Pool: 8iwiQ9CzYKAMAx3mYE8M... | AMM: ZeroFi | Trades: 277
#   9. Pool: FksffEqnBRixYGR791Qw... | AMM: HumidiFi | Trades: 197
#   6. Pool: DB3sUCP2H4icbeKmK6yb... | AMM: HumidiFi | Trades: 145
#   1. Pool: 65ZHSArs5XxPseKQbB1B... | AMM: SolFiV2 | Trades: 6
#   2. Pool: 6LDKXn2hqEtdW1r9jH2y... | AMM: SolFi | Trades: 2
#   3. Pool: 83U3nKpn2pMC3DfLLx57... | AMM: ZeroFi | Trades: 2
#   8. Pool: FkEB6uvyzuoaGpgs4yRt... | AMM: SolFiV2 | Trades: 2
#   5. Pool: BWBHrYqfcjAh5dSiRwzP... | AMM: ObricV2 | Trades: 1
#
# Attacker: CatyeC3LgBxub7HcpW2n7cZZZ66CUKdcZ8DzHucHrSiP
# ────────────────────────────────────────────────────────────────────────────────
# Active in 18 pools:
#
# Top 10 Pools by Trade Count:
#   13. Pool: FksffEqnBRixYGR791Qw... | AMM: HumidiFi | Trades: 3,481
#   11. Pool: DB3sUCP2H4icbeKmK6yb... | AMM: HumidiFi | Trades: 2,042
#   12. Pool: FAYL7CoNENA6jGCWVJb5... | AMM: HumidiFi | Trades: 991
#   3. Pool: 51FQwjrvo8J8zXUaKyAz... | AMM: BisonFi | Trades: 850
#   7. Pool: 8WFduUYU7iX94E3ZMejp... | AMM: HumidiFi | Trades: 710
#   18. Pool: iAMtZieUtpLwB3dzWw8F... | AMM: HumidiFi | Trades: 543
#   10. Pool: Cc2oMdeNDmZ7ZD8b7igQ... | AMM: HumidiFi | Trades: 323
#   16. Pool: HjKAdGgBZDW3kMyFLYzk... | AMM: HumidiFi | Trades: 289
#   17. Pool: hKgG7iEDRFNsJSwLYqz8... | AMM: HumidiFi | Trades: 249
#   8. Pool: 9c5xYTnURgpQLDk4XqkJ... | AMM: HumidiFi | Trades: 241
#   ... and 8 more pools
#
# Attacker: TAPNDP5dFr9Vp47DFuddRxNVYmjUqgh8boiUrWFgMqi
# ────────────────────────────────────────────────────────────────────────────────
# Active in 18 pools:
#
# Top 10 Pools by Trade Count:
#   3. Pool: 4ynTYgJK5ruYx3AZMRjC... | AMM: GoonFi | Trades: 2,279
#   2. Pool: 4uWuh9fC7rrZKrN8ZdJf... | AMM: GoonFi | Trades: 2,172
#   13. Pool: FksffEqnBRixYGR791Qw... | AMM: HumidiFi | Trades: 1,122
#   10. Pool: DB3sUCP2H4icbeKmK6yb... | AMM: HumidiFi | Trades: 602
#   12. Pool: FAYL7CoNENA6jGCWVJb5... | AMM: HumidiFi | Trades: 228
#   14. Pool: GAcKqojqgkRVDBihVAGv... | AMM: HumidiFi | Trades: 149
#   1. Pool: 2866MvCKPGz9LdnPcmPu... | AMM: HumidiFi | Trades: 115
#   17. Pool: hKgG7iEDRFNsJSwLYqz8... | AMM: HumidiFi | Trades: 72
#   8. Pool: AvGeFw71N5sNfV97mZ1u... | AMM: HumidiFi | Trades: 47
#   6. Pool: 8WFduUYU7iX94E3ZMejp... | AMM: HumidiFi | Trades: 41
#   ... and 8 more pools
#
# Attacker: AE861PyrYJXm2TuxiMc8Ecwo4YYgAHfcYum3GWpSRFe3
# ────────────────────────────────────────────────────────────────────────────────
# Active in 37 pools:
#
# Top 10 Pools by Trade Count:
#   29. Pool: FLckHLGMJy5gEoXWwcE6... | AMM: TesseraV | Trades: 4,189
#   27. Pool: F45HLDGN3mYBaJAKB1UG... | AMM: TesseraV | Trades: 1,948
#   8. Pool: 51FQwjrvo8J8zXUaKyAz... | AMM: BisonFi | Trades: 1,228
#   28. Pool: FAYL7CoNENA6jGCWVJb5... | AMM: HumidiFi | Trades: 789
#   30. Pool: FksffEqnBRixYGR791Qw... | AMM: HumidiFi | Trades: 623
#   26. Pool: EphNQCpMGGixqmkYHy9c... | AMM: ZeroFi | Trades: 338
#   35. Pool: H3chk8rgniKXnToGTdPU... | AMM: TesseraV | Trades: 310
#   23. Pool: DB3sUCP2H4icbeKmK6yb... | AMM: HumidiFi | Trades: 259
#   20. Pool: 9oLPmVd3Mett8X5YuwM2... | AMM: ZeroFi | Trades: 157
#   11. Pool: 6N8CvQP3KMQ7poeyLg94... | AMM: ZeroFi | Trades: 111
#   ... and 27 more pools
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# POOL ACTIVITY SUMMARY:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# Average pools per attacker: 15.9
# Max pools for single attacker: 37
# Min pools for single attacker: 1
#
# Attacker Pool Concentration:
#   High concentration (1-2 pools): 2 attackers
#   Medium concentration (3-5 pools): 1 attackers
#   Low concentration (6+ pools): 7 attackers
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# POOL DENSITY - Which Pools Have Most Attackers:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#
# Top 20 Pools by Attacker Count (Bot Density):
#                                         pool      amm  attacker_count
# DB3sUCP2H4icbeKmK6yb6nUxU5ogbcRHtGuq7W2RoRwW HumidiFi               6
# FksffEqnBRixYGR791Qw2MgdU7zNCpHVFYBL4Fa4qVuH HumidiFi               6
# 51FQwjrvo8J8zXUaKyAznJ5NYpoiTCuqAqCu3HAMB9NZ  BisonFi               6
# FLckHLGMJy5gEoXWwcE68Nprde1D4araK4TGLw4pQq2n TesseraV               5
# EZAzVScHjYXpmSDkW4AmejWWQsXig6U7njyzaSZpxQNd   GoonFi               5
# 4uWuh9fC7rrZKrN8ZdJf69MN1e2S7FPpMqcsyY1aof6K   GoonFi               5
# 4ynTYgJK5ruYx3AZMRjCHrJk1qkm61fePF7dkbvRQD46   GoonFi               5
# 65ZHSArs5XxPseKQbB1B4r16vDxMWnCxHMzogDAqiDUc  SolFiV2               5
# 6LDKXn2hqEtdW1r9jH2ykv5j4y3n4EPt1ZHDn5iVZgck    SolFi               5
# FAYL7CoNENA6jGCWVJb5MZ7mjKuiiyYRkDTopdVticpp HumidiFi               5
# 83U3nKpn2pMC3DfLLx57cBtyX68gzwZT5xJnA3W4qCCz   ZeroFi               4
# 9hFbZixs3PPkaXsiJWicfVxPpuUWYa74giXjwuipwHR4   GoonFi               4
# F45HLDGN3mYBaJAKB1UGkx8Y7o2ruS5hgBox1Us6AZF9 TesseraV               4
# 8iwiQ9CzYKAMAx3mYE8MYrFdRcw8XmSJUcXAzGGFqCLJ   ZeroFi               4
# 8WFduUYU7iX94E3ZMejpTXi5TadKh9j5qp5ez5uSBJwa HumidiFi               4
#  iAMtZieUtpLwB3dzWw8Fo3H3FPkMFy3ej52URusseR1 HumidiFi               4
# 7NbPAgjn6W9xH6G1opqYAXVVuJBAtn67DDbD5PTCbA3o    SolFi               4
# 6n9VhCwQ7EwK6NqFDjnHPzEk6wZdRBTfh43RFgHQWHuQ HumidiFi               4
# 4o9kDwyuBhcCF6mmp78HZHPc5Kdw1AmcSwBpcdyQhZvT    SolFi               4
# GAcKqojqgkRVDBihVAGvbqnuZdCiN9UGNrPCRG5DMGGA HumidiFi               4
#
# ✓ Attacker pool analysis saved to: attacker_pool_analysis.csv
# ✓ Pool density analysis saved to: pool_density_analysis.csv
#
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# INSIGHTS:
# ────────────────────────────────────────────────────────────────────────────────────────────────────
#   • Most targeted pool: DB3sUCP2H4icbeKmK6yb... (6 attackers)
#   • AMM: HumidiFi
#   • High density pools (>3 attackers): 22 pools
#   • Low density pools (1 attacker): 3 pools
#
#   Interpretation:
#     - High density pools (>3 attackers) = likely profitable targets for MEV
#     - Low density (1 attacker) = specialized bot or less profitable
#     - Multi-pool attackers = generalized bots scanning multiple opportunities
#
# ====================================================================================================
# RECOMMENDATIONS:
# ====================================================================================================
# 1. Check Orb (orbmarkets.io) for these addresses:
#    https://orbmarkets.io/account/YubQzu18FDqJRyNfG8JqHmsdbxhnoQqcKUHBdUkN6tP
#    https://orbmarkets.io/account/E2MPTDnFPNiCRmbJGKYSYew48NWRGVNfHjoiibFP5VL2
#    https://orbmarkets.io/account/YubVwWeg1vHFr17Q7HQQETcke7sFvMabqU8wbv8NXQW
#    https://orbmarkets.io/account/YubozzSnKomEnH3pkmYsdatUUwUTcm7s4mHJVmefEWj
#    https://orbmarkets.io/account/4swoALYuvetDK6N3ak1Knc1bMLbm7nzkxCW1nqjPWGRV
#
# 2. Look for:
#    - Failed transactions (slippage errors) = failed MEV attempts
#    - Transaction patterns (repeated front-run/back-run)
#    - Program IDs (Jupiter aggregator vs MEV bot)
#    - Profit/loss patterns
#
# 3. Compare with known MEV bot addresses from public sources
# 4. Review verification results above to determine if aggregator or MEV
# 5. Review pool density analysis - high density pools may need protection

# %%
# Summary of saved files:
# 1. per_pamm_all_mev_with_validator.csv - All MEV stats for all attackers across all pAMMs
# 2. per_pamm_top10_mev_with_validator.csv - Top 10 attackers per pAMM
# 3. mev_trades_bots_per_validator.csv - Validator statistics with bot counts and MEV types
